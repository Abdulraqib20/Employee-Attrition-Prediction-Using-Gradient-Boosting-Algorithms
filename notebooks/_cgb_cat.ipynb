# %%
import pandas as pd
pd.set_option('display.max_columns', None) # display all columns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# Setting Custom colors
my_colors = ["#ff6e54", "#ffa600", "#ff2e63", "#a3f7bf", "#9378ff", "#56e39f", "#ff67ab", "#5e2ca5", "#ffd166", "#00b4d8", "#4ecdc4", "#f8edeb"]
my_palette = sns.color_palette(my_colors) # Create a seaborn palette object
sns.set_palette(my_palette)  # Use the custom palette with a seaborn function
from matplotlib.colors import ListedColormap
colors = ['#ffc3a0', '#ffafcc', '#bde0fe', '#ffabab']
my_cmap = sns.color_palette(colors)
cmap = ListedColormap(colors)

import warnings
warnings.filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
train = pd.read_csv('/content/drive/MyDrive/Datasets/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Datasets/test.csv')
add_train = pd.read_csv('/content/drive/MyDrive/Datasets/WA_Fn-UseC_-HR-Employee-Attrition.csv')

display(train.head(), test.head(), add_train.head())
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1
#      id  Age     BusinessTravel  DailyRate              Department  \
# 0  1677   19         Non-Travel        992  Research & Development
# 1  1678   45      Travel_Rarely       1136                   Sales
# 2  1679   37      Travel_Rarely        155  Research & Development
# 3  1680   32      Travel_Rarely        688  Research & Development
# 4  1681   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
# 3                        3   Male          89               2         2
# 4                        3   Male          79               3         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                3        Single           2318
# 1            Sales Executive                1      Divorced           5486
# 2         Research Scientist                4      Divorced           2741
# 3  Healthcare Representative                3        Single           5228
# 4      Laboratory Technician                4        Single           1223
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
# 3        20364                   1      Y       No                 13
# 4        15178                   1      Y       No                 14
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         1             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
# 3                 0                 14                      2
# 4                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7
# 3                       11                     8
# 4                        0                     0
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
train.shape, test.shape, add_train.shape
# Out:
# ((1677, 35), (1119, 34), (1470, 35))

# %%
train.columns = train.columns.str.replace(' ', '')
test.columns = test.columns.str.replace(' ', '')
add_train.columns = add_train.columns.str.replace(' ', '')

# %%
# encode attrition in add_train to numerical
from sklearn.preprocessing import LabelEncoder
add_train['Attrition'] = add_train['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
for i in [train, add_train]:
    print(i['Attrition'].value_counts())
# Out:
# 0    1477
# 1     200
# Name: Attrition, dtype: int64
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
# a_a = add_train[add_train['Attrition'] == 1].reset_index(drop=True)
train = pd.concat([train, add_train]).reset_index(drop=True)
train.tail()
# Out:
#       id  Age     BusinessTravel  DailyRate              Department  \
# 3142 NaN   36  Travel_Frequently        884  Research & Development
# 3143 NaN   39      Travel_Rarely        613  Research & Development
# 3144 NaN   27      Travel_Rarely        155  Research & Development
# 3145 NaN   49  Travel_Frequently       1023                   Sales
# 3146 NaN   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 3142                23          2        Medical              1
# 3143                 6          1        Medical              1
# 3144                 4          3  Life Sciences              1
# 3145                 2          3        Medical              1
# 3146                 8          3        Medical              1
#
#       EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 3142                        3   Male          41               4         2
# 3143                        4   Male          42               2         3
# 3144                        2   Male          87               4         2
# 3145                        4   Male          63               2         2
# 3146                        2   Male          82               4         2
#
#                         JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 3142      Laboratory Technician                4       Married           2571
# 3143  Healthcare Representative                1       Married           9991
# 3144     Manufacturing Director                2       Married           6142
# 3145            Sales Executive                2       Married           5390
# 3146      Laboratory Technician                3       Married           4404
#
#       MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 3142        12290                   4      Y       No                 17
# 3143        21457                   4      Y       No                 15
# 3144         5174                   1      Y      Yes                 20
# 3145        13243                   2      Y       No                 14
# 3146        10228                   2      Y       No                 12
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 3142                  3                         3             80
# 3143                  3                         1             80
# 3144                  4                         2             80
# 3145                  3                         4             80
# 3146                  3                         1             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 3142                 1                 17                      3
# 3143                 1                  9                      5
# 3144                 1                  6                      0
# 3145                 0                 17                      3
# 3146                 0                  6                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 3142                3               5                   2
# 3143                3               7                   7
# 3144                3               6                   2
# 3145                2               9                   6
# 3146                4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition  EmployeeNumber
# 3142                        0                     3          0          2061.0
# 3143                        1                     7          0          2062.0
# 3144                        0                     3          0          2064.0
# 3145                        0                     8          0          2065.0
# 3146                        1                     2          0          2068.0

# %%
data = [train, test]
for i in data:
    print(i.info())
    print('-' *100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1677 non-null   float64
#  1   Age                       3147 non-null   int64
#  2   BusinessTravel            3147 non-null   object
#  3   DailyRate                 3147 non-null   int64
#  4   Department                3147 non-null   object
#  5   DistanceFromHome          3147 non-null   int64
#  6   Education                 3147 non-null   int64
#  7   EducationField            3147 non-null   object
#  8   EmployeeCount             3147 non-null   int64
#  9   EnvironmentSatisfaction   3147 non-null   int64
#  10  Gender                    3147 non-null   object
#  11  HourlyRate                3147 non-null   int64
#  12  JobInvolvement            3147 non-null   int64
#  13  JobLevel                  3147 non-null   int64
#  14  JobRole                   3147 non-null   object
#  15  JobSatisfaction           3147 non-null   int64
#  16  MaritalStatus             3147 non-null   object
#  17  MonthlyIncome             3147 non-null   int64
#  18  MonthlyRate               3147 non-null   int64
#  19  NumCompaniesWorked        3147 non-null   int64
#  20  Over18                    3147 non-null   object
#  21  OverTime                  3147 non-null   object
#  22  PercentSalaryHike         3147 non-null   int64
#  23  PerformanceRating         3147 non-null   int64
#  24  RelationshipSatisfaction  3147 non-null   int64
#  25  StandardHours             3147 non-null   int64
#  26  StockOptionLevel          3147 non-null   int64
#  27  TotalWorkingYears         3147 non-null   int64
#  28  TrainingTimesLastYear     3147 non-null   int64
#  29  WorkLifeBalance           3147 non-null   int64
#  30  YearsAtCompany            3147 non-null   int64
#  31  YearsInCurrentRole        3147 non-null   int64
#  32  YearsSinceLastPromotion   3147 non-null   int64
#  33  YearsWithCurrManager      3147 non-null   int64
#  34  Attrition                 3147 non-null   int64
#  35  EmployeeNumber            1470 non-null   float64
# dtypes: float64(2), int64(26), object(8)
# memory usage: 885.2+ KB
# None
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1119 non-null   int64
#  1   Age                       1119 non-null   int64
#  2   BusinessTravel            1119 non-null   object
#  3   DailyRate                 1119 non-null   int64
#  4   Department                1119 non-null   object
#  5   DistanceFromHome          1119 non-null   int64
#  6   Education                 1119 non-null   int64
#  7   EducationField            1119 non-null   object
#  8   EmployeeCount             1119 non-null   int64
#  9   EnvironmentSatisfaction   1119 non-null   int64
#  10  Gender                    1119 non-null   object
#  11  HourlyRate                1119 non-null   int64
#  12  JobInvolvement            1119 non-null   int64
#  13  JobLevel                  1119 non-null   int64
#  14  JobRole                   1119 non-null   object
#  15  JobSatisfaction           1119 non-null   int64
#  16  MaritalStatus             1119 non-null   object
#  17  MonthlyIncome             1119 non-null   int64
#  18  MonthlyRate               1119 non-null   int64
#  19  NumCompaniesWorked        1119 non-null   int64
#  20  Over18                    1119 non-null   object
#  21  OverTime                  1119 non-null   object
#  22  PercentSalaryHike         1119 non-null   int64
#  23  PerformanceRating         1119 non-null   int64
#  24  RelationshipSatisfaction  1119 non-null   int64
#  25  StandardHours             1119 non-null   int64
#  26  StockOptionLevel          1119 non-null   int64
#  27  TotalWorkingYears         1119 non-null   int64
#  28  TrainingTimesLastYear     1119 non-null   int64
#  29  WorkLifeBalance           1119 non-null   int64
#  30  YearsAtCompany            1119 non-null   int64
#  31  YearsInCurrentRole        1119 non-null   int64
#  32  YearsSinceLastPromotion   1119 non-null   int64
#  33  YearsWithCurrManager      1119 non-null   int64
# dtypes: int64(26), object(8)
# memory usage: 297.4+ KB
# None
# ----------------------------------------------------------------------------------------------------

# %%
print(train.duplicated().sum())
print(test.duplicated().sum())
# Out:
# 0
# 0

# %%
print(train.columns.tolist());print()
print(test.columns.tolist())
# Out:
# ['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition', 'EmployeeNumber']
#
# ['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
train = train.drop(['id', 'Over18','StandardHours', 'EmployeeCount', 'EmployeeNumber'], axis=1)
test = test.drop(['id', 'Over18','StandardHours', 'EmployeeCount'], axis=1)

# %%
for i in train.select_dtypes(exclude='number').columns:
    print(train[i].value_counts())
    print(100 * '-')
# Out:
# Travel_Rarely        2333
# Travel_Frequently     538
# Non-Travel            276
# Name: BusinessTravel, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Research & Development    2128
# Sales                      917
# Human Resources            102
# Name: Department, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Life Sciences       1381
# Medical             1013
# Marketing            311
# Technical Degree     238
# Other                164
# Human Resources       40
# Name: EducationField, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Male      1946
# Female    1201
# Name: Gender, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Sales Executive              681
# Research Scientist           636
# Laboratory Technician        593
# Manufacturing Director       341
# Healthcare Representative    286
# Manager                      213
# Sales Representative         160
# Research Director            151
# Human Resources               86
# Name: JobRole, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Married     1446
# Single      1047
# Divorced     654
# Name: MaritalStatus, dtype: int64
# ----------------------------------------------------------------------------------------------------
# No     2331
# Yes     816
# Name: OverTime, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
for i in test.select_dtypes(exclude='number').columns:
    print(test[i].value_counts())
    print(100 * '-')
# Out:
# Travel_Rarely        799
# Travel_Frequently    212
# Non-Travel           108
# Name: BusinessTravel, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Research & Development    777
# Sales                     306
# Human Resources            36
# Name: Department, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Life Sciences       519
# Medical             345
# Marketing           102
# Technical Degree     96
# Other                45
# Human Resources      12
# Name: EducationField, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Male      690
# Female    429
# Name: Gender, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Sales Executive              240
# Laboratory Technician        230
# Research Scientist           230
# Manufacturing Director       117
# Healthcare Representative    112
# Manager                       71
# Research Director             46
# Sales Representative          44
# Human Resources               29
# Name: JobRole, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Married     524
# Single      394
# Divorced    201
# Name: MaritalStatus, dtype: int64
# ----------------------------------------------------------------------------------------------------
# No     852
# Yes    267
# Name: OverTime, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## EDA

# %%
cat_col = train.select_dtypes('O').columns.to_list() + ['Attrition']
print(cat_col)

test_cat_col = cat_col[:-1]
print(test_cat_col)
# Out:
# ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime', 'Attrition']
# ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']

# %%
review = train[cat_col]
for i in review.columns:
    plt.figure(figsize=(8, 5))
    sns.barplot(x=review[i].value_counts().index, y=review[i].value_counts()).set_title(i)
    plt.show()

# %%
# for i in concatenated_train.select_dtypes(include='number').columns:
#     plt.figure(figsize=(8, 5))
#     sns.histplot(train[i])
#     plt.show();

# %%
# for i in concatenated_train.select_dtypes(include='number').columns:
#     plt.figure(figsize=(8, 5))
#     sns.boxplot(y=train[i])
#     plt.xlabel(i)
#     plt.show();

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Explanation of the columns in the dataset:
#
# 1. **id:** Unique identifier for each employee.
#
# 2. **Age:** The age of the employee.
#
# 3. **BusinessTravel:** The frequency of business travel. This could be "Non-Travel," "Travel_Rarely," or "Travel_Frequently."
#
# 4. **DailyRate:** The daily rate of pay for the employee.
#
# 5. **Department:** The department in which the employee works ('Research & Development', 'Sales', 'Human Resources').
#
# 6. **DistanceFromHome:** The distance of the employee's home from the workplace.
#
# 7. **Education:** The level of education achieved by the employee.
#
# 8. **EducationField:** The field of education of the employee ('Medical', 'Other', 'Marketing', 'Life Sciences', 'Technical Degree', 'Human Resources').
#
# 9. **EmployeeCount:** The count of employees. This column seems to have a constant value and may be dropped as it doesn't provide useful information.
#
# 10. **EnvironmentSatisfaction:** Employee's satisfaction with their work environment.
#
# 11. **Gender:** The gender of the employee.
#
# 12. **HourlyRate:** The hourly rate of pay for the employee.
#
# 13. **JobInvolvement:** The level of job involvement.
#
# 14. **JobLevel:** The level of the employee's job within the company hierarchy.
#
# 15. **JobRole:** The role/title of the employee ('Laboratory Technician', 'Sales Representative', 'Sales Executive',
#        'Healthcare Representative', 'Manager', 'Manufacturing Director',
#        'Research Scientist', 'Human Resources', 'Research Director').
#
# 16. **JobSatisfaction:** Employee's satisfaction with their job.
#
# 17. **MaritalStatus:** The marital status of the employee ('Married', 'Divorced', 'Single').
#
# 18. **MonthlyIncome:** The monthly income of the employee.
#
# 19. **MonthlyRate:** The monthly rate of pay for the employee.
#
# 20. **NumCompaniesWorked:** The number of companies the employee has worked for.
#
# 21. **Over18:** Indicates if the employee is over 18 years old. This column may be dropped if all values are the same.
#
# 22. **OverTime:** Whether the employee works overtime or not.
#
# 23. **PercentSalaryHike:** The percentage increase in salary.
#
# 24. **PerformanceRating:** The performance rating of the employee.
#
# 25. **RelationshipSatisfaction:** Employee's satisfaction with their relationships at work.
#
# 26. **StandardHours:** The standard number of working hours.
#
# 27. **StockOptionLevel:** The level of stock options granted to the employee.
#
# 28. **TotalWorkingYears:** The total number of years the employee has been working.
#
# 29. **TrainingTimesLastYear:** The number of training times the employee attended last year.
#
# 30. **WorkLifeBalance:** Employee's perception of work-life balance.
#
# 31. **YearsAtCompany:** The number of years the employee has spent at the current company.
#
# 32. **YearsInCurrentRole:** The number of years the employee has been in the current role.
#
# 33. **YearsSinceLastPromotion:** The number of years since the last promotion.
#
# 34. **YearsWithCurrManager:** The number of years the employee has been with the current manager.
#
# 35. **Attrition:** The target variable indicating whether the employee has attrited (left the company) or not "Yes" or "No."

# %%
train.select_dtypes(include=['int64', 'float']).columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
for i in train.select_dtypes(exclude='number').columns:
    print(train[i].value_counts())
    print('-' * 50)

print();print();print()
for i in train.select_dtypes(include='number').columns:
    print(train[i].value_counts())
    print('-' * 50)
# Out:
# Travel_Rarely        2333
# Travel_Frequently     538
# Non-Travel            276
# Name: BusinessTravel, dtype: int64
# --------------------------------------------------
# Research & Development    2128
# Sales                      917
# Human Resources            102
# Name: Department, dtype: int64
# --------------------------------------------------
# Life Sciences       1381
# Medical             1013
# Marketing            311
# Technical Degree     238
# Other                164
# Human Resources       40
# Name: EducationField, dtype: int64
# --------------------------------------------------
# Male      1946
# Female    1201
# Name: Gender, dtype: int64
# --------------------------------------------------
# Sales Executive              681
# Research Scientist           636
# Laboratory Technician        593
# Manufacturing Director       341
# Healthcare Representative    286
# Manager                      213
# Sales Representative         160
# Research Director            151
# Human Resources               86
# Name: JobRole, dtype: int64
# --------------------------------------------------
# Married     1446
# Single      1047
# Divorced     654
# Name: MaritalStatus, dtype: int64
# --------------------------------------------------
# No     2331
# Yes     816
# Name: OverTime, dtype: int64
# --------------------------------------------------
#
#
#
# 34    172
# 36    170
# 35    167
# 29    164
# 31    159
# 38    146
# 40    136
# 30    126
# 32    121
# 27    115
# 28    110
# 33    108
# 37    108
# 39     96
# 26     84
# 45     82
# 42     82
# 41     80
# 46     80
# 44     72
# 25     62
# 43     61
# 50     59
# 24     49
# 48     47
# 47     46
# 49     43
# 55     39
# 52     36
# 53     34
# 23     34
# 51     33
# 22     30
# 21     29
# 54     25
# 56     24
# 58     23
# 19     22
# 59     20
# 18     20
# 20     17
# 57      8
# 60      8
# Name: Age, dtype: int64
# --------------------------------------------------
# 1082    21
# 775     15
# 1329    15
# 465     15
# 827     14
#         ..
# 1207     1
# 1442     1
# 608      1
# 294      1
# 1023     1
# Name: DailyRate, Length: 901, dtype: int64
# --------------------------------------------------
# 2     489
# 1     445
# 9     186
# 10    185
# 8     184
# 3     179
# 7     175
# 5     139
# 6     137
# 4     128
# 16     64
# 11     61
# 15     56
# 24     56
# 18     56
# 29     54
# 25     51
# 23     51
# 20     50
# 28     49
# 26     49
# 19     49
# 17     46
# 14     43
# 12     38
# 21     36
# 22     35
# 13     35
# 27     21
# Name: DistanceFromHome, dtype: int64
# --------------------------------------------------
# 3     1254
# 4      862
# 2      586
# 1      352
# 5       92
# 15       1
# Name: Education, dtype: int64
# --------------------------------------------------
# 4    983
# 3    949
# 2    632
# 1    583
# Name: EnvironmentSatisfaction, dtype: int64
# --------------------------------------------------
# 42    69
# 84    69
# 66    68
# 96    66
# 72    62
#       ..
# 47    23
# 53    21
# 31    20
# 38    18
# 34    18
# Name: HourlyRate, Length: 71, dtype: int64
# --------------------------------------------------
# 3    1975
# 2     733
# 4     283
# 1     156
# Name: JobInvolvement, dtype: int64
# --------------------------------------------------
# 1    1198
# 2    1151
# 3     453
# 4     200
# 5     144
# 7       1
# Name: JobLevel, dtype: int64
# --------------------------------------------------
# 4    1020
# 3     958
# 1     599
# 2     570
# Name: JobSatisfaction, dtype: int64
# --------------------------------------------------
# 2559    12
# 2342    12
# 2911    11
# 5228    10
# 6811    10
#         ..
# 5715     1
# 3034     1
# 7596     1
# 2476     1
# 9936     1
# Name: MonthlyIncome, Length: 1383, dtype: int64
# --------------------------------------------------
# 4223     12
# 15891    10
# 9150     10
# 8952     10
# 11652     9
#          ..
# 2227      1
# 12740     1
# 13436     1
# 4345      1
# 3787      1
# Name: MonthlyRate, Length: 1447, dtype: int64
# --------------------------------------------------
# 1    1127
# 0     450
# 3     325
# 2     315
# 4     300
# 7     162
# 6     138
# 5     124
# 9     115
# 8      91
# Name: NumCompaniesWorked, dtype: int64
# --------------------------------------------------
# 13    476
# 14    459
# 11    447
# 12    433
# 15    225
# 18    186
# 17    174
# 19    155
# 16    152
# 22    113
# 20    110
# 21    102
# 23     50
# 24     37
# 25     28
# Name: PercentSalaryHike, dtype: int64
# --------------------------------------------------
# 3    2707
# 4     440
# Name: PerformanceRating, dtype: int64
# --------------------------------------------------
# 3    982
# 4    950
# 2    640
# 1    575
# Name: RelationshipSatisfaction, dtype: int64
# --------------------------------------------------
# 0    1363
# 1    1341
# 2     293
# 3     150
# Name: StockOptionLevel, dtype: int64
# --------------------------------------------------
# 10    456
# 6     281
# 8     219
# 9     210
# 7     185
# 1     184
# 5     182
# 4     140
# 12    102
# 15     93
# 3      90
# 13     80
# 16     77
# 21     67
# 17     67
# 11     64
# 14     62
# 18     62
# 2      61
# 20     59
# 22     46
# 19     44
# 23     42
# 24     36
# 28     31
# 26     30
# 25     29
# 0      24
# 31     18
# 29     18
# 33     15
# 30     14
# 27     14
# 32     11
# 34      9
# 36      8
# 37      6
# 35      4
# 40      3
# 38      3
# 41      1
# Name: TotalWorkingYears, dtype: int64
# --------------------------------------------------
# 2    1202
# 3    1117
# 4     245
# 5     241
# 1     134
# 0     104
# 6     104
# Name: TrainingTimesLastYear, dtype: int64
# --------------------------------------------------
# 3    1982
# 2     729
# 4     288
# 1     148
# Name: WorkLifeBalance, dtype: int64
# --------------------------------------------------
# 5     424
# 1     385
# 3     304
# 10    258
# 2     235
# 4     231
# 7     193
# 9     181
# 8     171
# 6     163
# 0      98
# 20     62
# 11     60
# 13     52
# 15     47
# 14     34
# 22     32
# 12     28
# 16     28
# 21     27
# 17     23
# 18     20
# 19     19
# 24     15
# 33     10
# 25      9
# 31      7
# 26      5
# 29      5
# 27      4
# 30      3
# 34      3
# 32      3
# 37      2
# 36      2
# 23      2
# 41      1
# 40      1
# Name: YearsAtCompany, dtype: int64
# --------------------------------------------------
# 2     787
# 0     551
# 7     485
# 3     301
# 4     229
# 8     192
# 9     144
# 1     100
# 6      77
# 5      70
# 10     57
# 11     38
# 13     28
# 14     25
# 12     21
# 16     13
# 15     13
# 17     10
# 18      6
# Name: YearsInCurrentRole, dtype: int64
# --------------------------------------------------
# 0     1307
# 1      764
# 2      307
# 7      165
# 4      139
# 3      105
# 5       86
# 6       68
# 11      55
# 8       33
# 9       32
# 15      25
# 13      18
# 12      18
# 14      15
# 10      10
# Name: YearsSinceLastPromotion, dtype: int64
# --------------------------------------------------
# 2     731
# 0     561
# 7     481
# 3     316
# 8     233
# 4     205
# 1     147
# 9     121
# 5      68
# 6      63
# 10     56
# 11     52
# 12     40
# 13     31
# 17     15
# 14     12
# 15     11
# 16      4
# Name: YearsWithCurrManager, dtype: int64
# --------------------------------------------------
# 0    2710
# 1     437
# Name: Attrition, dtype: int64
# --------------------------------------------------

# %%
selected_features = train.columns.tolist()[:-1]

target_col = 'Attrition'

ord_cat_features = ['BusinessTravel']
ord_cat_order = ['Non-Travel', 'Travel_Rarely', 'Travel_Frequently']

num_features = ['Education', 'JobInvolvement', 'PerformanceRating','RelationshipSatisfaction', 'WorkLifeBalance',
                'StockOptionLevel', 'JobLevel', 'JobSatisfaction', 'EnvironmentSatisfaction']

cat_features = ['Department', 'EducationField', 'Gender', 'MaritalStatus', 'OverTime', 'JobRole']

cont_features = ['MonthlyRate', 'MonthlyIncome', 'DailyRate', 'HourlyRate', 'Age', 'DistanceFromHome', 'TotalWorkingYears',
                 'YearsAtCompany', 'YearsInCurrentRole', 'YearsWithCurrManager', 'PercentSalaryHike', 'NumCompaniesWorked',
                 'TrainingTimesLastYear', 'YearsSinceLastPromotion']

comb_features = ord_cat_features + num_features + cat_features + cont_features

# %%
print(train[comb_features].shape, train.shape)

print(set(train[comb_features]) ^ set(train))
# Out:
# (3147, 30) (3147, 31)
# {'Attrition'}

# %%
# Processing 'train' data
train_df = train.copy()

train_df['IncomePerAge'] = train_df['MonthlyIncome'] / train_df['Age']
train_df["AgeRisk"] = (train_df["Age"] < 34).astype(int)
train_df["HourlyRateRisk"] = (train_df["HourlyRate"] < 60).astype(int)
train_df["DistanceRisk"] = (train_df["DistanceFromHome"] >= 20).astype(int)
train_df["ShortCompanyTenure"] = (train_df["YearsAtCompany"] < 4).astype(int)
train_df['NumCompaniesAdjusted'] = train_df['NumCompaniesWorked'].replace(0, 1)
train_df['AverageCompanyTenure'] = train_df["TotalWorkingYears"] / train_df["NumCompaniesAdjusted"]
train_df['JobHopperIndicator'] = ((train_df["NumCompaniesAdjusted"] > 2) & (train_df["AverageCompanyTenure"] < 2.0)).astype(int)
train_df["AttritionRiskScore"] = train_df["AgeRisk"] + train_df["HourlyRateRisk"] + train_df["DistanceRisk"] + train_df["ShortCompanyTenure"] + train_df['JobHopperIndicator']
train_df['IncomeToDailyRateRatio'] = train_df['MonthlyIncome'] / train_df['DailyRate']
train_df['TenureToAgeRatio'] = train_df['TotalWorkingYears'] / train_df['Age']
train_df['TotalSatisfaction'] = train_df['EnvironmentSatisfaction'] + train_df['JobSatisfaction'] + train_df['RelationshipSatisfaction']

train_df.loc[train_df['Education'] == 15, 'Education'] = 5
train_df.loc[train_df['JobLevel'] == 7, 'JobLevel'] = 5

# %%
# Processing 'test' data
test_df = test.copy()

test_df['IncomePerAge'] = test_df['MonthlyIncome'] / test_df['Age']
test_df["AgeRisk"] = (test_df["Age"] < 34).astype(int)
test_df["HourlyRateRisk"] = (test_df["HourlyRate"] < 60).astype(int)
test_df["DistanceRisk"] = (test_df["DistanceFromHome"] >= 20).astype(int)
test_df["ShortCompanyTenure"] = (test_df["YearsAtCompany"] < 4).astype(int)
test_df['NumCompaniesAdjusted'] = test_df['NumCompaniesWorked'].replace(0, 1)
test_df['AverageCompanyTenure'] = test_df["TotalWorkingYears"] / test_df["NumCompaniesAdjusted"]
test_df['JobHopperIndicator'] = ((test_df["NumCompaniesAdjusted"] > 2) & (test_df["AverageCompanyTenure"] < 2.0)).astype(int)
test_df["AttritionRiskScore"] = test_df["AgeRisk"] + test_df["HourlyRateRisk"] + test_df["DistanceRisk"] + test_df["ShortCompanyTenure"] + test_df['JobHopperIndicator']
test_df['IncomeToDailyRateRatio'] = test_df['MonthlyIncome'] / test_df['DailyRate']
test_df['TenureToAgeRatio'] = test_df['TotalWorkingYears'] / test_df['Age']
test_df['TotalSatisfaction'] = test_df['EnvironmentSatisfaction'] + test_df['JobSatisfaction'] + test_df['RelationshipSatisfaction']

test_df.loc[test_df['Education'] == 15, 'Education'] = 5
test_df.loc[test_df['JobLevel'] == 7, 'JobLevel'] = 5

# %%
display(train_df.describe(), test_df.describe())
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  3147.000000  3147.000000       3147.000000  3147.000000
# mean     36.451223   850.586273          8.921513     2.923101
# std       8.815861   390.859919          7.961278     1.010025
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   543.000000          2.000000     2.000000
# 50%      35.000000   852.000000          7.000000     3.000000
# 75%      42.000000  1198.500000         13.000000     4.000000
# max      60.000000  3921.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              3147.000000  3147.000000     3147.000000  3147.000000
# mean                  2.741023    66.907531        2.757865     2.028599
# std                   1.089733    19.877918        0.680183     1.092281
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    50.000000        2.000000     1.000000
# 50%                   3.000000    67.000000        3.000000     2.000000
# 75%                   4.000000    84.000000        3.000000     3.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count      3147.000000    3147.000000   3147.000000         3147.000000
# mean          2.762313    6339.397521  14556.604067            2.630124
# std           1.100224    4610.584686   7117.334257            2.488848
# min           1.000000    1009.000000    636.000000            0.000000
# 25%           2.000000    2888.000000   8306.000000            1.000000
# 50%           3.000000    4877.000000  14908.000000            1.000000
# 75%           4.000000    7725.000000  20744.500000            4.000000
# max           4.000000   19999.000000  26999.000000            9.000000
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count        3147.000000        3147.000000               3147.000000
# mean           15.046393           3.139816                  2.733079
# std             3.537252           0.346851                  1.079454
# min            11.000000           3.000000                  1.000000
# 25%            12.000000           3.000000                  2.000000
# 50%            14.000000           3.000000                  3.000000
# 75%            17.000000           3.000000                  4.000000
# max            25.000000           4.000000                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       3147.000000        3147.000000            3147.000000
# mean           0.755323          10.975850               2.763902
# std            0.810688           7.509438               1.214918
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000           9.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          41.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      3147.000000     3147.000000         3147.000000
# mean          2.765809        6.900858            4.183985
# std           0.675707        5.998015            3.601691
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       41.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager    Attrition  \
# count              3147.000000           3147.000000  3147.000000
# mean                  2.076263              4.156975     0.138862
# std                   3.130744              3.572003     0.345858
# min                   0.000000              0.000000     0.000000
# 25%                   0.000000              2.000000     0.000000
# 50%                   1.000000              3.000000     0.000000
# 75%                   2.000000              7.000000     0.000000
# max                  15.000000             17.000000     1.000000
#
#        IncomePerAge      AgeRisk  HourlyRateRisk  DistanceRisk  \
# count   3147.000000  3147.000000     3147.000000   3147.000000
# mean     169.249028     0.397204        0.385764      0.143629
# std      101.523449     0.489397        0.486853      0.350769
# min       26.541667     0.000000        0.000000      0.000000
# 25%       93.027778     0.000000        0.000000      0.000000
# 50%      139.766667     0.000000        0.000000      0.000000
# 75%      215.508798     1.000000        1.000000      0.000000
# max      660.956522     1.000000        1.000000      1.000000
#
#        ShortCompanyTenure  NumCompaniesAdjusted  AverageCompanyTenure  \
# count         3147.000000           3147.000000           3147.000000
000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  IncomePerAge  \
# count              1119.000000           1119.000000   1119.000000
# mean                  2.076854              4.308311    166.889923
# std                   3.278022              3.729282    104.216139
# min                   0.000000              0.000000     24.017241
# 25%                   0.000000              2.000000     90.738791
# 50%                   1.000000              3.000000    136.846154
# 75%                   2.000000              7.000000    205.236111
# max                  15.000000             17.000000    733.000000
#
#            AgeRisk  HourlyRateRisk  DistanceRisk  ShortCompanyTenure  \
# count  1119.000000     1119.000000   1119.000000         1119.000000
# mean      0.399464        0.356568      0.132261            0.324397
# std       0.490007        0.479200      0.338926            0.468358
# min       0.000000        0.000000      0.000000            0.000000
# 25%       0.000000        0.000000      0.000000            0.000000
# 50%       0.000000        0.000000      0.000000            0.000000
# 75%       1.000000        1.000000      0.000000            1.000000
# max       1.000000        1.000000      1.000000            1.000000
#
#        NumCompaniesAdjusted  AverageCompanyTenure  JobHopperIndicator  \
# count           1119.000000           1119.000000         1119.000000
# mean               2.685433              6.280057            0.147453
# std                2.335706              5.695892            0.354716
# min                1.000000              0.000000            0.000000
# 25%                1.000000              2.208333            0.000000
# 50%                1.000000              5.000000            0.000000
# 75%                4.000000              9.000000            0.000000
# max               17.000000             37.000000            1.000000
#
#        AttritionRiskScore  IncomeToDailyRateRatio  TenureToAgeRatio  \
# count         1119.000000             1119.000000       1119.000000
# mean             1.360143               10.311969          0.281864
# std              0.989146               43.343659          0.153674
# min              0.000000                0.349135          0.000000
# 25%              1.000000                3.528986          0.176471
# 50%              1.000000                5.849921          0.259259
# 75%              2.000000               10.430198          0.373775
# max              5.000000             1416.666667          1.027778
#
#        TotalSatisfaction
# count        1119.000000
# mean            8.226095
# std             1.903720
# min             3.000000
# 25%             7.000000
# 50%             8.000000
# 75%            10.000000
# max            12.000000

# %%
train_df.shape, test_df.shape
# Out:
# ((3147, 43), (1119, 42))

# %%
data = [train_df, test_df]
for i in data:
    print(i.isnull().any().sum())
    print('-' *100)
# Out:
# 0
# ----------------------------------------------------------------------------------------------------
# 0
# ----------------------------------------------------------------------------------------------------

# %%
data = [train_df, test_df]
for i in data:
    print(i.info())
    print('-' *100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3147 non-null   int64
#  1   BusinessTravel            3147 non-null   object
#  2   DailyRate                 3147 non-null   int64
#  3   Department                3147 non-null   object
#  4   DistanceFromHome          3147 non-null   int64
#  5   Education                 3147 non-null   int64
#  6   EducationField            3147 non-null   object
#  7   EnvironmentSatisfaction   3147 non-null   int64
#  8   Gender                    3147 non-null   object
#  9   HourlyRate                3147 non-null   int64
#  10  JobInvolvement            3147 non-null   int64
#  11  JobLevel                  3147 non-null   int64
#  12  JobRole                   3147 non-null   object
#  13  JobSatisfaction           3147 non-null   int64
#  14  MaritalStatus             3147 non-null   object
#  15  MonthlyIncome             3147 non-null   int64
#  16  MonthlyRate               3147 non-null   int64
#  17  NumCompaniesWorked        3147 non-null   int64
#  18  OverTime                  3147 non-null   object
#  19  PercentSalaryHike         3147 non-null   int64
#  20  PerformanceRating         3147 non-null   int64
#  21  RelationshipSatisfaction  3147 non-null   int64
#  22  StockOptionLevel          3147 non-null   int64
#  23  TotalWorkingYears         3147 non-null   int64
#  24  TrainingTimesLastYear     3147 non-null   int64
#  25  WorkLifeBalance           3147 non-null   int64
#  26  YearsAtCompany            3147 non-null   int64
 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition', 'IncomePerAge', 'AgeRisk', 'HourlyRateRisk', 'DistanceRisk', 'ShortCompanyTenure', 'NumCompaniesAdjusted', 'AverageCompanyTenure', 'JobHopperIndicator', 'AttritionRiskScore', 'IncomeToDailyRateRatio', 'TenureToAgeRatio', 'TotalSatisfaction']
#
# ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'IncomePerAge', 'AgeRisk', 'HourlyRateRisk', 'DistanceRisk', 'ShortCompanyTenure', 'NumCompaniesAdjusted', 'AverageCompanyTenure', 'JobHopperIndicator', 'AttritionRiskScore', 'IncomeToDailyRateRatio', 'TenureToAgeRatio', 'TotalSatisfaction']

# %%
# encoding ordinal features

from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[ord_cat_order], dtype=int)
train_df[['BusinessTravel']] = encoder.fit_transform(train_df[['BusinessTravel']])
test_df[['BusinessTravel']] = encoder.transform(test_df[['BusinessTravel']])

# %%
# scaling continuous features

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_df[cont_features] = scaler.fit_transform(train_df[cont_features])
test_df[cont_features] = scaler.transform(test_df[cont_features])

# %%
set(train_df) ^ set(train)
# Out:
# {'AgeRisk',
#  'AttritionRiskScore',
#  'AverageCompanyTenure',
#  'DistanceRisk',
#  'HourlyRateRisk',
#  'IncomePerAge',
#  'IncomeToDailyRateRatio',
#  'JobHopperIndicator',
#  'NumCompaniesAdjusted',
#  'ShortCompanyTenure',
#  'TenureToAgeRatio',
#  'TotalSatisfaction'}

# %%
from sklearn.preprocessing import OneHotEncoder

encoded_features = []

for feature in cat_features:
    ohe = OneHotEncoder(sparse=False, drop='first')
    train_feature_df = pd.DataFrame(train_df[feature])
    test_feature_df = pd.DataFrame(test_df[feature])

    merged_feature_df = pd.concat([train_feature_df, test_feature_df], ignore_index=True)
    ohe.fit(merged_feature_df)

    new_encoded_columns = [f"{feature}_{val}_ohe" for val in ohe.categories_[0][1:]]
    encoded_features.extend(new_encoded_columns)

    train_df_encoded_columns = pd.DataFrame(ohe.transform(train_feature_df), columns=new_encoded_columns, dtype='int')
    test_df_encoded_columns = pd.DataFrame(ohe.transform(test_feature_df), columns=new_encoded_columns, dtype='int')

    for column in new_encoded_columns:
        train_df[column] = train_df_encoded_columns[column]
        test_df[column] = test_df_encoded_columns[column]
        selected_features.append(column)

for feature in cat_features:
    if feature in selected_features:
        selected_features.remove(feature)

train_df.drop(cat_features, axis=1, inplace=True)
test_df.drop(cat_features, axis=1, inplace=True)

cat_features = encoded_features

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### CatBoost

# %%
train_df.shape, test_df.shape
# Out:
# ((3147, 43), (1119, 42))

# %%
X = train_df.drop(['Attrition'], axis=1)
y = train_df['Attrition']

# %%
# !pip install catboost
# !pip install shap
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2
# Collecting shap
#   Downloading shap-0.44.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (533 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.5/533.5 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.44.0 slicer-0.0.7

# %%
import catboost as cb
import catboost.utils as cbu

import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from hyperopt import fmin, tpe, hp, STATUS_OK
import random

# %%
# hyperparams
space = {
    # 'n_estimators': hp.quniform('n_estimators', 50, 550, 50),
    # 'colsample_bytree': hp.uniform('colsample_bytree', 0.1, 0.9),
    # 'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
    # 'max_depth': hp.quniform('max_depth', 2, 8, 1),
    # 'min_split_gain': hp.uniform('min_split_gain', 0.1, 0.5),
    # 'num_leaves': hp.quniform('num_leaves', 30, 150, 1),
    # 'reg_alpha': hp.uniform('reg_alpha', 0, 1),
    # 'reg_lambda': hp.uniform('reg_lambda', 0, 1),
    # 'subsample': hp.uniform('subsample', 0.1, 0.9),

    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
    'depth': hp.uniform('depth', 2, 9),
    'l2_leaf_reg': hp.quniform('l2_leaf_reg', 1.5, 5, 0.5),
    'iterations': hp.quniform('iterations', 100, 500, 50),
    'min_child_samples': hp.quniform('min_child_samples', 5, 10, 1),
    'subsample': hp.uniform('subsample', 0.5, 1.0),
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1.0, 3.0),
}

# Objective function
def objective(params):
    # Convert certain hyperparameters to integers
    params.update({key: int(value) if key in ('iterations', 'depth', 'min_child_samples') else value for key, value in params.items()})

    skf_seed = random.randint(0, 2023)
    skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=skf_seed)

    cb_model = cb.CatBoostClassifier(**params, random_state=skf_seed, eval_metric='AUC', cat_features=cat_features)

    auc_scores = [roc_auc_score(y.iloc[test_index], cb_model.fit(X.iloc[train_index], y.iloc[train_index],
                                                                  eval_set=[(X.iloc[test_index], y.iloc[test_index])]
                                                                  ).predict_proba(X.iloc[test_index])[:, 1])
                  for train_index, test_index in skf.split(X, y)]

    mean_auc = np.mean(auc_scores)
    loss = 1 - mean_auc

    return {'loss': loss, 'status': STATUS_OK, 'params': params}

# Hyperparameter optimization
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100)

# Extract the best parameters
best_params = {key: int(value) if key in ('iterations', 'depth', 'min_child_samples') else value for key, value
               in best.items() if key not in ('loss', 'status')}

random.seed(20181224)
skf_seed = random.randint(0, 2023)
# Initialize CatBoost classifier with best parameters
cb_model = cb.CatBoostClassifier(**best_params, random_state=skf_seed, eval_metric='AUC', cat_features=cat_features)

# Train and predict using StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=skf_seed)
roc_val = [roc_auc_score(y_val_fold, cb_model.fit(train_fold, y_fold, eval_set=[(val_fold, y_val_fold)])
                          .predict_proba(val_fold)[:, 1])
           for (train_index, test_index), (train_fold, val_fold, y_fold, y_val_fold) in
           zip(skf.split(X, y), [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for
                                 train_index, test_index in skf.split(X, y)])]

roc_train = [roc_auc_score(y_fold, cb_model.fit(train_fold, y_fold, eval_set=[(val_fold, y_val_fold)])
                             .predict_proba(train_fold)[:, 1])
             for (train_index, test_index), (train_fold, val_fold, y_fold, y_val_fold) in
             zip(skf.split(X, y), [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for
                                   train_index, test_index in skf.split(X, y)])]

# Store predictions on the testing dataset test_df
predictions_df = pd.DataFrame()

for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    train_fold, val_fold = X.iloc[train_index], X.iloc[test_index]
    y_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]

    # Fit the model on the training data
    cb_model.fit(train_fold, y_fold, eval_set=[(val_fold, y_val_fold)])

    # Make predictions on the testing dataset
    predictions_df[i] = cb_model.predict_proba(test_df)[:, 1]

print("roc_val:", roc_val)
print("Mean roc_val:", np.mean(roc_val))
print("\nroc_train:", roc_train)
print("Mean roc_train:", np.mean(roc_train))
print("\nBest Parameters:", best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# 330:	test: 0.8365481	best: 0.8407414 (212)	total: 2.16s	remaining: 124ms
# 331:	test: 0.8376384	best: 0.8407414 (212)	total: 2.16s	remaining: 117ms
# 332:	test: 0.8368836	best: 0.8407414 (212)	total: 2.17s	remaining: 111ms
# 333:	test: 0.8366320	best: 0.8407414 (212)	total: 2.17s	remaining: 104ms
# 334:	test: 0.8365481	best: 0.8407414 (212)	total: 2.18s	remaining: 97.6ms
# 335:	test: 0.8364643	best: 0.8407414 (212)	total: 2.19s	remaining: 91.1ms
# 336:	test: 0.8361288	best: 0.8407414 (212)	total: 2.19s	remaining: 84.6ms
# 337:	test: 0.8362965	best: 0.8407414 (212)	total: 2.2s	remaining: 78ms
# 338:	test: 0.8371352	best: 0.8407414 (212)	total: 2.2s	remaining: 71.5ms
# 339:	test: 0.8374706	best: 0.8407414 (212)	total: 2.21s	remaining: 65ms
# 340:	test: 0.8376384	best: 0.8407414 (212)	total: 2.21s	remaining: 58.5ms
# 341:	test: 0.8373868	best: 0.8407414 (212)	total: 2.22s	remaining: 51.9ms
# 342:	test: 0.8369675	best: 0.8407414 (212)	total: 2.23s	remaining: 45.4ms
# 343:	test: 0.8378900	best: 0.8407414 (212)	total: 2.23s	remaining: 38.9ms
# 344:	test: 0.8379738	best: 0.8407414 (212)	total: 2.24s	remaining: 32.4ms
# 345:	test: 0.8379738	best: 0.8407414 (212)	total: 2.24s	remaining: 25.9ms
# 346:	test: 0.8362127	best: 0.8407414 (212)	total: 2.25s	remaining: 19.4ms
# 347:	test: 0.8368836	best: 0.8407414 (212)	total: 2.25s	remaining: 13ms
# 348:	test: 0.8368836	best: 0.8407414 (212)	total: 2.26s	remaining: 6.48ms
# 349:	test: 0.8366320	best: 0.8407414 (212)	total: 2.27s	remaining: 0us
#
# bestTest = 0.840741362
# bestIteration = 212
#
# Shrink model to first 213 iterations.
# 0:	test: 0.6285642	best: 0.6285642 (0)	total: 5.89ms	remaining: 2.06s
# 1:	test: 0.6722576	best: 0.6722576 (1)	total: 11.8ms	remaining: 2.06s
# 2:	test: 0.6928044	best: 0.6928044 (2)	total: 18.3ms	remaining: 2.12s
# 3:	test: 0.7942804	best: 0.7942804 (3)	total: 24.2ms	remaining: 2.1s
# 4:	test: 0.8136951	best: 0.8136951 (4)	total: 29.8ms	remaining: 2.06s
# 5:	test: 0.8312647	best: 0.8312647 (5)	total: 35.1ms	remaining: 2.01s
# 6:	test: 0.8444733	best: 0.8444733 (6)	total: 40.9ms	remaining: 2.01s
# 7:	test: 0.8415800	best: 0.8444733 (6)	total: 47ms	remaining: 2.01s
# 8:	test: 0.8390641	best: 0.8444733 (6)	total: 52.8ms	remaining: 2s
# 9:	test: 0.8399866	best: 0.8444733 (6)	total: 59.1ms	remaining: 2.01s
# 10:	test: 0.8481214	best: 0.8481214 (10)	total: 65.3ms	remaining: 2.01s
# 11:	test: 0.8486246	best: 0.8486246 (11)	total: 71.3ms	remaining: 2.01s
# 12:	test: 0.8558370	best: 0.8558370 (12)	total: 77.4ms	remaining: 2.01s
# 13:	test: 0.8546629	best: 0.8558370 (12)	total: 83.3ms	remaining: 2s
# 14:	test: 0.8595270	best: 0.8595270 (14)	total: 88.9ms	remaining: 1.99s
# 15:	test: 0.8622945	best: 0.8622945 (15)	total: 94.4ms	remaining: 1.97s
# 16:	test: 0.8645589	best: 0.8645589 (16)	total: 101ms	remaining: 1.97s
# 17:	test: 0.8681650	best: 0.8681650 (17)	total: 107ms	remaining: 1.97s
# 18:	test: 0.8670748	best: 0.8681650 (17)	total: 113ms	remaining: 1.96s
# 19:	test: 0.8669071	best: 0.8681650 (17)	total: 119ms	remaining: 1.96s
# 20:	test: 0.8667393	best: 0.8681650 (17)	total: 124ms	remaining: 1.95s
# 21:	test: 0.8657330	best: 0.8681650 (17)	total: 130ms	remaining: 1.94s
# 22:	test: 0.8698423	best: 0.8698423 (22)	total: 136ms	remaining: 1.93s
# 23:	test: 0.8726937	best: 0.8726937 (23)	total: 143ms	remaining: 1.95s
# 24:	test: 0.8714358	best: 0.8726937 (23)	total: 149ms	remaining: 1.93s
# 25:	test: 0.8677457	best: 0.8726937 (23)	total: 154ms	remaining: 1.92s
# 26:	test: 0.8690037	best: 0.8726937 (23)	total: 159ms	remaining: 1.91s
# 27:	test: 0.8682489	best: 0.8726937 (23)	total: 165ms	remaining: 1.89s
# 28:	test: 0.8698423	best: 0.8726937 (23)	total: 170ms	remaining: 1.88s
# 29:	test: 0.8705971	best: 0.8726937 (23)	total: 175ms	remaining: 1.87s
# 30:	test: 0.8705133	best: 0.8726937 (23)	total: 180ms	remaining: 1.86s
# 31:	test: 0.8709326	best: 0.8726937 (23)	total: 186ms	remaining: 1.84s
# 32:	test: 0.8738678	best: 0.8738678 (32)	total: 191ms	remaining: 1.83s
# 33:	test: 0.8745387	best: 0.8745387 (33)	total: 198ms	remaining: 1.84s
# 34:	test: 0.8738678	best: 0.8745387 (33)	total: 209ms	remaining: 1.88s
# 35:	test: 0.8741194	best: 0.8745387 (33)	total: 218ms	remaining: 1.9s
# 36:	test: 0.8747903	best: 0.8747903 (36)	total: 224ms	remaining: 1.9s
# 37:	test: 0.8756290	best: 0.8756290 (37)	total: 231ms	remaining: 1.89s
# 38:	test: 0.8757967	best: 0.8757967 (38)	total: 236ms	remaining: 1.88s
# 39:	test: 0.8753774	best: 0.8757967 (38)	total: 241ms	remaining: 1.87s
# 40:	test: 0.8770547	best: 0.8770547 (40)	total: 247ms	remaining: 1.86s
# 41:	test: 0.8795706	best: 0.8795706 (41)	total: 253ms	remaining: 1.85s
# 42:	test: 0.8808286	best: 0.8808286 (42)	total: 258ms	remaining: 1.84s
# 43:	test: 0.8823381	best: 0.8823381 (43)	total: 264ms	remaining: 1.84s
# 44:	test: 0.8827575	best: 0.8827575 (44)	total: 270ms	remaining: 1.83s
# 115:	test: 0.8113790	best: 0.8136960 (114)	total: 772ms	remaining: 1.56s
# 116:	test: 0.8108642	best: 0.8136960 (114)	total: 778ms	remaining: 1.55s
# 117:	test: 0.8104351	best: 0.8136960 (114)	total: 784ms	remaining: 1.54s
# 118:	test: 0.8108642	best: 0.8136960 (114)	total: 790ms	remaining: 1.53s
# 119:	test: 0.8137819	best: 0.8137819 (119)	total: 796ms	remaining: 1.52s
# 120:	test: 0.8140393	best: 0.8140393 (120)	total: 802ms	remaining: 1.52s
# 121:	test: 0.8155840	best: 0.8155840 (121)	total: 811ms	remaining: 1.51s
# 122:	test: 0.8154123	best: 0.8155840 (121)	total: 822ms	remaining: 1.52s
# 123:	test: 0.8174719	best: 0.8174719 (123)	total: 828ms	remaining: 1.51s
# 124:	test: 0.8165279	best: 0.8174719 (123)	total: 835ms	remaining: 1.5s
# 125:	test: 0.8167854	best: 0.8174719 (123)	total: 841ms	remaining: 1.49s
# 126:	test: 0.8171286	best: 0.8174719 (123)	total: 847ms	remaining: 1.49s
# 127:	test: 0.8167854	best: 0.8174719 (123)	total: 853ms	remaining: 1.48s
# 128:	test: 0.8176435	best: 0.8176435 (128)	total: 860ms	remaining: 1.47s
# 129:	test: 0.8165279	best: 0.8176435 (128)	total: 866ms	remaining: 1.46s
# 130:	test: 0.8163563	best: 0.8176435 (128)	total: 872ms	remaining: 1.46s
# 131:	test: 0.8161847	best: 0.8176435 (128)	total: 878ms	remaining: 1.45s
# 132:	test: 0.8166137	best: 0.8176435 (128)	total: 885ms	remaining: 1.44s
# 133:	test: 0.8173861	best: 0.8176435 (128)	total: 891ms	remaining: 1.44s
# 134:	test: 0.8174719	best: 0.8176435 (128)	total: 898ms	remaining: 1.43s
# 135:	test: 0.8173861	best: 0.8176435 (128)	total: 904ms	remaining: 1.42s
# 136:	test: 0.8178152	best: 0.8178152 (136)	total: 910ms	remaining: 1.42s
# 137:	test: 0.8206470	best: 0.8206470 (137)	total: 917ms	remaining: 1.41s
# 138:	test: 0.8204754	best: 0.8206470 (137)	total: 923ms	remaining: 1.4s
# 139:	test: 0.8212477	best: 0.8212477 (139)	total: 930ms	remaining: 1.39s
# 140:	test: 0.8211619	best: 0.8212477 (139)	total: 936ms	remaining: 1.39s
# 141:	test: 0.8203896	best: 0.8212477 (139)	total: 943ms	remaining: 1.38s
# 142:	test: 0.8194456	best: 0.8212477 (139)	total: 949ms	remaining: 1.37s
# 143:	test: 0.8195315	best: 0.8212477 (139)	total: 956ms	remaining: 1.37s
# 144:	test: 0.8196173	best: 0.8212477 (139)	total: 962ms	remaining: 1.36s
# 145:	test: 0.8199605	best: 0.8212477 (139)	total: 969ms	remaining: 1.35s
# 146:	test: 0.8185017	best: 0.8212477 (139)	total: 975ms	remaining: 1.35s
# 147:	test: 0.8199605	best: 0.8212477 (139)	total: 981ms	remaining: 1.34s
# 148:	test: 0.8209903	best: 0.8212477 (139)	total: 987ms	remaining: 1.33s
# 149:	test: 0.8201322	best: 0.8212477 (139)	total: 993ms	remaining: 1.32s
# 150:	test: 0.8202180	best: 0.8212477 (139)	total: 999ms	remaining: 1.32s
# 151:	test: 0.8196173	best: 0.8212477 (139)	total: 1.01s	remaining: 1.31s
# 152:	test: 0.8200463	best: 0.8212477 (139)	total: 1.02s	remaining: 1.32s
# 153:	test: 0.8200463	best: 0.8212477 (139)	total: 1.03s	remaining: 1.31s
# 154:	test: 0.8203038	best: 0.8212477 (139)	total: 1.04s	remaining: 1.3s
# 155:	test: 0.8200463	best: 0.8212477 (139)	total: 1.04s	remaining: 1.3s
# 156:	test: 0.8199605	best: 0.8212477 (139)	total: 1.05s	remaining: 1.29s
# 157:	test: 0.8191024	best: 0.8212477 (139)	total: 1.06s	remaining: 1.28s
# 158:	test: 0.8193598	best: 0.8212477 (139)	total: 1.06s	remaining: 1.28s
# 159:	test: 0.8185875	best: 0.8212477 (139)	total: 1.07s	remaining: 1.27s
# 160:	test: 0.8187591	best: 0.8212477 (139)	total: 1.07s	remaining: 1.26s
# 161:	test: 0.8185875	best: 0.8212477 (139)	total: 1.08s	remaining: 1.25s
# 162:	test: 0.8188449	best: 0.8212477 (139)	total: 1.08s	remaining: 1.25s
# 163:	test: 0.8179868	best: 0.8212477 (139)	total: 1.09s	remaining: 1.24s
# 164:	test: 0.8186733	best: 0.8212477 (139)	total: 1.1s	remaining: 1.23s
# 165:	test: 0.8188449	best: 0.8212477 (139)	total: 1.11s	remaining: 1.23s
# 166:	test: 0.8190166	best: 0.8212477 (139)	total: 1.11s	remaining: 1.22s
# 167:	test: 0.8182442	best: 0.8212477 (139)	total: 1.12s	remaining: 1.21s
# 168:	test: 0.8179010	best: 0.8212477 (139)	total: 1.13s	remaining: 1.21s
# 169:	test: 0.8178152	best: 0.8212477 (139)	total: 1.13s	remaining: 1.2s
# 170:	test: 0.8179010	best: 0.8212477 (139)	total: 1.14s	remaining: 1.19s
# 171:	test: 0.8181584	best: 0.8212477 (139)	total: 1.15s	remaining: 1.19s
# 172:	test: 0.8184159	best: 0.8212477 (139)	total: 1.15s	remaining: 1.18s
# 173:	test: 0.8185875	best: 0.8212477 (139)	total: 1.16s	remaining: 1.17s
# 174:	test: 0.8194456	best: 0.8212477 (139)	total: 1.16s	remaining: 1.16s
# 175:	test: 0.8197031	best: 0.8212477 (139)	total: 1.17s	remaining: 1.16s
# 176:	test: 0.8203896	best: 0.8212477 (139)	total: 1.18s	remaining: 1.15s
# 177:	test: 0.8210761	best: 0.8212477 (139)	total: 1.19s	remaining: 1.15s
# 178:	test: 0.8184159	best: 0.8212477 (139)	total: 1.19s	remaining: 1.14s
# 179:	test: 0.8182442	best: 0.8212477 (139)	total: 1.2s	remaining: 1.13s
# 180:	test: 0.8191024	best: 0.8212477 (139)	total: 1.21s	remaining: 1.13s
# 181:	test: 0.8191024	best: 0.8212477 (139)	total: 1.22s	remaining: 1.13s
# 182:	test: 0.8193598	best: 0.8212477 (139)	total: 1.23s	remaining: 1.12s
# 183:	test: 0.8191024	best: 0.8212477 (139)	total: 1.24s	remaining: 1.11s
# 184:	test: 0.8178152	best: 0.8212477 (139)	total: 1.24s	remaining: 1.11s
# 346:	test: 0.7879516	best: 0.8413284 (19)	total: 3.64s	remaining: 31.4ms
# 347:	test: 0.7872651	best: 0.8413284 (19)	total: 3.66s	remaining: 21ms
# 348:	test: 0.7864069	best: 0.8413284 (19)	total: 3.67s	remaining: 10.5ms
# 349:	test: 0.7880374	best: 0.8413284 (19)	total: 3.69s	remaining: 0us
#
# bestTest = 0.8413284133
# bestIteration = 19
#
# Shrink model to first 20 iterations.
# roc_val: [0.8600301912110031, 0.8465280107346528, 0.8947500838644751, 0.8305937604830593, 0.8959241865145924, 0.8407413619590741, 0.8907245890640725, 0.8226207843473785, 0.8504247833176005, 0.8413284132841329]
# Mean roc_val: 0.8573666164780042
#
# roc_train: [0.9302742645747067, 0.917236551500375, 0.9245310773718425, 0.9137509950163114, 0.8973205762591976, 0.9759892000955632, 0.9542266415030561, 0.9872076639548121, 0.9943598420755781, 0.8682143801133444]
# Mean roc_train: 0.9363111192464786
#
# Best Parameters: {'depth': 4, 'iterations': 350, 'l2_leaf_reg': 4.5, 'learning_rate': 0.13202264372559647, 'min_child_samples': 10, 'scale_pos_weight': 1.3164712349558514, 'subsample': 0.5373554575981913}

# %%
print("roc_val:", roc_val)
print("Mean roc_val:", np.mean(roc_val))
print("\nroc_train:", roc_train)
print("Mean roc_train:", np.mean(roc_train))
print("\nBest Parameters:", best_params)
# Out:
# roc_val: [0.8600301912110031, 0.8465280107346528, 0.8947500838644751, 0.8305937604830593, 0.8959241865145924, 0.8407413619590741, 0.8907245890640725, 0.8226207843473785, 0.8504247833176005, 0.8413284132841329]
# Mean roc_val: 0.8573666164780042
#
# roc_train: [0.9302742645747067, 0.917236551500375, 0.9245310773718425, 0.9137509950163114, 0.8973205762591976, 0.9759892000955632, 0.9542266415030561, 0.9872076639548121, 0.9943598420755781, 0.8682143801133444]
# Mean roc_train: 0.9363111192464786
#
# Best Parameters: {'depth': 4, 'iterations': 350, 'l2_leaf_reg': 4.5, 'learning_rate': 0.13202264372559647, 'min_child_samples': 10, 'scale_pos_weight': 1.3164712349558514, 'subsample': 0.5373554575981913}

# %% [markdown]
# roc_val: [0.8600301912110031, 0.8465280107346528, 0.8947500838644751, 0.8305937604830593, 0.8959241865145924, 0.8407413619590741, 0.8907245890640725, 0.8226207843473785, 0.8504247833176005, 0.8413284132841329]
# Mean roc_val: 0.8573666164780042
#
# roc_train: [0.9302742645747067, 0.917236551500375, 0.9245310773718425, 0.9137509950163114, 0.8973205762591976, 0.9759892000955632, 0.9542266415030561, 0.9872076639548121, 0.9943598420755781, 0.8682143801133444]
# Mean roc_train: 0.9363111192464786
#
# Best Parameters: {'depth': 4, 'iterations': 350, 'l2_leaf_reg': 4.5, 'learning_rate': 0.13202264372559647, 'min_child_samples': 10, 'scale_pos_weight': 1.3164712349558514, 'subsample': 0.5373554575981913}

# %%
# make submissions

test_ = pd.read_csv('/content/drive/MyDrive/Datasets/test.csv')
predictions_cb=predictions_df.min(axis=1)
sub=pd.DataFrame({"id":test_["id"],"Attrition":predictions_cb}).set_index("id")
sub.to_csv("sub_cv.csv")
