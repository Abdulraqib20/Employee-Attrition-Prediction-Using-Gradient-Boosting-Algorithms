# %%
import pandas as pd
pd.set_option('display.max_columns', None) # display all columns
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')

# Setting Custom colors
my_colors = ["#ff6e54", "#ffa600", "#ff2e63", "#a3f7bf", "#9378ff", "#56e39f", "#ff67ab", "#5e2ca5", "#ffd166", "#00b4d8", "#4ecdc4", "#f8edeb"]
my_palette = sns.color_palette(my_colors) # Create a seaborn palette object
sns.set_palette(my_palette)  # Use the custom palette with a seaborn function
from matplotlib.colors import ListedColormap
colors = ['#ffc3a0', '#ffafcc', '#bde0fe', '#ffabab']
my_cmap = sns.color_palette(colors)
cmap = ListedColormap(colors)

import warnings
warnings.filterwarnings(action='ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv('/content/drive/MyDrive/Datasets/train.csv')
test = pd.read_csv('/content/drive/MyDrive/Datasets/test.csv')
add_train = pd.read_csv('/content/drive/MyDrive/Datasets/WA_Fn-UseC_-HR-Employee-Attrition.csv')

display(train.head(), test.head(), add_train.head())
# Out:
#    id  Age     BusinessTravel  DailyRate              Department  \
# 0   0   36  Travel_Frequently        599  Research & Development
# 1   1   35      Travel_Rarely        921                   Sales
# 2   2   32      Travel_Rarely        718                   Sales
# 3   3   38      Travel_Rarely       1488  Research & Development
# 4   4   50      Travel_Rarely       1017  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                24          3        Medical              1
# 1                 8          3          Other              1
# 2                26          3      Marketing              1
# 3                 2          3        Medical              1
# 4                 5          4        Medical              1
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4    Male          42               3         1
# 1                        1    Male          46               3         1
# 2                        3    Male          80               3         2
# 3                        3  Female          40               3         2
# 4                        2  Female          37               3         5
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                4       Married           2596
# 1       Sales Representative                1       Married           2899
# 2            Sales Executive                4      Divorced           4627
# 3  Healthcare Representative                1       Married           5347
# 4                    Manager                1        Single          19033
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0         5099                   1      Y      Yes                 13
# 1        10778                   1      Y       No                 17
# 2        16495                   0      Y       No                 17
# 3        13384                   3      Y       No                 14
# 4        19805                   1      Y      Yes                 13
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         2             80
# 1                  3                         4             80
# 2                  3                         4             80
# 3                  3                         3             80
# 4                  3                         3             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 1                 10                      2
# 1                 1                  4                      3
# 2                 2                  4                      3
# 3                 0                 15                      1
# 4                 0                 31                      0
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                3              10                   0
# 1                3               4                   2
# 2                3               3                   2
# 3                1               6                   0
# 4                3              31                  14
#
#    YearsSinceLastPromotion  YearsWithCurrManager  Attrition
# 0                        7                     8          0
# 1                        0                     3          0
# 2                        1                     2          0
# 3                        0                     2          0
# 4                        4                    10          1
#      id  Age     BusinessTravel  DailyRate              Department  \
# 0  1677   19         Non-Travel        992  Research & Development
# 1  1678   45      Travel_Rarely       1136                   Sales
# 2  1679   37      Travel_Rarely        155  Research & Development
# 3  1680   32      Travel_Rarely        688  Research & Development
# 4  1681   29  Travel_Frequently        464  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          1        Medical              1
# 1                 4          4      Marketing              1
# 2                13          3  Life Sciences              1
# 3                 1          4  Life Sciences              1
# 4                 9          1  Life Sciences              1
#
#    EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        4   Male          43               3         1
# 1                        3   Male          67               3         2
# 2                        4   Male          41               3         1
# 3                        3   Male          89               2         2
# 4                        3   Male          79               3         1
#
#                      JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0      Laboratory Technician                3        Single           2318
# 1            Sales Executive                1      Divorced           5486
# 2         Research Scientist                4      Divorced           2741
# 3  Healthcare Representative                3        Single           5228
# 4      Laboratory Technician                4        Single           1223
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        17778                   1      Y       No                 12
# 1        12421                   6      Y      Yes                 12
# 2        23577                   4      Y      Yes                 13
# 3        20364                   1      Y       No                 13
# 4        15178                   1      Y       No                 14
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         4             80
# 1                  3                         3             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         1             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  1                      2
# 1                 1                  7                      3
# 2                 2                 13                      2
# 3                 0                 14                      2
# 4                 0                  1                      5
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                2               1                   0
# 1                3               2                   2
# 2                2               7                   7
# 3                2              14                  10
# 4                3               1                   0
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     0
# 1                        2                     2
# 2                        1                     7
# 3                       11                     8
# 4                        0                     0
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %%
train.shape, test.shape, add_train.shape
# Out:
# ((1677, 35), (1119, 34), (1470, 35))

# %%
train.columns = train.columns.str.replace(' ', '')
test.columns = test.columns.str.replace(' ', '')
add_train.columns = add_train.columns.str.replace(' ', '')

# %%
# encode attrition in add_train to numerical
from sklearn.preprocessing import LabelEncoder
add_train['Attrition'] = add_train['Attrition'].apply(lambda x: 1 if x == 'Yes' else 0)

# %%
for i in [train, add_train]:
    print(i['Attrition'].value_counts())
# Out:
# 0    1477
# 1     200
# Name: Attrition, dtype: int64
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
# a_a = add_train[add_train['Attrition'] == 1].reset_index(drop=True)
train = pd.concat([train, add_train]).reset_index(drop=True)
train.tail()
# Out:
#       id  Age     BusinessTravel  DailyRate              Department  \
# 3142 NaN   36  Travel_Frequently        884  Research & Development
# 3143 NaN   39      Travel_Rarely        613  Research & Development
# 3144 NaN   27      Travel_Rarely        155  Research & Development
# 3145 NaN   49  Travel_Frequently       1023                   Sales
# 3146 NaN   34      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 3142                23          2        Medical              1
# 3143                 6          1        Medical              1
# 3144                 4          3  Life Sciences              1
# 3145                 2          3        Medical              1
# 3146                 8          3        Medical              1
#
#       EnvironmentSatisfaction Gender  HourlyRate  JobInvolvement  JobLevel  \
# 3142                        3   Male          41               4         2
# 3143                        4   Male          42               2         3
# 3144                        2   Male          87               4         2
# 3145                        4   Male          63               2         2
# 3146                        2   Male          82               4         2
#
#                         JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 3142      Laboratory Technician                4       Married           2571
# 3143  Healthcare Representative                1       Married           9991
# 3144     Manufacturing Director                2       Married           6142
# 3145            Sales Executive                2       Married           5390
# 3146      Laboratory Technician                3       Married           4404
#
#       MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 3142        12290                   4      Y       No                 17
# 3143        21457                   4      Y       No                 15
# 3144         5174                   1      Y      Yes                 20
# 3145        13243                   2      Y       No                 14
# 3146        10228                   2      Y       No                 12
#
#       PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 3142                  3                         3             80
# 3143                  3                         1             80
# 3144                  4                         2             80
# 3145                  3                         4             80
# 3146                  3                         1             80
#
#       StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 3142                 1                 17                      3
# 3143                 1                  9                      5
# 3144                 1                  6                      0
# 3145                 0                 17                      3
# 3146                 0                  6                      3
#
#       WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 3142                3               5                   2
# 3143                3               7                   7
# 3144                3               6                   2
# 3145                2               9                   6
# 3146                4               4                   3
#
#       YearsSinceLastPromotion  YearsWithCurrManager  Attrition  EmployeeNumber
# 3142                        0                     3          0          2061.0
# 3143                        1                     7          0          2062.0
# 3144                        0                     3          0          2064.0
# 3145                        0                     8          0          2065.0
# 3146                        1                     2          0          2068.0

# %%
data = [train, test]
for i in data:
    print(i.info())
    print('-' *100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 36 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1677 non-null   float64
#  1   Age                       3147 non-null   int64
#  2   BusinessTravel            3147 non-null   object
#  3   DailyRate                 3147 non-null   int64
#  4   Department                3147 non-null   object
#  5   DistanceFromHome          3147 non-null   int64
#  6   Education                 3147 non-null   int64
#  7   EducationField            3147 non-null   object
#  8   EmployeeCount             3147 non-null   int64
#  9   EnvironmentSatisfaction   3147 non-null   int64
#  10  Gender                    3147 non-null   object
#  11  HourlyRate                3147 non-null   int64
#  12  JobInvolvement            3147 non-null   int64
#  13  JobLevel                  3147 non-null   int64
#  14  JobRole                   3147 non-null   object
#  15  JobSatisfaction           3147 non-null   int64
#  16  MaritalStatus             3147 non-null   object
#  17  MonthlyIncome             3147 non-null   int64
#  18  MonthlyRate               3147 non-null   int64
#  19  NumCompaniesWorked        3147 non-null   int64
#  20  Over18                    3147 non-null   object
#  21  OverTime                  3147 non-null   object
#  22  PercentSalaryHike         3147 non-null   int64
#  23  PerformanceRating         3147 non-null   int64
#  24  RelationshipSatisfaction  3147 non-null   int64
#  25  StandardHours             3147 non-null   int64
#  26  StockOptionLevel          3147 non-null   int64
#  27  TotalWorkingYears         3147 non-null   int64
#  28  TrainingTimesLastYear     3147 non-null   int64
#  29  WorkLifeBalance           3147 non-null   int64
#  30  YearsAtCompany            3147 non-null   int64
#  31  YearsInCurrentRole        3147 non-null   int64
#  32  YearsSinceLastPromotion   3147 non-null   int64
#  33  YearsWithCurrManager      3147 non-null   int64
#  34  Attrition                 3147 non-null   int64
#  35  EmployeeNumber            1470 non-null   float64
# dtypes: float64(2), int64(26), object(8)
# memory usage: 885.2+ KB
# None
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        1119 non-null   int64
#  1   Age                       1119 non-null   int64
#  2   BusinessTravel            1119 non-null   object
#  3   DailyRate                 1119 non-null   int64
#  4   Department                1119 non-null   object
#  5   DistanceFromHome          1119 non-null   int64
#  6   Education                 1119 non-null   int64
#  7   EducationField            1119 non-null   object
#  8   EmployeeCount             1119 non-null   int64
#  9   EnvironmentSatisfaction   1119 non-null   int64
#  10  Gender                    1119 non-null   object
#  11  HourlyRate                1119 non-null   int64
#  12  JobInvolvement            1119 non-null   int64
#  13  JobLevel                  1119 non-null   int64
#  14  JobRole                   1119 non-null   object
#  15  JobSatisfaction           1119 non-null   int64
#  16  MaritalStatus             1119 non-null   object
#  17  MonthlyIncome             1119 non-null   int64
#  18  MonthlyRate               1119 non-null   int64
#  19  NumCompaniesWorked        1119 non-null   int64
#  20  Over18                    1119 non-null   object
#  21  OverTime                  1119 non-null   object
#  22  PercentSalaryHike         1119 non-null   int64
#  23  PerformanceRating         1119 non-null   int64
#  24  RelationshipSatisfaction  1119 non-null   int64
#  25  StandardHours             1119 non-null   int64
#  26  StockOptionLevel          1119 non-null   int64
#  27  TotalWorkingYears         1119 non-null   int64
#  28  TrainingTimesLastYear     1119 non-null   int64
#  29  WorkLifeBalance           1119 non-null   int64
#  30  YearsAtCompany            1119 non-null   int64
#  31  YearsInCurrentRole        1119 non-null   int64
#  32  YearsSinceLastPromotion   1119 non-null   int64
#  33  YearsWithCurrManager      1119 non-null   int64
# dtypes: int64(26), object(8)
# memory usage: 297.4+ KB
# None
# ----------------------------------------------------------------------------------------------------

# %%
print(train.duplicated().sum())
print(test.duplicated().sum())
# Out:
# 0
# 0

# %%
print(train.columns.tolist());print()
print(test.columns.tolist())
# Out:
# ['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition', 'EmployeeNumber']
#
# ['id', 'Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
train = train.drop(['id', 'Over18','StandardHours', 'EmployeeCount', 'EmployeeNumber'], axis=1)
test = test.drop(['id', 'Over18','StandardHours', 'EmployeeCount'], axis=1)

# %%
for i in train.select_dtypes(exclude='number').columns:
    print(train[i].value_counts())
    print(100 * '-')
# Out:
# Travel_Rarely        2333
# Travel_Frequently     538
# Non-Travel            276
# Name: BusinessTravel, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Research & Development    2128
# Sales                      917
# Human Resources            102
# Name: Department, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Life Sciences       1381
# Medical             1013
# Marketing            311
# Technical Degree     238
# Other                164
# Human Resources       40
# Name: EducationField, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Male      1946
# Female    1201
# Name: Gender, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Sales Executive              681
# Research Scientist           636
# Laboratory Technician        593
# Manufacturing Director       341
# Healthcare Representative    286
# Manager                      213
# Sales Representative         160
# Research Director            151
# Human Resources               86
# Name: JobRole, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Married     1446
# Single      1047
# Divorced     654
# Name: MaritalStatus, dtype: int64
# ----------------------------------------------------------------------------------------------------
# No     2331
# Yes     816
# Name: OverTime, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %%
for i in test.select_dtypes(exclude='number').columns:
    print(test[i].value_counts())
    print(100 * '-')
# Out:
# Travel_Rarely        799
# Travel_Frequently    212
# Non-Travel           108
# Name: BusinessTravel, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Research & Development    777
# Sales                     306
# Human Resources            36
# Name: Department, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Life Sciences       519
# Medical             345
# Marketing           102
# Technical Degree     96
# Other                45
# Human Resources      12
# Name: EducationField, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Male      690
# Female    429
# Name: Gender, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Sales Executive              240
# Laboratory Technician        230
# Research Scientist           230
# Manufacturing Director       117
# Healthcare Representative    112
# Manager                       71
# Research Director             46
# Sales Representative          44
# Human Resources               29
# Name: JobRole, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Married     524
# Single      394
# Divorced    201
# Name: MaritalStatus, dtype: int64
# ----------------------------------------------------------------------------------------------------
# No     852
# Yes    267
# Name: OverTime, dtype: int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ## EDA

# %%
cat_col = train.select_dtypes('O').columns.to_list() + ['Attrition']
print(cat_col)

test_cat_col = cat_col[:-1]
print(test_cat_col)
# Out:
# ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime', 'Attrition']
# ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'OverTime']

# %%
review = train[cat_col]
for i in review.columns:
    plt.figure(figsize=(8, 5))
    sns.barplot(x=review[i].value_counts().index, y=review[i].value_counts()).set_title(i)
    plt.show()

# %%
# for i in concatenated_train.select_dtypes(include='number').columns:
#     plt.figure(figsize=(8, 5))
#     sns.histplot(train[i])
#     plt.show();

# %%
# for i in concatenated_train.select_dtypes(include='number').columns:
#     plt.figure(figsize=(8, 5))
#     sns.boxplot(y=train[i])
#     plt.xlabel(i)
#     plt.show();

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Explanation of the columns in the dataset:
#
# 1. **id:** Unique identifier for each employee.
#
# 2. **Age:** The age of the employee.
#
# 3. **BusinessTravel:** The frequency of business travel. This could be "Non-Travel," "Travel_Rarely," or "Travel_Frequently."
#
# 4. **DailyRate:** The daily rate of pay for the employee.
#
# 5. **Department:** The department in which the employee works ('Research & Development', 'Sales', 'Human Resources').
#
# 6. **DistanceFromHome:** The distance of the employee's home from the workplace.
#
# 7. **Education:** The level of education achieved by the employee.
#
# 8. **EducationField:** The field of education of the employee ('Medical', 'Other', 'Marketing', 'Life Sciences', 'Technical Degree', 'Human Resources').
#
# 9. **EmployeeCount:** The count of employees. This column seems to have a constant value and may be dropped as it doesn't provide useful information.
#
# 10. **EnvironmentSatisfaction:** Employee's satisfaction with their work environment.
#
# 11. **Gender:** The gender of the employee.
#
# 12. **HourlyRate:** The hourly rate of pay for the employee.
#
# 13. **JobInvolvement:** The level of job involvement.
#
# 14. **JobLevel:** The level of the employee's job within the company hierarchy.
#
# 15. **JobRole:** The role/title of the employee ('Laboratory Technician', 'Sales Representative', 'Sales Executive',
#        'Healthcare Representative', 'Manager', 'Manufacturing Director',
#        'Research Scientist', 'Human Resources', 'Research Director').
#
# 16. **JobSatisfaction:** Employee's satisfaction with their job.
#
# 17. **MaritalStatus:** The marital status of the employee ('Married', 'Divorced', 'Single').
#
# 18. **MonthlyIncome:** The monthly income of the employee.
#
# 19. **MonthlyRate:** The monthly rate of pay for the employee.
#
# 20. **NumCompaniesWorked:** The number of companies the employee has worked for.
#
# 21. **Over18:** Indicates if the employee is over 18 years old. This column may be dropped if all values are the same.
#
# 22. **OverTime:** Whether the employee works overtime or not.
#
# 23. **PercentSalaryHike:** The percentage increase in salary.
#
# 24. **PerformanceRating:** The performance rating of the employee.
#
# 25. **RelationshipSatisfaction:** Employee's satisfaction with their relationships at work.
#
# 26. **StandardHours:** The standard number of working hours.
#
# 27. **StockOptionLevel:** The level of stock options granted to the employee.
#
# 28. **TotalWorkingYears:** The total number of years the employee has been working.
#
# 29. **TrainingTimesLastYear:** The number of training times the employee attended last year.
#
# 30. **WorkLifeBalance:** Employee's perception of work-life balance.
#
# 31. **YearsAtCompany:** The number of years the employee has spent at the current company.
#
# 32. **YearsInCurrentRole:** The number of years the employee has been in the current role.
#
# 33. **YearsSinceLastPromotion:** The number of years since the last promotion.
#
# 34. **YearsWithCurrManager:** The number of years the employee has been with the current manager.
#
# 35. **Attrition:** The target variable indicating whether the employee has attrited (left the company) or not "Yes" or "No."

# %%
train.select_dtypes(include=['int64', 'float']).columns
# Out:
# Index(['Age', 'DailyRate', 'DistanceFromHome', 'Education',
#        'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
for i in train.select_dtypes(exclude='number').columns:
    print(train[i].value_counts())
    print('-' * 50)

print();print();print()
for i in train.select_dtypes(include='number').columns:
    print(train[i].value_counts())
    print('-' * 50)
# Out:
# Travel_Rarely        2333
# Travel_Frequently     538
# Non-Travel            276
# Name: BusinessTravel, dtype: int64
# --------------------------------------------------
# Research & Development    2128
# Sales                      917
# Human Resources            102
# Name: Department, dtype: int64
# --------------------------------------------------
# Life Sciences       1381
# Medical             1013
# Marketing            311
# Technical Degree     238
# Other                164
# Human Resources       40
# Name: EducationField, dtype: int64
# --------------------------------------------------
# Male      1946
# Female    1201
# Name: Gender, dtype: int64
# --------------------------------------------------
# Sales Executive              681
# Research Scientist           636
# Laboratory Technician        593
# Manufacturing Director       341
# Healthcare Representative    286
# Manager                      213
# Sales Representative         160
# Research Director            151
# Human Resources               86
# Name: JobRole, dtype: int64
# --------------------------------------------------
# Married     1446
# Single      1047
# Divorced     654
# Name: MaritalStatus, dtype: int64
# --------------------------------------------------
# No     2331
# Yes     816
# Name: OverTime, dtype: int64
# --------------------------------------------------
#
#
#
# 34    172
# 36    170
# 35    167
# 29    164
# 31    159
# 38    146
# 40    136
# 30    126
# 32    121
# 27    115
# 28    110
# 33    108
# 37    108
# 39     96
# 26     84
# 45     82
# 42     82
# 41     80
# 46     80
# 44     72
# 25     62
# 43     61
# 50     59
# 24     49
# 48     47
# 47     46
# 49     43
# 55     39
# 52     36
# 53     34
# 23     34
# 51     33
# 22     30
# 21     29
# 54     25
# 56     24
# 58     23
# 19     22
# 59     20
# 18     20
# 20     17
# 57      8
# 60      8
# Name: Age, dtype: int64
# --------------------------------------------------
# 1082    21
# 775     15
# 1329    15
# 465     15
# 827     14
#         ..
# 1207     1
# 1442     1
# 608      1
# 294      1
# 1023     1
# Name: DailyRate, Length: 901, dtype: int64
# --------------------------------------------------
# 2     489
# 1     445
# 9     186
# 10    185
# 8     184
# 3     179
# 7     175
# 5     139
# 6     137
# 4     128
# 16     64
# 11     61
# 15     56
# 24     56
# 18     56
# 29     54
# 25     51
# 23     51
# 20     50
# 28     49
# 26     49
# 19     49
# 17     46
# 14     43
# 12     38
# 21     36
# 22     35
# 13     35
# 27     21
# Name: DistanceFromHome, dtype: int64
# --------------------------------------------------
# 3     1254
# 4      862
# 2      586
# 1      352
# 5       92
# 15       1
# Name: Education, dtype: int64
# --------------------------------------------------
# 4    983
# 3    949
# 2    632
# 1    583
# Name: EnvironmentSatisfaction, dtype: int64
# --------------------------------------------------
# 42    69
# 84    69
# 66    68
# 96    66
# 72    62
#       ..
# 47    23
# 53    21
# 31    20
# 38    18
# 34    18
# Name: HourlyRate, Length: 71, dtype: int64
# --------------------------------------------------
# 3    1975
# 2     733
# 4     283
# 1     156
# Name: JobInvolvement, dtype: int64
# --------------------------------------------------
# 1    1198
# 2    1151
# 3     453
# 4     200
# 5     144
# 7       1
# Name: JobLevel, dtype: int64
# --------------------------------------------------
# 4    1020
# 3     958
# 1     599
# 2     570
# Name: JobSatisfaction, dtype: int64
# --------------------------------------------------
# 2559    12
# 2342    12
# 2911    11
# 5228    10
# 6811    10
#         ..
# 5715     1
# 3034     1
# 7596     1
# 2476     1
# 9936     1
# Name: MonthlyIncome, Length: 1383, dtype: int64
# --------------------------------------------------
# 4223     12
# 15891    10
# 9150     10
# 8952     10
# 11652     9
#          ..
# 2227      1
# 12740     1
# 13436     1
# 4345      1
# 3787      1
# Name: MonthlyRate, Length: 1447, dtype: int64
# --------------------------------------------------
# 1    1127
# 0     450
# 3     325
# 2     315
# 4     300
# 7     162
# 6     138
# 5     124
# 9     115
# 8      91
# Name: NumCompaniesWorked, dtype: int64
# --------------------------------------------------
# 13    476
# 14    459
# 11    447
# 12    433
# 15    225
# 18    186
# 17    174
# 19    155
# 16    152
# 22    113
# 20    110
# 21    102
# 23     50
# 24     37
# 25     28
# Name: PercentSalaryHike, dtype: int64
# --------------------------------------------------
# 3    2707
# 4     440
# Name: PerformanceRating, dtype: int64
# --------------------------------------------------
# 3    982
# 4    950
# 2    640
# 1    575
# Name: RelationshipSatisfaction, dtype: int64
# --------------------------------------------------
# 0    1363
# 1    1341
# 2     293
# 3     150
# Name: StockOptionLevel, dtype: int64
# --------------------------------------------------
# 10    456
# 6     281
# 8     219
# 9     210
# 7     185
# 1     184
# 5     182
# 4     140
# 12    102
# 15     93
# 3      90
# 13     80
# 16     77
# 21     67
# 17     67
# 11     64
# 14     62
# 18     62
# 2      61
# 20     59
# 22     46
# 19     44
# 23     42
# 24     36
# 28     31
# 26     30
# 25     29
# 0      24
# 31     18
# 29     18
# 33     15
# 30     14
# 27     14
# 32     11
# 34      9
# 36      8
# 37      6
# 35      4
# 40      3
# 38      3
# 41      1
# Name: TotalWorkingYears, dtype: int64
# --------------------------------------------------
# 2    1202
# 3    1117
# 4     245
# 5     241
# 1     134
# 0     104
# 6     104
# Name: TrainingTimesLastYear, dtype: int64
# --------------------------------------------------
# 3    1982
# 2     729
# 4     288
# 1     148
# Name: WorkLifeBalance, dtype: int64
# --------------------------------------------------
# 5     424
# 1     385
# 3     304
# 10    258
# 2     235
# 4     231
# 7     193
# 9     181
# 8     171
# 6     163
# 0      98
# 20     62
# 11     60
# 13     52
# 15     47
# 14     34
# 22     32
# 12     28
# 16     28
# 21     27
# 17     23
# 18     20
# 19     19
# 24     15
# 33     10
# 25      9
# 31      7
# 26      5
# 29      5
# 27      4
# 30      3
# 34      3
# 32      3
# 37      2
# 36      2
# 23      2
# 41      1
# 40      1
# Name: YearsAtCompany, dtype: int64
# --------------------------------------------------
# 2     787
# 0     551
# 7     485
# 3     301
# 4     229
# 8     192
# 9     144
# 1     100
# 6      77
# 5      70
# 10     57
# 11     38
# 13     28
# 14     25
# 12     21
# 16     13
# 15     13
# 17     10
# 18      6
# Name: YearsInCurrentRole, dtype: int64
# --------------------------------------------------
# 0     1307
# 1      764
# 2      307
# 7      165
# 4      139
# 3      105
# 5       86
# 6       68
# 11      55
# 8       33
# 9       32
# 15      25
# 13      18
# 12      18
# 14      15
# 10      10
# Name: YearsSinceLastPromotion, dtype: int64
# --------------------------------------------------
# 2     731
# 0     561
# 7     481
# 3     316
# 8     233
# 4     205
# 1     147
# 9     121
# 5      68
# 6      63
# 10     56
# 11     52
# 12     40
# 13     31
# 17     15
# 14     12
# 15     11
# 16      4
# Name: YearsWithCurrManager, dtype: int64
# --------------------------------------------------
# 0    2710
# 1     437
# Name: Attrition, dtype: int64
# --------------------------------------------------

# %%
selected_features = train.columns.tolist()[:-1]

target_col = 'Attrition'

ord_cat_features = ['BusinessTravel']
ord_cat_order = ['Non-Travel', 'Travel_Rarely', 'Travel_Frequently']

num_features = ['Education', 'JobInvolvement', 'PerformanceRating','RelationshipSatisfaction', 'WorkLifeBalance',
                'StockOptionLevel', 'JobLevel', 'JobSatisfaction', 'EnvironmentSatisfaction']

cat_features = ['Department', 'EducationField', 'Gender', 'MaritalStatus', 'OverTime', 'JobRole']

cont_features = ['MonthlyRate', 'MonthlyIncome', 'DailyRate', 'HourlyRate', 'Age', 'DistanceFromHome', 'TotalWorkingYears',
                 'YearsAtCompany', 'YearsInCurrentRole', 'YearsWithCurrManager', 'PercentSalaryHike', 'NumCompaniesWorked',
                 'TrainingTimesLastYear', 'YearsSinceLastPromotion']

comb_features = ord_cat_features + num_features + cat_features + cont_features

# %%
print(train[comb_features].shape, train.shape)

print(set(train[comb_features]) ^ set(train))
# Out:
# (3147, 30) (3147, 31)
# {'Attrition'}

# %%
# Processing 'train' data
train_df = train.copy()

train_df['IncomePerAge'] = train_df['MonthlyIncome'] / train_df['Age']
train_df["AgeRisk"] = (train_df["Age"] < 34).astype(int)
train_df["HourlyRateRisk"] = (train_df["HourlyRate"] < 60).astype(int)
train_df["DistanceRisk"] = (train_df["DistanceFromHome"] >= 20).astype(int)
train_df["ShortCompanyTenure"] = (train_df["YearsAtCompany"] < 4).astype(int)
train_df['NumCompaniesAdjusted'] = train_df['NumCompaniesWorked'].replace(0, 1)
train_df['AverageCompanyTenure'] = train_df["TotalWorkingYears"] / train_df["NumCompaniesAdjusted"]
train_df['JobHopperIndicator'] = ((train_df["NumCompaniesAdjusted"] > 2) & (train_df["AverageCompanyTenure"] < 2.0)).astype(int)
train_df["AttritionRiskScore"] = train_df["AgeRisk"] + train_df["HourlyRateRisk"] + train_df["DistanceRisk"] + train_df["ShortCompanyTenure"] + train_df['JobHopperIndicator']
train_df['IncomeToDailyRateRatio'] = train_df['MonthlyIncome'] / train_df['DailyRate']
train_df['TenureToAgeRatio'] = train_df['TotalWorkingYears'] / train_df['Age']
train_df['TotalSatisfaction'] = train_df['EnvironmentSatisfaction'] + train_df['JobSatisfaction'] + train_df['RelationshipSatisfaction']

train_df.loc[train_df['Education'] == 15, 'Education'] = 5
train_df.loc[train_df['JobLevel'] == 7, 'JobLevel'] = 5

# %%
# Processing 'test' data
test_df = test.copy()

test_df['IncomePerAge'] = test_df['MonthlyIncome'] / test_df['Age']
test_df["AgeRisk"] = (test_df["Age"] < 34).astype(int)
test_df["HourlyRateRisk"] = (test_df["HourlyRate"] < 60).astype(int)
test_df["DistanceRisk"] = (test_df["DistanceFromHome"] >= 20).astype(int)
test_df["ShortCompanyTenure"] = (test_df["YearsAtCompany"] < 4).astype(int)
test_df['NumCompaniesAdjusted'] = test_df['NumCompaniesWorked'].replace(0, 1)
test_df['AverageCompanyTenure'] = test_df["TotalWorkingYears"] / test_df["NumCompaniesAdjusted"]
test_df['JobHopperIndicator'] = ((test_df["NumCompaniesAdjusted"] > 2) & (test_df["AverageCompanyTenure"] < 2.0)).astype(int)
test_df["AttritionRiskScore"] = test_df["AgeRisk"] + test_df["HourlyRateRisk"] + test_df["DistanceRisk"] + test_df["ShortCompanyTenure"] + test_df['JobHopperIndicator']
test_df['IncomeToDailyRateRatio'] = test_df['MonthlyIncome'] / test_df['DailyRate']
test_df['TenureToAgeRatio'] = test_df['TotalWorkingYears'] / test_df['Age']
test_df['TotalSatisfaction'] = test_df['EnvironmentSatisfaction'] + test_df['JobSatisfaction'] + test_df['RelationshipSatisfaction']

test_df.loc[test_df['Education'] == 15, 'Education'] = 5
test_df.loc[test_df['JobLevel'] == 7, 'JobLevel'] = 5

# %%
display(train_df.describe(), test_df.describe())
# Out:
#                Age    DailyRate  DistanceFromHome    Education  \
# count  3147.000000  3147.000000       3147.000000  3147.000000
# mean     36.451223   850.586273          8.921513     2.923101
# std       8.815861   390.859919          7.961278     1.010025
# min      18.000000   102.000000          1.000000     1.000000
# 25%      30.000000   543.000000          2.000000     2.000000
# 50%      35.000000   852.000000          7.000000     3.000000
# 75%      42.000000  1198.500000         13.000000     4.000000
# max      60.000000  3921.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              3147.000000  3147.000000     3147.000000  3147.000000
# mean                  2.741023    66.907531        2.757865     2.028599
# std                   1.089733    19.877918        0.680183     1.092281
# min                   1.000000    30.000000        1.000000     1.000000
# 25%                   2.000000    50.000000        2.000000     1.000000
# 50%                   3.000000    67.000000        3.000000     2.000000
# 75%                   4.000000    84.000000        3.000000     3.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count      3147.000000    3147.000000   3147.000000         3147.000000
# mean          2.762313    6339.397521  14556.604067            2.630124
# std           1.100224    4610.584686   7117.334257            2.488848
# min           1.000000    1009.000000    636.000000            0.000000
# 25%           2.000000    2888.000000   8306.000000            1.000000
# 50%           3.000000    4877.000000  14908.000000            1.000000
# 75%           4.000000    7725.000000  20744.500000            4.000000
# max           4.000000   19999.000000  26999.000000            9.000000
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count        3147.000000        3147.000000               3147.000000
# mean           15.046393           3.139816                  2.733079
# std             3.537252           0.346851                  1.079454
# min            11.000000           3.000000                  1.000000
# 25%            12.000000           3.000000                  2.000000
# 50%            14.000000           3.000000                  3.000000
# 75%            17.000000           3.000000                  4.000000
# max            25.000000           4.000000                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       3147.000000        3147.000000            3147.000000
# mean           0.755323          10.975850               2.763902
# std            0.810688           7.509438               1.214918
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000           9.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          41.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      3147.000000     3147.000000         3147.000000
# mean          2.765809        6.900858            4.183985
# std           0.675707        5.998015            3.601691
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       41.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager    Attrition  \
# count              3147.000000           3147.000000  3147.000000
# mean                  2.076263              4.156975     0.138862
# std                   3.130744              3.572003     0.345858
# min                   0.000000              0.000000     0.000000
# 25%                   0.000000              2.000000     0.000000
# 50%                   1.000000              3.000000     0.000000
# 75%                   2.000000              7.000000     0.000000
# max                  15.000000             17.000000     1.000000
#
#        IncomePerAge      AgeRisk  HourlyRateRisk  DistanceRisk  \
# count   3147.000000  3147.000000     3147.000000   3147.000000
# mean     169.249028     0.397204        0.385764      0.143629
# std      101.523449     0.489397        0.486853      0.350769
# min       26.541667     0.000000        0.000000      0.000000
# 25%       93.027778     0.000000        0.000000      0.000000
# 50%      139.766667     0.000000        0.000000      0.000000
# 75%      215.508798     1.000000        1.000000      0.000000
# max      660.956522     1.000000        1.000000      1.000000
#
#        ShortCompanyTenure  NumCompaniesAdjusted  AverageCompanyTenure  \
# count         3147.000000           3147.000000           3147.000000
# mean             0.324754              2.773117              6.092536
# std              0.468357              2.358925              5.514808
# min              0.000000              1.000000              0.000000
# 25%              0.000000              1.000000              2.071429
# 50%              0.000000              1.000000              4.800000
# 75%              1.000000              4.000000              9.000000
# max              1.000000              9.000000             41.000000
#
#        JobHopperIndicator  AttritionRiskScore  IncomeToDailyRateRatio  \
# count         3147.000000         3147.000000             3147.000000
# mean             0.140133            1.391484               10.749591
# std              0.347181            1.028780               13.943818
# min              0.000000            0.000000                0.740822
# 25%              0.000000            1.000000                3.640864
# 50%              0.000000            1.000000                6.401399
# 75%              0.000000            2.000000               12.154957
# max              1.000000            5.000000              185.057143
#
#        TenureToAgeRatio  TotalSatisfaction
# count       3147.000000        3147.000000
# mean           0.285063           8.236416
# std            0.153233           1.861896
# min            0.000000           3.000000
# 25%            0.178571           7.000000
# 50%            0.260870           8.000000
# 75%            0.387755          10.000000
# max            1.051282          12.000000
#                Age    DailyRate  DistanceFromHome    Education  \
# count  1119.000000  1119.000000       1119.000000  1119.000000
# mean     36.147453   883.550492          8.667560     2.941912
# std       8.786102   366.427230          7.772384     1.012986
# min      18.000000     6.000000          1.000000     1.000000
# 25%      30.000000   589.000000          2.000000     2.000000
# 50%      35.000000   889.000000          7.000000     3.000000
# 75%      41.000000  1206.000000         12.000000     4.000000
# max      59.000000  1499.000000         29.000000     5.000000
#
#        EnvironmentSatisfaction   HourlyRate  JobInvolvement     JobLevel  \
# count              1119.000000  1119.000000     1119.000000  1119.000000
# mean                  2.736372    68.226095        2.741734     1.999106
# std                   1.106668    19.495282        0.652751     1.091109
# min                   0.000000    30.000000        0.000000     1.000000
# 25%                   2.000000    52.000000        2.000000     1.000000
# 50%                   3.000000    71.000000        3.000000     2.000000
# 75%                   4.000000    85.000000        3.000000     2.000000
# max                   4.000000   100.000000        4.000000     5.000000
#
#        JobSatisfaction  MonthlyIncome   MonthlyRate  NumCompaniesWorked  \
# count      1119.000000    1119.000000   1119.000000         1119.000000
# mean          2.767650    6153.750670  14712.646113            2.544236
# std           1.103576    4558.597502   6916.185207            2.460340
# min           1.000000     464.000000    959.000000            0.000000
# 25%           2.000000    2853.000000   8821.000000            1.000000
# 50%           3.000000    4721.000000  15211.000000            1.000000
# 75%           4.000000    7082.500000  20652.000000            4.000000
# max           4.000000   19999.000000  26999.000000           17.000000
#
#        PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# count        1119.000000        1119.000000               1119.000000
# mean           14.763181           3.109026                  2.722073
# std             3.397653           0.311811                  1.058472
# min            11.000000           3.000000                  1.000000
# 25%            12.000000           3.000000                  2.000000
# 50%            14.000000           3.000000                  3.000000
# 75%            17.000000           3.000000                  4.000000
# max            25.000000           4.000000                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1119.000000        1119.000000            1119.000000
# mean           0.758713          10.685433               2.795353
# std            0.826037           7.251628               1.195600
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000           9.000000               3.000000
# 75%            1.000000          14.000000               3.000000
# max            4.000000          38.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1119.000000     1119.000000         1119.000000
# mean          2.759607        7.016979            4.184093
# std           0.656830        5.975403            3.533139
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000       10.000000            7.000000
# max           4.000000       36.000000           17.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager  IncomePerAge  \
# count              1119.000000           1119.000000   1119.000000
# mean                  2.076854              4.308311    166.889923
# std                   3.278022              3.729282    104.216139
# min                   0.000000              0.000000     24.017241
# 25%                   0.000000              2.000000     90.738791
# 50%                   1.000000              3.000000    136.846154
# 75%                   2.000000              7.000000    205.236111
# max                  15.000000             17.000000    733.000000
#
#            AgeRisk  HourlyRateRisk  DistanceRisk  ShortCompanyTenure  \
# count  1119.000000     1119.000000   1119.000000         1119.000000
# mean      0.399464        0.356568      0.132261            0.324397
# std       0.490007        0.479200      0.338926            0.468358
# min       0.000000        0.000000      0.000000            0.000000
# 25%       0.000000        0.000000      0.000000            0.000000
# 50%       0.000000        0.000000      0.000000            0.000000
# 75%       1.000000        1.000000      0.000000            1.000000
# max       1.000000        1.000000      1.000000            1.000000
#
#        NumCompaniesAdjusted  AverageCompanyTenure  JobHopperIndicator  \
# count           1119.000000           1119.000000         1119.000000
# mean               2.685433              6.280057            0.147453
# std                2.335706              5.695892            0.354716
# min                1.000000              0.000000            0.000000
# 25%                1.000000              2.208333            0.000000
# 50%                1.000000              5.000000            0.000000
# 75%                4.000000              9.000000            0.000000
# max               17.000000             37.000000            1.000000
#
#        AttritionRiskScore  IncomeToDailyRateRatio  TenureToAgeRatio  \
# count         1119.000000             1119.000000       1119.000000
# mean             1.360143               10.311969          0.281864
# std              0.989146               43.343659          0.153674
# min              0.000000                0.349135          0.000000
# 25%              1.000000                3.528986          0.176471
# 50%              1.000000                5.849921          0.259259
# 75%              2.000000               10.430198          0.373775
# max              5.000000             1416.666667          1.027778
#
#        TotalSatisfaction
# count        1119.000000
# mean            8.226095
# std             1.903720
# min             3.000000
# 25%             7.000000
# 50%             8.000000
# 75%            10.000000
# max            12.000000

# %%
train_df.shape, test_df.shape
# Out:
# ((3147, 43), (1119, 42))

# %%
data = [train_df, test_df]
for i in data:
    print(i.isnull().any().sum())
    print('-' *100)
# Out:
# 0
# ----------------------------------------------------------------------------------------------------
# 0
# ----------------------------------------------------------------------------------------------------

# %%
data = [train_df, test_df]
for i in data:
    print(i.info())
    print('-' *100)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 43 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       3147 non-null   int64
#  1   BusinessTravel            3147 non-null   object
#  2   DailyRate                 3147 non-null   int64
#  3   Department                3147 non-null   object
#  4   DistanceFromHome          3147 non-null   int64
#  5   Education                 3147 non-null   int64
#  6   EducationField            3147 non-null   object
#  7   EnvironmentSatisfaction   3147 non-null   int64
#  8   Gender                    3147 non-null   object
#  9   HourlyRate                3147 non-null   int64
#  10  JobInvolvement            3147 non-null   int64
#  11  JobLevel                  3147 non-null   int64
#  12  JobRole                   3147 non-null   object
#  13  JobSatisfaction           3147 non-null   int64
#  14  MaritalStatus             3147 non-null   object
#  15  MonthlyIncome             3147 non-null   int64
#  16  MonthlyRate               3147 non-null   int64
#  17  NumCompaniesWorked        3147 non-null   int64
#  18  OverTime                  3147 non-null   object
#  19  PercentSalaryHike         3147 non-null   int64
#  20  PerformanceRating         3147 non-null   int64
#  21  RelationshipSatisfaction  3147 non-null   int64
#  22  StockOptionLevel          3147 non-null   int64
#  23  TotalWorkingYears         3147 non-null   int64
#  24  TrainingTimesLastYear     3147 non-null   int64
#  25  WorkLifeBalance           3147 non-null   int64
#  26  YearsAtCompany            3147 non-null   int64
#  27  YearsInCurrentRole        3147 non-null   int64
#  28  YearsSinceLastPromotion   3147 non-null   int64
#  29  YearsWithCurrManager      3147 non-null   int64
#  30  Attrition                 3147 non-null   int64
#  31  IncomePerAge              3147 non-null   float64
#  32  AgeRisk                   3147 non-null   int64
#  33  HourlyRateRisk            3147 non-null   int64
#  34  DistanceRisk              3147 non-null   int64
#  35  ShortCompanyTenure        3147 non-null   int64
#  36  NumCompaniesAdjusted      3147 non-null   int64
#  37  AverageCompanyTenure      3147 non-null   float64
#  38  JobHopperIndicator        3147 non-null   int64
#  39  AttritionRiskScore        3147 non-null   int64
#  40  IncomeToDailyRateRatio    3147 non-null   float64
#  41  TenureToAgeRatio          3147 non-null   float64
#  42  TotalSatisfaction         3147 non-null   int64
# dtypes: float64(4), int64(32), object(7)
# memory usage: 1.0+ MB
# None
# ----------------------------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1119 non-null   int64
#  1   BusinessTravel            1119 non-null   object
#  2   DailyRate                 1119 non-null   int64
#  3   Department                1119 non-null   object
#  4   DistanceFromHome          1119 non-null   int64
#  5   Education                 1119 non-null   int64
#  6   EducationField            1119 non-null   object
#  7   EnvironmentSatisfaction   1119 non-null   int64
#  8   Gender                    1119 non-null   object
#  9   HourlyRate                1119 non-null   int64
#  10  JobInvolvement            1119 non-null   int64
#  11  JobLevel                  1119 non-null   int64
#  12  JobRole                   1119 non-null   object
#  13  JobSatisfaction           1119 non-null   int64
#  14  MaritalStatus             1119 non-null   object
#  15  MonthlyIncome             1119 non-null   int64
#  16  MonthlyRate               1119 non-null   int64
#  17  NumCompaniesWorked        1119 non-null   int64
#  18  OverTime                  1119 non-null   object
#  19  PercentSalaryHike         1119 non-null   int64
#  20  PerformanceRating         1119 non-null   int64
#  21  RelationshipSatisfaction  1119 non-null   int64
#  22  StockOptionLevel          1119 non-null   int64
#  23  TotalWorkingYears         1119 non-null   int64
#  24  TrainingTimesLastYear     1119 non-null   int64
#  25  WorkLifeBalance           1119 non-null   int64
#  26  YearsAtCompany            1119 non-null   int64
#  27  YearsInCurrentRole        1119 non-null   int64
#  28  YearsSinceLastPromotion   1119 non-null   int64
#  29  YearsWithCurrManager      1119 non-null   int64
#  30  IncomePerAge              1119 non-null   float64
#  31  AgeRisk                   1119 non-null   int64
#  32  HourlyRateRisk            1119 non-null   int64
#  33  DistanceRisk              1119 non-null   int64
#  34  ShortCompanyTenure        1119 non-null   int64
#  35  NumCompaniesAdjusted      1119 non-null   int64
#  36  AverageCompanyTenure      1119 non-null   float64
#  37  JobHopperIndicator        1119 non-null   int64
#  38  AttritionRiskScore        1119 non-null   int64
#  39  IncomeToDailyRateRatio    1119 non-null   float64
#  40  TenureToAgeRatio          1119 non-null   float64
#  41  TotalSatisfaction         1119 non-null   int64
# dtypes: float64(4), int64(31), object(7)
# memory usage: 367.3+ KB
# None
# ----------------------------------------------------------------------------------------------------

# %%
print(train_df.columns.tolist());print()
print(test_df.columns.tolist())
# Out:
# ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition', 'IncomePerAge', 'AgeRisk', 'HourlyRateRisk', 'DistanceRisk', 'ShortCompanyTenure', 'NumCompaniesAdjusted', 'AverageCompanyTenure', 'JobHopperIndicator', 'AttritionRiskScore', 'IncomeToDailyRateRatio', 'TenureToAgeRatio', 'TotalSatisfaction']
#
# ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education', 'EducationField', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'IncomePerAge', 'AgeRisk', 'HourlyRateRisk', 'DistanceRisk', 'ShortCompanyTenure', 'NumCompaniesAdjusted', 'AverageCompanyTenure', 'JobHopperIndicator', 'AttritionRiskScore', 'IncomeToDailyRateRatio', 'TenureToAgeRatio', 'TotalSatisfaction']

# %%
# encoding ordinal features

from sklearn.preprocessing import OrdinalEncoder

encoder = OrdinalEncoder(categories=[ord_cat_order], dtype=int)
train_df[['BusinessTravel']] = encoder.fit_transform(train_df[['BusinessTravel']])
test_df[['BusinessTravel']] = encoder.transform(test_df[['BusinessTravel']])

# %%
# encoding continuous features

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_df[cont_features] = scaler.fit_transform(train_df[cont_features])
test_df[cont_features] = scaler.transform(test_df[cont_features])

# %%
set(train_df) ^ set(train)
# Out:
# {'AgeRisk',
#  'AttritionRiskScore',
#  'AverageCompanyTenure',
#  'DistanceRisk',
#  'HourlyRateRisk',
#  'IncomePerAge',
#  'IncomeToDailyRateRatio',
#  'JobHopperIndicator',
#  'NumCompaniesAdjusted',
#  'ShortCompanyTenure',
#  'TenureToAgeRatio',
#  'TotalSatisfaction'}

# %%
from sklearn.preprocessing import OneHotEncoder

encoded_features = []

for feature in cat_features:
    ohe = OneHotEncoder(sparse=False, drop='first')
    train_feature_df = pd.DataFrame(train_df[feature])
    test_feature_df = pd.DataFrame(test_df[feature])

    merged_feature_df = pd.concat([train_feature_df, test_feature_df], ignore_index=True)
    ohe.fit(merged_feature_df)

    new_encoded_columns = [f"{feature}_{val}_ohe" for val in ohe.categories_[0][1:]]
    encoded_features.extend(new_encoded_columns)

    train_df_encoded_columns = pd.DataFrame(ohe.transform(train_feature_df), columns=new_encoded_columns, dtype='int')
    test_df_encoded_columns = pd.DataFrame(ohe.transform(test_feature_df), columns=new_encoded_columns, dtype='int')

    for column in new_encoded_columns:
        train_df[column] = train_df_encoded_columns[column]
        test_df[column] = test_df_encoded_columns[column]
        selected_features.append(column)

for feature in cat_features:
    if feature in selected_features:
        selected_features.remove(feature)

train_df.drop(cat_features, axis=1, inplace=True)
test_df.drop(cat_features, axis=1, inplace=True)

cat_features = encoded_features

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### CatBoost

# %%
train_df.shape, test_df.shape
# Out:
# ((3147, 56), (1119, 55))

# %%
X = train_df.drop(['Attrition'], axis=1)
y = train_df['Attrition']

# %%
# !pip install catboost
# !pip install shap
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.46.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Collecting shap
#   Downloading shap-0.44.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (533 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 533.5/533.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.11.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.2.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (1.5.3)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (23.2)
# Collecting slicer==0.0.7 (from shap)
#   Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.58.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.41.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->shap) (1.16.0)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.44.0 slicer-0.0.7

# %%
import catboost as cb
import catboost.utils as cbu

import shap
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_curve, auc, roc_auc_score
from hyperopt import fmin, tpe, hp, STATUS_OK
import random

# %%
# hyperparams
space = {
    # 'n_estimators': hp.quniform('n_estimators', 50, 550, 50),
    # 'colsample_bytree': hp.uniform('colsample_bytree', 0.1, 0.9),
    # 'learning_rate': hp.uniform('learning_rate', 0.01, 0.2),
    # 'max_depth': hp.quniform('max_depth', 2, 8, 1),
    # 'min_split_gain': hp.uniform('min_split_gain', 0.1, 0.5),
    # 'num_leaves': hp.quniform('num_leaves', 30, 150, 1),
    # 'reg_alpha': hp.uniform('reg_alpha', 0, 1),
    # 'reg_lambda': hp.uniform('reg_lambda', 0, 1),
    # 'subsample': hp.uniform('subsample', 0.1, 0.9),

    'learning_rate': hp.uniform('learning_rate', 0.01, 0.3),
    'depth': hp.uniform('depth', 2, 9),
    'l2_leaf_reg': hp.quniform('l2_leaf_reg', 1.5, 5, 0.5),
    'iterations': hp.quniform('iterations', 100, 500, 50),
    'min_child_samples': hp.quniform('min_child_samples', 5, 10, 1),
    'subsample': hp.uniform('subsample', 0.5, 1.0),
    'scale_pos_weight': hp.uniform('scale_pos_weight', 1.0, 3.0),
}

# Objective function
def objective(params):
    # Convert certain hyperparameters to integers
    params.update({key: int(value) if key in ('iterations', 'depth', 'min_child_samples') else value for key, value in params.items()})

    skf_seed = random.randint(0, 2023)
    skf = StratifiedKFold(n_splits=6, shuffle=True, random_state=skf_seed)

    cb_model = cb.CatBoostClassifier(**params, random_state=skf_seed, eval_metric='AUC')

    auc_scores = [roc_auc_score(y.iloc[test_index], cb_model.fit(X.iloc[train_index], y.iloc[train_index],
                                                                  eval_set=[(X.iloc[test_index], y.iloc[test_index])]
                                                                  ).predict_proba(X.iloc[test_index])[:, 1])
                  for train_index, test_index in skf.split(X, y)]

    mean_auc = np.mean(auc_scores)
    loss = 1 - mean_auc

    return {'loss': loss, 'status': STATUS_OK, 'params': params}

# Hyperparameter optimization
best = fmin(fn=objective, space=space, algo=tpe.suggest, max_evals=100)

# Extract the best parameters
best_params = {key: int(value) if key in ('iterations', 'depth', 'min_child_samples') else value for key, value
               in best.items() if key not in ('loss', 'status')}

random.seed(20181224)
skf_seed = random.randint(0, 2023)
# Initialize CatBoost classifier with best parameters
cb_model = cb.CatBoostClassifier(**best_params, random_state=skf_seed, eval_metric='AUC')

# Train and predict using StratifiedKFold
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=skf_seed)
roc_val = [roc_auc_score(y_val_fold, cb_model.fit(train_fold, y_fold, eval_set=[(val_fold, y_val_fold)])
                          .predict_proba(val_fold)[:, 1])
           for (train_index, test_index), (train_fold, val_fold, y_fold, y_val_fold) in
           zip(skf.split(X, y), [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for
                                 train_index, test_index in skf.split(X, y)])]

roc_train = [roc_auc_score(y_fold, cb_model.fit(train_fold, y_fold, eval_set=[(val_fold, y_val_fold)])
                             .predict_proba(train_fold)[:, 1])
             for (train_index, test_index), (train_fold, val_fold, y_fold, y_val_fold) in
             zip(skf.split(X, y), [(X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]) for
                                   train_index, test_index in skf.split(X, y)])]

# Store predictions on the testing dataset test_df
predictions_df = pd.DataFrame()

for i, (train_index, test_index) in enumerate(skf.split(X, y)):
    train_fold, val_fold = X.iloc[train_index], X.iloc[test_index]
    y_fold, y_val_fold = y.iloc[train_index], y.iloc[test_index]

    # Fit the model on the training data
    cb_model.fit(train_fold, y_fold, eval_set=[(val_fold, y_val_fold)])

    # Make predictions on the testing dataset
    predictions_df[i] = cb_model.predict_proba(test_df)[:, 1]

print("roc_val:", roc_val)
print("Mean roc_val:", np.mean(roc_val))
print("\nroc_train:", roc_train)
print("Mean roc_train:", np.mean(roc_train))
print("\nBest Parameters:", best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# 12:	test: 0.8221488	best: 0.8221488 (12)	total: 22.8ms	remaining: 766ms
# 13:	test: 0.8209474	best: 0.8221488 (12)	total: 24.5ms	remaining: 762ms
# 14:	test: 0.8194885	best: 0.8221488 (12)	total: 26.1ms	remaining: 758ms
# 15:	test: 0.8208616	best: 0.8221488 (12)	total: 27.8ms	remaining: 753ms
# 16:	test: 0.8213765	best: 0.8221488 (12)	total: 29.4ms	remaining: 748ms
# 17:	test: 0.8244658	best: 0.8244658 (17)	total: 30.9ms	remaining: 743ms
# 18:	test: 0.8236506	best: 0.8244658 (17)	total: 32.6ms	remaining: 739ms
# 19:	test: 0.8221059	best: 0.8244658 (17)	total: 34.2ms	remaining: 736ms
# 20:	test: 0.8304299	best: 0.8304299 (20)	total: 36.4ms	remaining: 743ms
# 21:	test: 0.8292285	best: 0.8304299 (20)	total: 38ms	remaining: 740ms
# 22:	test: 0.8291427	best: 0.8304299 (20)	total: 39.8ms	remaining: 739ms
# 23:	test: 0.8334335	best: 0.8334335 (23)	total: 43.2ms	remaining: 766ms
# 24:	test: 0.8346349	best: 0.8346349 (24)	total: 45.8ms	remaining: 779ms
# 25:	test: 0.8334335	best: 0.8346349 (24)	total: 50ms	remaining: 815ms
# 26:	test: 0.8367802	best: 0.8367802 (26)	total: 55.4ms	remaining: 868ms
# 27:	test: 0.8345490	best: 0.8367802 (26)	total: 57.3ms	remaining: 864ms
# 28:	test: 0.8332618	best: 0.8367802 (26)	total: 59ms	remaining: 857ms
# 29:	test: 0.8300009	best: 0.8367802 (26)	total: 60.8ms	remaining: 851ms
# 30:	test: 0.8320604	best: 0.8367802 (26)	total: 62.5ms	remaining: 844ms
# 31:	test: 0.8298292	best: 0.8367802 (26)	total: 64.2ms	remaining: 839ms
# 32:	test: 0.8283704	best: 0.8367802 (26)	total: 66ms	remaining: 834ms
# 33:	test: 0.8246803	best: 0.8367802 (26)	total: 67.7ms	remaining: 828ms
# 34:	test: 0.8225350	best: 0.8367802 (26)	total: 69.4ms	remaining: 823ms
# 35:	test: 0.8234789	best: 0.8367802 (26)	total: 71.1ms	remaining: 818ms
# 36:	test: 0.8281987	best: 0.8367802 (26)	total: 72.8ms	remaining: 813ms
# 37:	test: 0.8282846	best: 0.8367802 (26)	total: 74.4ms	remaining: 807ms
# 38:	test: 0.8280271	best: 0.8367802 (26)	total: 76.3ms	remaining: 805ms
# 39:	test: 0.8251094	best: 0.8367802 (26)	total: 78ms	remaining: 800ms
# 40:	test: 0.8257101	best: 0.8367802 (26)	total: 79.7ms	remaining: 795ms
# 41:	test: 0.8268257	best: 0.8367802 (26)	total: 81.3ms	remaining: 790ms
# 42:	test: 0.8276839	best: 0.8367802 (26)	total: 83.1ms	remaining: 786ms
# 43:	test: 0.8251952	best: 0.8367802 (26)	total: 84.7ms	remaining: 782ms
# 44:	test: 0.8283704	best: 0.8367802 (26)	total: 86.5ms	remaining: 778ms
# 45:	test: 0.8277697	best: 0.8367802 (26)	total: 88.1ms	remaining: 774ms
# 46:	test: 0.8258817	best: 0.8367802 (26)	total: 89.8ms	remaining: 770ms
# 47:	test: 0.8256243	best: 0.8367802 (26)	total: 91.5ms	remaining: 766ms
# 48:	test: 0.8255385	best: 0.8367802 (26)	total: 93.1ms	remaining: 762ms
# 49:	test: 0.8243371	best: 0.8367802 (26)	total: 94.8ms	remaining: 758ms
# 50:	test: 0.8227066	best: 0.8367802 (26)	total: 96.5ms	remaining: 755ms
# 51:	test: 0.8225350	best: 0.8367802 (26)	total: 98.2ms	remaining: 751ms
# 52:	test: 0.8259676	best: 0.8367802 (26)	total: 100ms	remaining: 749ms
# 53:	test: 0.8248520	best: 0.8367802 (26)	total: 102ms	remaining: 746ms
# 54:	test: 0.8248520	best: 0.8367802 (26)	total: 103ms	remaining: 743ms
# 55:	test: 0.8259676	best: 0.8367802 (26)	total: 105ms	remaining: 740ms
# 56:	test: 0.8267399	best: 0.8367802 (26)	total: 107ms	remaining: 738ms
# 57:	test: 0.8272548	best: 0.8367802 (26)	total: 109ms	remaining: 734ms
# 58:	test: 0.8290569	best: 0.8367802 (26)	total: 110ms	remaining: 731ms
# 59:	test: 0.8284562	best: 0.8367802 (26)	total: 112ms	remaining: 728ms
# 60:	test: 0.8246803	best: 0.8367802 (26)	total: 114ms	remaining: 725ms
# 61:	test: 0.8219343	best: 0.8367802 (26)	total: 115ms	remaining: 722ms
# 62:	test: 0.8231357	best: 0.8367802 (26)	total: 117ms	remaining: 719ms
# 63:	test: 0.8234789	best: 0.8367802 (26)	total: 119ms	remaining: 716ms
# 64:	test: 0.8256243	best: 0.8367802 (26)	total: 120ms	remaining: 713ms
# 65:	test: 0.8272548	best: 0.8367802 (26)	total: 122ms	remaining: 710ms
# 66:	test: 0.8262250	best: 0.8367802 (26)	total: 124ms	remaining: 708ms
# 67:	test: 0.8262250	best: 0.8367802 (26)	total: 126ms	remaining: 705ms
# 68:	test: 0.8276839	best: 0.8367802 (26)	total: 127ms	remaining: 703ms
# 69:	test: 0.8280271	best: 0.8367802 (26)	total: 129ms	remaining: 700ms
# 70:	test: 0.8267399	best: 0.8367802 (26)	total: 131ms	remaining: 697ms
# 71:	test: 0.8250236	best: 0.8367802 (26)	total: 132ms	remaining: 694ms
# 72:	test: 0.8226208	best: 0.8367802 (26)	total: 134ms	remaining: 691ms
# 73:	test: 0.8231357	best: 0.8367802 (26)	total: 135ms	remaining: 688ms
# 74:	test: 0.8228782	best: 0.8367802 (26)	total: 137ms	remaining: 686ms
# 75:	test: 0.8215910	best: 0.8367802 (26)	total: 139ms	remaining: 683ms
# 76:	test: 0.8242513	best: 0.8367802 (26)	total: 141ms	remaining: 683ms
# 77:	test: 0.8213336	best: 0.8367802 (26)	total: 143ms	remaining: 683ms
# 78:	test: 0.8197889	best: 0.8367802 (26)	total: 147ms	remaining: 692ms
# 79:	test: 0.8199605	best: 0.8367802 (26)	total: 151ms	remaining: 698ms
# 80:	test: 0.8193598	best: 0.8367802 (26)	total: 154ms	remaining: 703ms
# 81:	test: 0.8191024	best: 0.8367802 (26)	total: 158ms	remaining: 709ms
# 82:	test: 0.8195315	best: 0.8367802 (26)	total: 162ms	remaining: 715ms
# 83:	test: 0.8174719	best: 0.8367802 (26)	total: 164ms	remaining: 713ms
# 84:	test: 0.8155840	best: 0.8367802 (26)	total: 165ms	remaining: 709ms
# 85:	test: 0.8179010	best: 0.8367802 (26)	total: 167ms	remaining: 705ms
# 86:	test: 0.8172145	best: 0.8367802 (26)	total: 168ms	remaining: 701ms
# 87:	test: 0.8176435	best: 0.8367802 (26)	total: 170ms	remaining: 698ms
# 88:	test: 0.8188449	best: 0.8367802 (26)	total: 171ms	remaining: 695ms
# 89:	test: 0.8179868	best: 0.8367802 (26)	total: 173ms	remaining: 691ms
# 90:	test: 0.8183300	best: 0.8367802 (26)	total: 174ms	remaining: 688ms
# 91:	test: 0.8115507	best: 0.8367802 (26)	total: 176ms	remaining: 684ms
# 92:	test: 0.8115507	best: 0.8367802 (26)	total: 177ms	remaining: 680ms
# 93:	test: 0.8112932	best: 0.8367802 (26)	total: 179ms	remaining: 676ms
# 94:	test: 0.8108642	best: 0.8367802 (26)	total: 180ms	remaining: 673ms
# 95:	test: 0.8117223	best: 0.8367802 (26)	total: 181ms	remaining: 669ms
# 96:	test: 0.8110358	best: 0.8367802 (26)	total: 183ms	remaining: 665ms
# 97:	test: 0.8119797	best: 0.8367802 (26)	total: 184ms	remaining: 662ms
# 98:	test: 0.8137819	best: 0.8367802 (26)	total: 186ms	remaining: 659ms
# 99:	test: 0.8131812	best: 0.8367802 (26)	total: 188ms	remaining: 657ms
# 100:	test: 0.8136102	best: 0.8367802 (26)	total: 189ms	remaining: 654ms
# 101:	test: 0.8122372	best: 0.8367802 (26)	total: 192ms	remaining: 654ms
# 102:	test: 0.8116365	best: 0.8367802 (26)	total: 194ms	remaining: 653ms
# 103:	test: 0.8142109	best: 0.8367802 (26)	total: 196ms	remaining: 650ms
# 104:	test: 0.8139535	best: 0.8367802 (26)	total: 197ms	remaining: 648ms
# 105:	test: 0.8142109	best: 0.8367802 (26)	total: 199ms	remaining: 645ms
# 106:	test: 0.8143826	best: 0.8367802 (26)	total: 201ms	remaining: 643ms
# 107:	test: 0.8142109	best: 0.8367802 (26)	total: 202ms	remaining: 640ms
# 108:	test: 0.8156698	best: 0.8367802 (26)	total: 204ms	remaining: 638ms
# 109:	test: 0.8144684	best: 0.8367802 (26)	total: 206ms	remaining: 635ms
# 110:	test: 0.8141251	best: 0.8367802 (26)	total: 207ms	remaining: 633ms
# 111:	test: 0.8146400	best: 0.8367802 (26)	total: 209ms	remaining: 630ms
# 112:	test: 0.8144684	best: 0.8367802 (26)	total: 211ms	remaining: 628ms
# 113:	test: 0.8146400	best: 0.8367802 (26)	total: 212ms	remaining: 625ms
# 114:	test: 0.8133528	best: 0.8367802 (26)	total: 214ms	remaining: 623ms
# 115:	test: 0.8126663	best: 0.8367802 (26)	total: 215ms	remaining: 620ms
# 116:	test: 0.8131812	best: 0.8367802 (26)	total: 217ms	remaining: 618ms
# 117:	test: 0.8122372	best: 0.8367802 (26)	total: 219ms	remaining: 615ms
# 118:	test: 0.8129237	best: 0.8367802 (26)	total: 220ms	remaining: 613ms
# 119:	test: 0.8132670	best: 0.8367802 (26)	total: 222ms	remaining: 611ms
# 120:	test: 0.8125805	best: 0.8367802 (26)	total: 228ms	remaining: 620ms
# 121:	test: 0.8134386	best: 0.8367802 (26)	total: 230ms	remaining: 619ms
# 122:	test: 0.8115507	best: 0.8367802 (26)	total: 232ms	remaining: 618ms
# 123:	test: 0.8095769	best: 0.8367802 (26)	total: 234ms	remaining: 615ms
# 124:	test: 0.8097486	best: 0.8367802 (26)	total: 236ms	remaining: 613ms
# 125:	test: 0.8103493	best: 0.8367802 (26)	total: 238ms	remaining: 612ms
# 126:	test: 0.8106067	best: 0.8367802 (26)	total: 240ms	remaining: 610ms
# 127:	test: 0.8113790	best: 0.8367802 (26)	total: 243ms	remaining: 611ms
# 128:	test: 0.8106067	best: 0.8367802 (26)	total: 244ms	remaining: 608ms
# 129:	test: 0.8106067	best: 0.8367802 (26)	total: 246ms	remaining: 606ms
# 130:	test: 0.8097486	best: 0.8367802 (26)	total: 248ms	remaining: 604ms
# 131:	test: 0.8108642	best: 0.8367802 (26)	total: 250ms	remaining: 601ms
# 132:	test: 0.8100060	best: 0.8367802 (26)	total: 251ms	remaining: 599ms
# 133:	test: 0.8111216	best: 0.8367802 (26)	total: 253ms	remaining: 597ms
# 134:	test: 0.8086330	best: 0.8367802 (26)	total: 255ms	remaining: 595ms
# 135:	test: 0.8075174	best: 0.8367802 (26)	total: 257ms	remaining: 593ms
# 136:	test: 0.8077748	best: 0.8367802 (26)	total: 259ms	remaining: 591ms
# 137:	test: 0.8078606	best: 0.8367802 (26)	total: 260ms	remaining: 589ms
# 138:	test: 0.8079465	best: 0.8367802 (26)	total: 262ms	remaining: 586ms
# 139:	test: 0.8070883	best: 0.8367802 (26)	total: 264ms	remaining: 584ms
# 140:	test: 0.8075174	best: 0.8367802 (26)	total: 265ms	remaining: 582ms
# 141:	test: 0.8072599	best: 0.8367802 (26)	total: 267ms	remaining: 579ms
# 142:	test: 0.8064018	best: 0.8367802 (26)	total: 269ms	remaining: 577ms
# 143:	test: 0.8055436	best: 0.8367802 (26)	total: 271ms	remaining: 576ms
# 144:	test: 0.8082897	best: 0.8367802 (26)	total: 273ms	remaining: 574ms
# 145:	test: 0.8073457	best: 0.8367802 (26)	total: 274ms	remaining: 571ms
# 146:	test: 0.8063160	best: 0.8367802 (26)	total: 276ms	remaining: 570ms
# 147:	test: 0.8078606	best: 0.8367802 (26)	total: 278ms	remaining: 568ms
# 148:	test: 0.8065734	best: 0.8367802 (26)	total: 281ms	remaining: 567ms
# 149:	test: 0.8058869	best: 0.8367802 (26)	total: 283ms	remaining: 565ms
# 150:	test: 0.8052004	best: 0.8367802 (26)	total: 284ms	remaining: 563ms
# 151:	test: 0.8045997	best: 0.8367802 (26)	total: 286ms	remaining: 561ms
# 152:	test: 0.8068309	best: 0.8367802 (26)	total: 288ms	remaining: 558ms
# 153:	test: 0.8070883	best: 0.8367802 (26)	total: 289ms	remaining: 556ms
# 154:	test: 0.8076032	best: 0.8367802 (26)	total: 291ms	remaining: 554ms
# 155:	test: 0.8067450	best: 0.8367802 (26)	total: 293ms	remaining: 552ms
# 156:	test: 0.8067450	best: 0.8367802 (26)	total: 294ms	remaining: 549ms
# 157:	test: 0.8074316	best: 0.8367802 (26)	total: 296ms	remaining: 547ms
# 158:	test: 0.8075174	best: 0.8367802 (26)	total: 298ms	remaining: 545ms
# 159:	test: 0.8061443	best: 0.8367802 (26)	total: 299ms	remaining: 543ms
# 160:	test: 0.8049429	best: 0.8367802 (26)	total: 301ms	remaining: 540ms
# 161:	test: 0.8055436	best: 0.8367802 (26)	total: 303ms	remaining: 538ms
# 162:	test: 0.8083755	best: 0.8367802 (26)	total: 304ms	remaining: 536ms
# 163:	test: 0.8078606	best: 0.8367802 (26)	total: 306ms	remaining: 534ms
# 164:	test: 0.8066592	best: 0.8367802 (26)	total: 308ms	remaining: 531ms
# 165:	test: 0.8073457	best: 0.8367802 (26)	total: 309ms	remaining: 529ms
# 166:	test: 0.8085472	best: 0.8367802 (26)	total: 311ms	remaining: 527ms
# 167:	test: 0.8099202	best: 0.8367802 (26)	total: 312ms	remaining: 524ms
# 168:	test: 0.8096627	best: 0.8367802 (26)	total: 314ms	remaining: 522ms
# 169:	test: 0.8114649	best: 0.8367802 (26)	total: 316ms	remaining: 520ms
# 170:	test: 0.8122372	best: 0.8367802 (26)	total: 317ms	remaining: 518ms
# 171:	test: 0.8144684	best: 0.8367802 (26)	total: 319ms	remaining: 515ms
# 172:	test: 0.8142967	best: 0.8367802 (26)	total: 320ms	remaining: 513ms
# 173:	test: 0.8139535	best: 0.8367802 (26)	total: 323ms	remaining: 512ms
# 174:	test: 0.8133528	best: 0.8367802 (26)	total: 325ms	remaining: 510ms
# 175:	test: 0.8135244	best: 0.8367802 (26)	total: 326ms	remaining: 508ms
# 176:	test: 0.8133528	best: 0.8367802 (26)	total: 328ms	remaining: 506ms
# 177:	test: 0.8128379	best: 0.8367802 (26)	total: 330ms	remaining: 504ms
# 178:	test: 0.8122372	best: 0.8367802 (26)	total: 332ms	remaining: 502ms
# 179:	test: 0.8124088	best: 0.8367802 (26)	total: 333ms	remaining: 500ms
# 180:	test: 0.8130095	best: 0.8367802 (26)	total: 335ms	remaining: 498ms
# 181:	test: 0.8133528	best: 0.8367802 (26)	total: 337ms	remaining: 496ms
# 182:	test: 0.8143826	best: 0.8367802 (26)	total: 339ms	remaining: 494ms
# 183:	test: 0.8148116	best: 0.8367802 (26)	total: 340ms	remaining: 492ms
# 184:	test: 0.8118081	best: 0.8367802 (26)	total: 342ms	remaining: 490ms
# 185:	test: 0.8143826	best: 0.8367802 (26)	total: 344ms	remaining: 488ms
# 186:	test: 0.8151549	best: 0.8367802 (26)	total: 346ms	remaining: 486ms
# 187:	test: 0.8148975	best: 0.8367802 (26)	total: 348ms	remaining: 485ms
# 188:	test: 0.8159272	best: 0.8367802 (26)	total: 350ms	remaining: 483ms
# 189:	test: 0.8151549	best: 0.8367802 (26)	total: 351ms	remaining: 481ms
# 190:	test: 0.8145542	best: 0.8367802 (26)	total: 353ms	remaining: 479ms
# 191:	test: 0.8146400	best: 0.8367802 (26)	total: 355ms	remaining: 477ms
# 192:	test: 0.8141251	best: 0.8367802 (26)	total: 357ms	remaining: 476ms
# 193:	test: 0.8133528	best: 0.8367802 (26)	total: 359ms	remaining: 474ms
# 194:	test: 0.8118939	best: 0.8367802 (26)	total: 361ms	remaining: 473ms
# 195:	test: 0.8126663	best: 0.8367802 (26)	total: 364ms	remaining: 472ms
# 196:	test: 0.8100918	best: 0.8367802 (26)	total: 366ms	remaining: 470ms
# 197:	test: 0.8112074	best: 0.8367802 (26)	total: 367ms	remaining: 468ms
# 198:	test: 0.8110358	best: 0.8367802 (26)	total: 369ms	remaining: 466ms
# 199:	test: 0.8093195	best: 0.8367802 (26)	total: 371ms	remaining: 464ms
# 200:	test: 0.8100918	best: 0.8367802 (26)	total: 373ms	remaining: 462ms
# 201:	test: 0.8088046	best: 0.8367802 (26)	total: 375ms	remaining: 460ms
# 202:	test: 0.8083755	best: 0.8367802 (26)	total: 376ms	remaining: 458ms
# 203:	test: 0.8083755	best: 0.8367802 (26)	total: 378ms	remaining: 456ms
# 204:	test: 0.8087188	best: 0.8367802 (26)	total: 380ms	remaining: 454ms
# 205:	test: 0.8099202	best: 0.8367802 (26)	total: 381ms	remaining: 452ms
# 206:	test: 0.8120656	best: 0.8367802 (26)	total: 383ms	remaining: 450ms
# 207:	test: 0.8131812	best: 0.8367802 (26)	total: 385ms	remaining: 448ms
# 208:	test: 0.8129237	best: 0.8367802 (26)	total: 386ms	remaining: 445ms
# 209:	test: 0.8115507	best: 0.8367802 (26)	total: 388ms	remaining: 443ms
# 210:	test: 0.8130953	best: 0.8367802 (26)	total: 390ms	remaining: 441ms
# 211:	test: 0.8115507	best: 0.8367802 (26)	total: 391ms	remaining: 439ms
# 212:	test: 0.8114649	best: 0.8367802 (26)	total: 393ms	remaining: 437ms
# 213:	test: 0.8116365	best: 0.8367802 (26)	total: 395ms	remaining: 435ms
# 214:	test: 0.8116365	best: 0.8367802 (26)	total: 397ms	remaining: 433ms
# 215:	test: 0.8116365	best: 0.8367802 (26)	total: 398ms	remaining: 431ms
# 216:	test: 0.8125805	best: 0.8367802 (26)	total: 400ms	remaining: 429ms
# 217:	test: 0.8120656	best: 0.8367802 (26)	total: 402ms	remaining: 427ms
# 218:	test: 0.8128379	best: 0.8367802 (26)	total: 403ms	remaining: 425ms
# 219:	test: 0.8118939	best: 0.8367802 (26)	total: 405ms	remaining: 424ms
# 220:	test: 0.8116365	best: 0.8367802 (26)	total: 408ms	remaining: 423ms
# 221:	test: 0.8116365	best: 0.8367802 (26)	total: 411ms	remaining: 422ms
# 222:	test: 0.8105209	best: 0.8367802 (26)	total: 413ms	remaining: 420ms
# 223:	test: 0.8105209	best: 0.8367802 (26)	total: 420ms	remaining: 424ms
# 224:	test: 0.8112074	best: 0.8367802 (26)	total: 424ms	remaining: 424ms
# 225:	test: 0.8133528	best: 0.8367802 (26)	total: 426ms	remaining: 422ms
# 226:	test: 0.8140393	best: 0.8367802 (26)	total: 428ms	remaining: 420ms
# 227:	test: 0.8151549	best: 0.8367802 (26)	total: 430ms	remaining: 419ms
# 228:	test: 0.8161847	best: 0.8367802 (26)	total: 432ms	remaining: 417ms
# 229:	test: 0.8160989	best: 0.8367802 (26)	total: 434ms	remaining: 415ms
# 230:	test: 0.8150691	best: 0.8367802 (26)	total: 435ms	remaining: 413ms
# 231:	test: 0.8148116	best: 0.8367802 (26)	total: 437ms	remaining: 411ms
# 232:	test: 0.8142967	best: 0.8367802 (26)	total: 439ms	remaining: 409ms
# 233:	test: 0.8141251	best: 0.8367802 (26)	total: 441ms	remaining: 407ms
# 234:	test: 0.8154123	best: 0.8367802 (26)	total: 442ms	remaining: 405ms
# 235:	test: 0.8150691	best: 0.8367802 (26)	total: 444ms	remaining: 403ms
# 236:	test: 0.8154123	best: 0.8367802 (26)	total: 446ms	remaining: 401ms
# 237:	test: 0.8151549	best: 0.8367802 (26)	total: 447ms	remaining: 398ms
# 238:	test: 0.8149833	best: 0.8367802 (26)	total: 449ms	remaining: 396ms
# 239:	test: 0.8144684	best: 0.8367802 (26)	total: 451ms	remaining: 394ms
# 240:	test: 0.8150691	best: 0.8367802 (26)	total: 453ms	remaining: 392ms
# 241:	test: 0.8138677	best: 0.8367802 (26)	total: 454ms	remaining: 390ms
# 242:	test: 0.8136102	best: 0.8367802 (26)	total: 456ms	remaining: 388ms
# 243:	test: 0.8130953	best: 0.8367802 (26)	total: 458ms	remaining: 387ms
# 244:	test: 0.8142109	best: 0.8367802 (26)	total: 460ms	remaining: 385ms
# 245:	test: 0.8142967	best: 0.8367802 (26)	total: 461ms	remaining: 382ms
# 246:	test: 0.8132670	best: 0.8367802 (26)	total: 463ms	remaining: 380ms
# 247:	test: 0.8150691	best: 0.8367802 (26)	total: 465ms	remaining: 378ms
# 248:	test: 0.8154123	best: 0.8367802 (26)	total: 466ms	remaining: 377ms
# 249:	test: 0.8130953	best: 0.8367802 (26)	total: 468ms	remaining: 374ms
# 250:	test: 0.8129237	best: 0.8367802 (26)	total: 470ms	remaining: 372ms
# 251:	test: 0.8132670	best: 0.8367802 (26)	total: 471ms	remaining: 370ms
# 252:	test: 0.8130953	best: 0.8367802 (26)	total: 473ms	remaining: 368ms
# 253:	test: 0.8125805	best: 0.8367802 (26)	total: 475ms	remaining: 366ms
# 254:	test: 0.8142967	best: 0.8367802 (26)	total: 477ms	remaining: 364ms
# 255:	test: 0.8136960	best: 0.8367802 (26)	total: 478ms	remaining: 362ms
# 256:	test: 0.8141251	best: 0.8367802 (26)	total: 480ms	remaining: 360ms
# 257:	test: 0.8145542	best: 0.8367802 (26)	total: 481ms	remaining: 358ms
# 258:	test: 0.8131812	best: 0.8367802 (26)	total: 483ms	remaining: 356ms
# 259:	test: 0.8124946	best: 0.8367802 (26)	total: 485ms	remaining: 354ms
# 260:	test: 0.8123230	best: 0.8367802 (26)	total: 487ms	remaining: 352ms
# 261:	test: 0.8125805	best: 0.8367802 (26)	total: 488ms	remaining: 350ms
# 262:	test: 0.8134386	best: 0.8367802 (26)	total: 490ms	remaining: 348ms
# 263:	test: 0.8126663	best: 0.8367802 (26)	total: 492ms	remaining: 346ms
# 264:	test: 0.8146400	best: 0.8367802 (26)	total: 493ms	remaining: 344ms
# 265:	test: 0.8146400	best: 0.8367802 (26)	total: 495ms	remaining: 342ms
# 266:	test: 0.8147258	best: 0.8367802 (26)	total: 496ms	remaining: 340ms
# 267:	test: 0.8136102	best: 0.8367802 (26)	total: 498ms	remaining: 338ms
# 268:	test: 0.8137819	best: 0.8367802 (26)	total: 499ms	remaining: 336ms
# 269:	test: 0.8135244	best: 0.8367802 (26)	total: 501ms	remaining: 334ms
# 270:	test: 0.8136960	best: 0.8367802 (26)	total: 504ms	remaining: 333ms
# 271:	test: 0.8146400	best: 0.8367802 (26)	total: 506ms	remaining: 331ms
# 272:	test: 0.8148116	best: 0.8367802 (26)	total: 508ms	remaining: 330ms
# 273:	test: 0.8148975	best: 0.8367802 (26)	total: 510ms	remaining: 328ms
# 274:	test: 0.8140393	best: 0.8367802 (26)	total: 512ms	remaining: 326ms
# 275:	test: 0.8149833	best: 0.8367802 (26)	total: 514ms	remaining: 324ms
# 276:	test: 0.8150691	best: 0.8367802 (26)	total: 516ms	remaining: 322ms
# 277:	test: 0.8159272	best: 0.8367802 (26)	total: 518ms	remaining: 321ms
# 278:	test: 0.8148975	best: 0.8367802 (26)	total: 520ms	remaining: 319ms
# 279:	test: 0.8125805	best: 0.8367802 (26)	total: 522ms	remaining: 317ms
# 280:	test: 0.8124088	best: 0.8367802 (26)	total: 524ms	remaining: 315ms
# 281:	test: 0.8130095	best: 0.8367802 (26)	total: 525ms	remaining: 313ms
# 282:	test: 0.8142967	best: 0.8367802 (26)	total: 527ms	remaining: 311ms
# 283:	test: 0.8160989	best: 0.8367802 (26)	total: 529ms	remaining: 309ms
# 284:	test: 0.8162705	best: 0.8367802 (26)	total: 531ms	remaining: 307ms
# 285:	test: 0.8154123	best: 0.8367802 (26)	total: 532ms	remaining: 305ms
# 286:	test: 0.8154982	best: 0.8367802 (26)	total: 534ms	remaining: 303ms
# 287:	test: 0.8153265	best: 0.8367802 (26)	total: 536ms	remaining: 301ms
# 288:	test: 0.8159272	best: 0.8367802 (26)	total: 537ms	remaining: 299ms
# 289:	test: 0.8148975	best: 0.8367802 (26)	total: 539ms	remaining: 297ms
# 290:	test: 0.8158414	best: 0.8367802 (26)	total: 541ms	remaining: 295ms
# 291:	test: 0.8164421	best: 0.8367802 (26)	total: 542ms	remaining: 293ms
# 292:	test: 0.8143826	best: 0.8367802 (26)	total: 544ms	remaining: 291ms
# 293:	test: 0.8148116	best: 0.8367802 (26)	total: 546ms	remaining: 290ms
# 294:	test: 0.8150691	best: 0.8367802 (26)	total: 548ms	remaining: 288ms
# 295:	test: 0.8144684	best: 0.8367802 (26)	total: 549ms	remaining: 286ms
# 296:	test: 0.8141251	best: 0.8367802 (26)	total: 551ms	remaining: 284ms
# 297:	test: 0.8139535	best: 0.8367802 (26)	total: 553ms	remaining: 282ms
# 298:	test: 0.8148975	best: 0.8367802 (26)	total: 554ms	remaining: 280ms
# 299:	test: 0.8146400	best: 0.8367802 (26)	total: 556ms	remaining: 278ms
# 300:	test: 0.8143826	best: 0.8367802 (26)	total: 558ms	remaining: 276ms
# 301:	test: 0.8157556	best: 0.8367802 (26)	total: 559ms	remaining: 274ms
# 302:	test: 0.8158414	best: 0.8367802 (26)	total: 561ms	remaining: 272ms
# 303:	test: 0.8167854	best: 0.8367802 (26)	total: 563ms	remaining: 270ms
# 304:	test: 0.8169570	best: 0.8367802 (26)	total: 564ms	remaining: 268ms
# 305:	test: 0.8154123	best: 0.8367802 (26)	total: 566ms	remaining: 266ms
# 306:	test: 0.8131812	best: 0.8367802 (26)	total: 568ms	remaining: 265ms
# 307:	test: 0.8136102	best: 0.8367802 (26)	total: 570ms	remaining: 263ms
# 308:	test: 0.8131812	best: 0.8367802 (26)	total: 571ms	remaining: 261ms
# 309:	test: 0.8133528	best: 0.8367802 (26)	total: 573ms	remaining: 259ms
# 310:	test: 0.8131812	best: 0.8367802 (26)	total: 575ms	remaining: 257ms
# 311:	test: 0.8146400	best: 0.8367802 (26)	total: 577ms	remaining: 255ms
# 312:	test: 0.8148975	best: 0.8367802 (26)	total: 578ms	remaining: 253ms
# 313:	test: 0.8141251	best: 0.8367802 (26)	total: 580ms	remaining: 251ms
# 314:	test: 0.8132670	best: 0.8367802 (26)	total: 582ms	remaining: 249ms
# 315:	test: 0.8134386	best: 0.8367802 (26)	total: 584ms	remaining: 247ms
# 316:	test: 0.8113790	best: 0.8367802 (26)	total: 585ms	remaining: 246ms
# 317:	test: 0.8112932	best: 0.8367802 (26)	total: 587ms	remaining: 244ms
# 318:	test: 0.8091479	best: 0.8367802 (26)	total: 589ms	remaining: 242ms
# 319:	test: 0.8090620	best: 0.8367802 (26)	total: 591ms	remaining: 240ms
# 320:	test: 0.8088046	best: 0.8367802 (26)	total: 594ms	remaining: 239ms
# 321:	test: 0.8084613	best: 0.8367802 (26)	total: 597ms	remaining: 237ms
# 322:	test: 0.8085472	best: 0.8367802 (26)	total: 600ms	remaining: 236ms
# 323:	test: 0.8080323	best: 0.8367802 (26)	total: 604ms	remaining: 235ms
# 324:	test: 0.8080323	best: 0.8367802 (26)	total: 607ms	remaining: 233ms
# 325:	test: 0.8113790	best: 0.8367802 (26)	total: 608ms	remaining: 231ms
# 326:	test: 0.8121514	best: 0.8367802 (26)	total: 610ms	remaining: 229ms
# 327:	test: 0.8094911	best: 0.8367802 (26)	total: 612ms	remaining: 228ms
# 328:	test: 0.8117223	best: 0.8367802 (26)	total: 614ms	remaining: 226ms
# 329:	test: 0.8107783	best: 0.8367802 (26)	total: 615ms	remaining: 224ms
# 330:	test: 0.8116365	best: 0.8367802 (26)	total: 617ms	remaining: 222ms
# 331:	test: 0.8123230	best: 0.8367802 (26)	total: 619ms	remaining: 220ms
# 332:	test: 0.8118081	best: 0.8367802 (26)	total: 621ms	remaining: 218ms
# 333:	test: 0.8118081	best: 0.8367802 (26)	total: 622ms	remaining: 216ms
# 334:	test: 0.8109500	best: 0.8367802 (26)	total: 624ms	remaining: 214ms
# 335:	test: 0.8093195	best: 0.8367802 (26)	total: 626ms	remaining: 212ms
# 336:	test: 0.8098344	best: 0.8367802 (26)	total: 628ms	remaining: 210ms
# 337:	test: 0.8106067	best: 0.8367802 (26)	total: 629ms	remaining: 209ms
# 338:	test: 0.8090620	best: 0.8367802 (26)	total: 631ms	remaining: 207ms
# 339:	test: 0.8069167	best: 0.8367802 (26)	total: 633ms	remaining: 205ms
# 340:	test: 0.8073457	best: 0.8367802 (26)	total: 635ms	remaining: 203ms
# 341:	test: 0.8072599	best: 0.8367802 (26)	total: 637ms	remaining: 201ms
# 342:	test: 0.8072599	best: 0.8367802 (26)	total: 638ms	remaining: 199ms
# 343:	test: 0.8076890	best: 0.8367802 (26)	total: 640ms	remaining: 197ms
# 344:	test: 0.8094911	best: 0.8367802 (26)	total: 642ms	remaining: 195ms
# 345:	test: 0.8088046	best: 0.8367802 (26)	total: 644ms	remaining: 194ms
# 346:	test: 0.8087188	best: 0.8367802 (26)	total: 646ms	remaining: 192ms
# 347:	test: 0.8088904	best: 0.8367802 (26)	total: 648ms	remaining: 190ms
# 348:	test: 0.8075174	best: 0.8367802 (26)	total: 650ms	remaining: 188ms
# 349:	test: 0.8058011	best: 0.8367802 (26)	total: 652ms	remaining: 186ms
# 350:	test: 0.8060585	best: 0.8367802 (26)	total: 654ms	remaining: 184ms
# 351:	test: 0.8059727	best: 0.8367802 (26)	total: 656ms	remaining: 183ms
# 352:	test: 0.8043422	best: 0.8367802 (26)	total: 657ms	remaining: 181ms
# 353:	test: 0.8039990	best: 0.8367802 (26)	total: 659ms	remaining: 179ms
# 354:	test: 0.8020252	best: 0.8367802 (26)	total: 661ms	remaining: 177ms
# 355:	test: 0.8015962	best: 0.8367802 (26)	total: 664ms	remaining: 175ms
# 356:	test: 0.8023685	best: 0.8367802 (26)	total: 666ms	remaining: 173ms
# 357:	test: 0.8021969	best: 0.8367802 (26)	total: 668ms	remaining: 172ms
# 358:	test: 0.8024543	best: 0.8367802 (26)	total: 669ms	remaining: 170ms
# 359:	test: 0.8004806	best: 0.8367802 (26)	total: 671ms	remaining: 168ms
# 360:	test: 0.8004806	best: 0.8367802 (26)	total: 673ms	remaining: 166ms
# 361:	test: 0.8003947	best: 0.8367802 (26)	total: 675ms	remaining: 164ms
# 362:	test: 0.8004806	best: 0.8367802 (26)	total: 677ms	remaining: 162ms
# 363:	test: 0.8008238	best: 0.8367802 (26)	total: 678ms	remaining: 160ms
# 364:	test: 0.7995366	best: 0.8367802 (26)	total: 680ms	remaining: 158ms
# 365:	test: 0.8010813	best: 0.8367802 (26)	total: 682ms	remaining: 157ms
# 366:	test: 0.8005664	best: 0.8367802 (26)	total: 684ms	remaining: 155ms
# 367:	test: 0.7999657	best: 0.8367802 (26)	total: 686ms	remaining: 153ms
# 368:	test: 0.7996224	best: 0.8367802 (26)	total: 688ms	remaining: 151ms
# 369:	test: 0.8006522	best: 0.8367802 (26)	total: 690ms	remaining: 149ms
# 370:	test: 0.8002231	best: 0.8367802 (26)	total: 692ms	remaining: 147ms
# 371:	test: 0.8003947	best: 0.8367802 (26)	total: 694ms	remaining: 146ms
# 372:	test: 0.8005664	best: 0.8367802 (26)	total: 696ms	remaining: 144ms
# 373:	test: 0.8003089	best: 0.8367802 (26)	total: 698ms	remaining: 142ms
# 374:	test: 0.8003947	best: 0.8367802 (26)	total: 699ms	remaining: 140ms
# 375:	test: 0.7998799	best: 0.8367802 (26)	total: 701ms	remaining: 138ms
# 376:	test: 0.8001373	best: 0.8367802 (26)	total: 703ms	remaining: 136ms
# 377:	test: 0.8005664	best: 0.8367802 (26)	total: 705ms	remaining: 134ms
# 378:	test: 0.7994508	best: 0.8367802 (26)	total: 707ms	remaining: 132ms
# 379:	test: 0.7991075	best: 0.8367802 (26)	total: 709ms	remaining: 131ms
# 380:	test: 0.7993650	best: 0.8367802 (26)	total: 711ms	remaining: 129ms
# 381:	test: 0.7994508	best: 0.8367802 (26)	total: 713ms	remaining: 127ms
# 382:	test: 0.7995366	best: 0.8367802 (26)	total: 714ms	remaining: 125ms
# 383:	test: 0.7997940	best: 0.8367802 (26)	total: 716ms	remaining: 123ms
# 384:	test: 0.7986785	best: 0.8367802 (26)	total: 718ms	remaining: 121ms
# 385:	test: 0.7979919	best: 0.8367802 (26)	total: 720ms	remaining: 119ms
# 386:	test: 0.7973912	best: 0.8367802 (26)	total: 721ms	remaining: 117ms
# 387:	test: 0.7976487	best: 0.8367802 (26)	total: 723ms	remaining: 116ms
# 388:	test: 0.7979919	best: 0.8367802 (26)	total: 725ms	remaining: 114ms
# 389:	test: 0.7984210	best: 0.8367802 (26)	total: 727ms	remaining: 112ms
# 390:	test: 0.7983352	best: 0.8367802 (26)	total: 729ms	remaining: 110ms
# 391:	test: 0.7985926	best: 0.8367802 (26)	total: 731ms	remaining: 108ms
# 392:	test: 0.7977345	best: 0.8367802 (26)	total: 733ms	remaining: 106ms
# 393:	test: 0.7975629	best: 0.8367802 (26)	total: 735ms	remaining: 104ms
# 394:	test: 0.7974770	best: 0.8367802 (26)	total: 737ms	remaining: 103ms
# 395:	test: 0.7977345	best: 0.8367802 (26)	total: 739ms	remaining: 101ms
# 396:	test: 0.7962756	best: 0.8367802 (26)	total: 741ms	remaining: 98.9ms
# 397:	test: 0.7967047	best: 0.8367802 (26)	total: 742ms	remaining: 97ms
# 398:	test: 0.7961898	best: 0.8367802 (26)	total: 744ms	remaining: 95.1ms
# 399:	test: 0.7959324	best: 0.8367802 (26)	total: 746ms	remaining: 93.2ms
# 400:	test: 0.7970480	best: 0.8367802 (26)	total: 748ms	remaining: 91.4ms
# 401:	test: 0.7963615	best: 0.8367802 (26)	total: 750ms	remaining: 89.5ms
# 402:	test: 0.7961898	best: 0.8367802 (26)	total: 752ms	remaining: 87.7ms
# 403:	test: 0.7980777	best: 0.8367802 (26)	total: 754ms	remaining: 85.8ms
# 404:	test: 0.7975629	best: 0.8367802 (26)	total: 756ms	remaining: 84ms
# 405:	test: 0.7998799	best: 0.8367802 (26)	total: 757ms	remaining: 82.1ms
# 406:	test: 0.8011671	best: 0.8367802 (26)	total: 759ms	remaining: 80.2ms
# 407:	test: 0.8005664	best: 0.8367802 (26)	total: 761ms	remaining: 78.4ms
# 408:	test: 0.8000515	best: 0.8367802 (26)	total: 763ms	remaining: 76.5ms
# 409:	test: 0.8007380	best: 0.8367802 (26)	total: 765ms	remaining: 74.6ms
# 410:	test: 0.8002231	best: 0.8367802 (26)	total: 767ms	remaining: 72.7ms
# 411:	test: 0.7999657	best: 0.8367802 (26)	total: 768ms	remaining: 70.9ms
# 412:	test: 0.7999657	best: 0.8367802 (26)	total: 770ms	remaining: 69ms
# 413:	test: 0.7989359	best: 0.8367802 (26)	total: 772ms	remaining: 67.1ms
# 414:	test: 0.8004806	best: 0.8367802 (26)	total: 779ms	remaining: 65.7ms
# 415:	test: 0.8003089	best: 0.8367802 (26)	total: 783ms	remaining: 64ms
# 416:	test: 0.8005664	best: 0.8367802 (26)	total: 785ms	remaining: 62.1ms
# 417:	test: 0.7997940	best: 0.8367802 (26)	total: 788ms	remaining: 60.3ms
# 418:	test: 0.8007380	best: 0.8367802 (26)	total: 790ms	remaining: 58.5ms
# 419:	test: 0.8005664	best: 0.8367802 (26)	total: 792ms	remaining: 56.5ms
# 420:	test: 0.7999657	best: 0.8367802 (26)	total: 793ms	remaining: 54.6ms
# 421:	test: 0.7995366	best: 0.8367802 (26)	total: 796ms	remaining: 52.8ms
# 422:	test: 0.7994508	best: 0.8367802 (26)	total: 798ms	remaining: 50.9ms
# 423:	test: 0.7993650	best: 0.8367802 (26)	total: 800ms	remaining: 49ms
# 424:	test: 0.7982494	best: 0.8367802 (26)	total: 801ms	remaining: 47.1ms
# 425:	test: 0.7979919	best: 0.8367802 (26)	total: 803ms	remaining: 45.2ms
# 426:	test: 0.7991933	best: 0.8367802 (26)	total: 805ms	remaining: 43.4ms
# 427:	test: 0.7998799	best: 0.8367802 (26)	total: 807ms	remaining: 41.5ms
# 428:	test: 0.8004806	best: 0.8367802 (26)	total: 809ms	remaining: 39.6ms
# 429:	test: 0.8004806	best: 0.8367802 (26)	total: 812ms	remaining: 37.8ms
# 430:	test: 0.8003947	best: 0.8367802 (26)	total: 814ms	remaining: 35.9ms
# 431:	test: 0.8002231	best: 0.8367802 (26)	total: 815ms	remaining: 34ms
# 432:	test: 0.8000515	best: 0.8367802 (26)	total: 817ms	remaining: 32.1ms
# 433:	test: 0.7985926	best: 0.8367802 (26)	total: 819ms	remaining: 30.2ms
# 434:	test: 0.7984210	best: 0.8367802 (26)	total: 821ms	remaining: 28.3ms
# 435:	test: 0.7984210	best: 0.8367802 (26)	total: 822ms	remaining: 26.4ms
# 436:	test: 0.7983352	best: 0.8367802 (26)	total: 824ms	remaining: 24.5ms
# 437:	test: 0.7980777	best: 0.8367802 (26)	total: 826ms	remaining: 22.6ms
# 438:	test: 0.7982494	best: 0.8367802 (26)	total: 828ms	remaining: 20.7ms
# 439:	test: 0.7982494	best: 0.8367802 (26)	total: 829ms	remaining: 18.8ms
# 440:	test: 0.7988501	best: 0.8367802 (26)	total: 831ms	remaining: 17ms
# 441:	test: 0.7986785	best: 0.8367802 (26)	total: 833ms	remaining: 15.1ms
# 442:	test: 0.7970480	best: 0.8367802 (26)	total: 835ms	remaining: 13.2ms
# 443:	test: 0.7966189	best: 0.8367802 (26)	total: 837ms	remaining: 11.3ms
# 444:	test: 0.7959324	best: 0.8367802 (26)	total: 838ms	remaining: 9.42ms
# 445:	test: 0.7955891	best: 0.8367802 (26)	total: 840ms	remaining: 7.53ms
# 446:	test: 0.7942161	best: 0.8367802 (26)	total: 842ms	remaining: 5.65ms
# 447:	test: 0.7947310	best: 0.8367802 (26)	total: 844ms	remaining: 3.77ms
# 448:	test: 0.7961898	best: 0.8367802 (26)	total: 846ms	remaining: 1.88ms
# 449:	test: 0.7956749	best: 0.8367802 (26)	total: 847ms	remaining: 0us
#
# bestTest = 0.8367802283
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# 0:	test: 0.6985491	best: 0.6985491 (0)	total: 1.7ms	remaining: 766ms
# 1:	test: 0.7708823	best: 0.7708823 (1)	total: 3.69ms	remaining: 828ms
# 2:	test: 0.8084535	best: 0.8084535 (2)	total: 5.18ms	remaining: 772ms
# 3:	test: 0.7991446	best: 0.8084535 (2)	total: 6.79ms	remaining: 758ms
# 4:	test: 0.7952868	best: 0.8084535 (2)	total: 8.75ms	remaining: 778ms
# 5:	test: 0.7939031	best: 0.8084535 (2)	total: 10.5ms	remaining: 775ms
# 6:	test: 0.8056441	best: 0.8084535 (2)	total: 12.2ms	remaining: 774ms
# 7:	test: 0.8200688	best: 0.8200688 (7)	total: 13.9ms	remaining: 768ms
# 8:	test: 0.8209913	best: 0.8209913 (8)	total: 15.7ms	remaining: 768ms
# 9:	test: 0.8215783	best: 0.8215783 (9)	total: 17.3ms	remaining: 761ms
# 10:	test: 0.8237588	best: 0.8237588 (10)	total: 18.9ms	remaining: 754ms
# 11:	test: 0.8351224	best: 0.8351224 (11)	total: 20.7ms	remaining: 755ms
# 12:	test: 0.8391479	best: 0.8391479 (12)	total: 22.3ms	remaining: 750ms
# 13:	test: 0.8380577	best: 0.8391479 (12)	total: 24ms	remaining: 748ms
# 14:	test: 0.8372191	best: 0.8391479 (12)	total: 25.6ms	remaining: 743ms
# 15:	test: 0.8376384	best: 0.8391479 (12)	total: 27.3ms	remaining: 741ms
# 16:	test: 0.8378900	best: 0.8391479 (12)	total: 28.9ms	remaining: 736ms
# 17:	test: 0.8362965	best: 0.8391479 (12)	total: 30.5ms	remaining: 732ms
# 18:	test: 0.8409091	best: 0.8409091 (18)	total: 32.2ms	remaining: 731ms
# 19:	test: 0.8445153	best: 0.8445153 (19)	total: 33.9ms	remaining: 729ms
# 20:	test: 0.8505535	best: 0.8505535 (20)	total: 35.7ms	remaining: 729ms
# 21:	test: 0.8490439	best: 0.8505535 (20)	total: 37.2ms	remaining: 724ms
# 22:	test: 0.8534049	best: 0.8534049 (22)	total: 38.8ms	remaining: 721ms
# 23:	test: 0.8536565	best: 0.8536565 (23)	total: 40.4ms	remaining: 717ms
# 24:	test: 0.8567595	best: 0.8567595 (24)	total: 42ms	remaining: 714ms
# 25:	test: 0.8575981	best: 0.8575981 (25)	total: 43.6ms	remaining: 711ms
# 26:	test: 0.8549145	best: 0.8575981 (25)	total: 45.6ms	remaining: 714ms
# 27:	test: 0.8545790	best: 0.8575981 (25)	total: 47.4ms	remaining: 715ms
# 28:	test: 0.8564240	best: 0.8575981 (25)	total: 49.1ms	remaining: 713ms
# 29:	test: 0.8570949	best: 0.8575981 (25)	total: 50.8ms	remaining: 711ms
# 30:	test: 0.8576820	best: 0.8576820 (30)	total: 52.5ms	remaining: 710ms
# 31:	test: 0.8619591	best: 0.8619591 (31)	total: 54.1ms	remaining: 706ms
# 32:	test: 0.8611204	best: 0.8619591 (31)	total: 55.7ms	remaining: 703ms
# 33:	test: 0.8595270	best: 0.8619591 (31)	total: 57.4ms	remaining: 703ms
# 34:	test: 0.8576820	best: 0.8619591 (31)	total: 59ms	remaining: 700ms
# 35:	test: 0.8594431	best: 0.8619591 (31)	total: 61.4ms	remaining: 707ms
# 36:	test: 0.8604495	best: 0.8619591 (31)	total: 63.6ms	remaining: 710ms
# 37:	test: 0.8648943	best: 0.8648943 (37)	total: 65.8ms	remaining: 714ms
# 38:	test: 0.8669909	best: 0.8669909 (38)	total: 68.3ms	remaining: 720ms
# 39:	test: 0.8648943	best: 0.8669909 (38)	total: 70.3ms	remaining: 721ms
# 40:	test: 0.8652298	best: 0.8669909 (38)	total: 72.3ms	remaining: 721ms
# 41:	test: 0.8668232	best: 0.8669909 (38)	total: 74.1ms	remaining: 720ms
# 42:	test: 0.8658168	best: 0.8669909 (38)	total: 76ms	remaining: 719ms
# 43:	test: 0.8666555	best: 0.8669909 (38)	total: 77.7ms	remaining: 717ms
# 44:	test: 0.8697585	best: 0.8697585 (44)	total: 79.2ms	remaining: 713ms
# 45:	test: 0.8684166	best: 0.8697585 (44)	total: 80.8ms	remaining: 710ms
# 46:	test: 0.8685005	best: 0.8697585 (44)	total: 82.6ms	remaining: 708ms
# 47:	test: 0.8696746	best: 0.8697585 (44)	total: 84.3ms	remaining: 706ms
# 48:	test: 0.8674941	best: 0.8697585 (44)	total: 86ms	remaining: 704ms
# 49:	test: 0.8720228	best: 0.8720228 (49)	total: 87.9ms	remaining: 703ms
# 50:	test: 0.8718551	best: 0.8720228 (49)	total: 89.7ms	remaining: 702ms
# 51:	test: 0.8690876	best: 0.8720228 (49)	total: 91.4ms	remaining: 699ms
# 52:	test: 0.8701778	best: 0.8720228 (49)	total: 93.2ms	remaining: 698ms
# 53:	test: 0.8679973	best: 0.8720228 (49)	total: 94.9ms	remaining: 696ms
# 54:	test: 0.8691714	best: 0.8720228 (49)	total: 97.2ms	remaining: 698ms
# 55:	test: 0.8716874	best: 0.8720228 (49)	total: 99.1ms	remaining: 697ms
# 56:	test: 0.8711003	best: 0.8720228 (49)	total: 101ms	remaining: 697ms
# 57:	test: 0.8695907	best: 0.8720228 (49)	total: 103ms	remaining: 695ms
# 58:	test: 0.8690876	best: 0.8720228 (49)	total: 105ms	remaining: 693ms
# 59:	test: 0.8698423	best: 0.8720228 (49)	total: 106ms	remaining: 691ms
# 60:	test: 0.8690876	best: 0.8720228 (49)	total: 108ms	remaining: 690ms
# 61:	test: 0.8692553	best: 0.8720228 (49)	total: 110ms	remaining: 687ms
# 62:	test: 0.8674941	best: 0.8720228 (49)	total: 112ms	remaining: 685ms
# 63:	test: 0.8679973	best: 0.8720228 (49)	total: 113ms	remaining: 684ms
# 64:	test: 0.8681650	best: 0.8720228 (49)	total: 115ms	remaining: 683ms
# 65:	test: 0.8667393	best: 0.8720228 (49)	total: 117ms	remaining: 681ms
# 66:	test: 0.8690876	best: 0.8720228 (49)	total: 119ms	remaining: 679ms
# 67:	test: 0.8694230	best: 0.8720228 (49)	total: 121ms	remaining: 677ms
# 68:	test: 0.8632170	best: 0.8720228 (49)	total: 122ms	remaining: 675ms
# 69:	test: 0.8639718	best: 0.8720228 (49)	total: 124ms	remaining: 673ms
# 70:	test: 0.8644750	best: 0.8720228 (49)	total: 126ms	remaining: 671ms
# 71:	test: 0.8660684	best: 0.8720228 (49)	total: 128ms	remaining: 670ms
# 72:	test: 0.8685005	best: 0.8720228 (49)	total: 129ms	remaining: 668ms
# 73:	test: 0.8680812	best: 0.8720228 (49)	total: 131ms	remaining: 665ms
# 74:	test: 0.8674941	best: 0.8720228 (49)	total: 133ms	remaining: 663ms
# 75:	test: 0.8690037	best: 0.8720228 (49)	total: 134ms	remaining: 662ms
# 76:	test: 0.8719389	best: 0.8720228 (49)	total: 136ms	remaining: 659ms
# 77:	test: 0.8735324	best: 0.8735324 (77)	total: 138ms	remaining: 657ms
# 78:	test: 0.8745387	best: 0.8745387 (78)	total: 139ms	remaining: 655ms
# 79:	test: 0.8729453	best: 0.8745387 (78)	total: 141ms	remaining: 653ms
# 80:	test: 0.8721067	best: 0.8745387 (78)	total: 143ms	remaining: 650ms
# 81:	test: 0.8726099	best: 0.8745387 (78)	total: 144ms	remaining: 648ms
# 82:	test: 0.8726099	best: 0.8745387 (78)	total: 146ms	remaining: 646ms
# 83:	test: 0.8715196	best: 0.8745387 (78)	total: 149ms	remaining: 649ms
# 84:	test: 0.8721067	best: 0.8745387 (78)	total: 151ms	remaining: 650ms
# 85:	test: 0.8716035	best: 0.8745387 (78)	total: 154ms	remaining: 650ms
# 86:	test: 0.8725260	best: 0.8745387 (78)	total: 158ms	remaining: 658ms
# 87:	test: 0.8714358	best: 0.8745387 (78)	total: 161ms	remaining: 663ms
# 88:	test: 0.8724421	best: 0.8745387 (78)	total: 165ms	remaining: 669ms
# 89:	test: 0.8739517	best: 0.8745387 (78)	total: 168ms	remaining: 674ms
# 90:	test: 0.8739517	best: 0.8745387 (78)	total: 172ms	remaining: 679ms
# 91:	test: 0.8742033	best: 0.8745387 (78)	total: 175ms	remaining: 683ms
# 92:	test: 0.8761322	best: 0.8761322 (92)	total: 177ms	remaining: 681ms
# 93:	test: 0.8761322	best: 0.8761322 (92)	total: 179ms	remaining: 679ms
# 94:	test: 0.8739517	best: 0.8761322 (92)	total: 182ms	remaining: 679ms
# 95:	test: 0.8745387	best: 0.8761322 (92)	total: 185ms	remaining: 682ms
# 96:	test: 0.8757128	best: 0.8761322 (92)	total: 187ms	remaining: 680ms
# 97:	test: 0.8749581	best: 0.8761322 (92)	total: 190ms	remaining: 681ms
# 98:	test: 0.8772224	best: 0.8772224 (98)	total: 192ms	remaining: 682ms
# 99:	test: 0.8768870	best: 0.8772224 (98)	total: 195ms	remaining: 683ms
# 100:	test: 0.8772224	best: 0.8772224 (98)	total: 197ms	remaining: 681ms
# 101:	test: 0.8774740	best: 0.8774740 (101)	total: 199ms	remaining: 679ms
# 102:	test: 0.8787320	best: 0.8787320 (102)	total: 201ms	remaining: 676ms
# 103:	test: 0.8774740	best: 0.8787320 (102)	total: 203ms	remaining: 674ms
# 104:	test: 0.8779772	best: 0.8787320 (102)	total: 204ms	remaining: 671ms
# 105:	test: 0.8788158	best: 0.8788158 (105)	total: 206ms	remaining: 669ms
# 106:	test: 0.8768870	best: 0.8788158 (105)	total: 208ms	remaining: 666ms
# 107:	test: 0.8783965	best: 0.8788158 (105)	total: 209ms	remaining: 663ms
# 108:	test: 0.8775579	best: 0.8788158 (105)	total: 211ms	remaining: 660ms
# 109:	test: 0.8770547	best: 0.8788158 (105)	total: 213ms	remaining: 658ms
# 110:	test: 0.8775579	best: 0.8788158 (105)	total: 215ms	remaining: 655ms
# 111:	test: 0.8766354	best: 0.8788158 (105)	total: 216ms	remaining: 652ms
# 112:	test: 0.8765515	best: 0.8788158 (105)	total: 218ms	remaining: 649ms
# 113:	test: 0.8768870	best: 0.8788158 (105)	total: 219ms	remaining: 647ms
# 114:	test: 0.8740356	best: 0.8788158 (105)	total: 221ms	remaining: 645ms
# 115:	test: 0.8729453	best: 0.8788158 (105)	total: 223ms	remaining: 642ms
# 116:	test: 0.8731969	best: 0.8788158 (105)	total: 225ms	remaining: 639ms
# 117:	test: 0.8736162	best: 0.8788158 (105)	total: 226ms	remaining: 637ms
# 118:	test: 0.8721067	best: 0.8788158 (105)	total: 228ms	remaining: 634ms
# 119:	test: 0.8720228	best: 0.8788158 (105)	total: 231ms	remaining: 634ms
# 120:	test: 0.8718551	best: 0.8788158 (105)	total: 232ms	remaining: 632ms
# 121:	test: 0.8743710	best: 0.8788158 (105)	total: 234ms	remaining: 629ms
# 122:	test: 0.8737001	best: 0.8788158 (105)	total: 236ms	remaining: 627ms
# 123:	test: 0.8731969	best: 0.8788158 (105)	total: 238ms	remaining: 625ms
# 124:	test: 0.8735324	best: 0.8788158 (105)	total: 240ms	remaining: 625ms
# 125:	test: 0.8752097	best: 0.8788158 (105)	total: 243ms	remaining: 624ms
# 126:	test: 0.8749581	best: 0.8788158 (105)	total: 250ms	remaining: 637ms
# 127:	test: 0.8751258	best: 0.8788158 (105)	total: 254ms	remaining: 639ms
# 128:	test: 0.8756290	best: 0.8788158 (105)	total: 258ms	remaining: 643ms
# 129:	test: 0.8762999	best: 0.8788158 (105)	total: 260ms	remaining: 640ms
# 130:	test: 0.8754613	best: 0.8788158 (105)	total: 262ms	remaining: 638ms
# 131:	test: 0.8773901	best: 0.8788158 (105)	total: 264ms	remaining: 635ms
# 132:	test: 0.8775579	best: 0.8788158 (105)	total: 265ms	remaining: 633ms
# 133:	test: 0.8770547	best: 0.8788158 (105)	total: 267ms	remaining: 631ms
# 134:	test: 0.8763838	best: 0.8788158 (105)	total: 269ms	remaining: 628ms
# 135:	test: 0.8761322	best: 0.8788158 (105)	total: 271ms	remaining: 626ms
# 136:	test: 0.8765515	best: 0.8788158 (105)	total: 273ms	remaining: 624ms
# 137:	test: 0.8765515	best: 0.8788158 (105)	total: 275ms	remaining: 621ms
# 138:	test: 0.8765515	best: 0.8788158 (105)	total: 277ms	remaining: 619ms
# 139:	test: 0.8762160	best: 0.8788158 (105)	total: 279ms	remaining: 617ms
# 140:	test: 0.8762160	best: 0.8788158 (105)	total: 280ms	remaining: 615ms
# 141:	test: 0.8736162	best: 0.8788158 (105)	total: 282ms	remaining: 612ms
# 142:	test: 0.8725260	best: 0.8788158 (105)	total: 284ms	remaining: 610ms
# 143:	test: 0.8725260	best: 0.8788158 (105)	total: 286ms	remaining: 607ms
# 144:	test: 0.8724421	best: 0.8788158 (105)	total: 288ms	remaining: 605ms
# 145:	test: 0.8729453	best: 0.8788158 (105)	total: 289ms	remaining: 602ms
# 146:	test: 0.8715196	best: 0.8788158 (105)	total: 291ms	remaining: 600ms
# 147:	test: 0.8710164	best: 0.8788158 (105)	total: 293ms	remaining: 597ms
# 148:	test: 0.8714358	best: 0.8788158 (105)	total: 294ms	remaining: 595ms
# 149:	test: 0.8716874	best: 0.8788158 (105)	total: 296ms	remaining: 592ms
# 150:	test: 0.8718551	best: 0.8788158 (105)	total: 298ms	remaining: 590ms
# 151:	test: 0.8716035	best: 0.8788158 (105)	total: 300ms	remaining: 587ms
# 152:	test: 0.8724421	best: 0.8788158 (105)	total: 301ms	remaining: 585ms
# 153:	test: 0.8713519	best: 0.8788158 (105)	total: 303ms	remaining: 583ms
# 154:	test: 0.8723583	best: 0.8788158 (105)	total: 305ms	remaining: 581ms
# 155:	test: 0.8709326	best: 0.8788158 (105)	total: 307ms	remaining: 578ms
# 156:	test: 0.8716035	best: 0.8788158 (105)	total: 310ms	remaining: 578ms
# 157:	test: 0.8706810	best: 0.8788158 (105)	total: 312ms	remaining: 576ms
# 158:	test: 0.8708487	best: 0.8788158 (105)	total: 313ms	remaining: 573ms
# 159:	test: 0.8709326	best: 0.8788158 (105)	total: 315ms	remaining: 570ms
# 160:	test: 0.8719389	best: 0.8788158 (105)	total: 316ms	remaining: 567ms
# 161:	test: 0.8715196	best: 0.8788158 (105)	total: 318ms	remaining: 565ms
# 162:	test: 0.8710164	best: 0.8788158 (105)	total: 320ms	remaining: 563ms
# 163:	test: 0.8708487	best: 0.8788158 (105)	total: 321ms	remaining: 560ms
# 164:	test: 0.8705971	best: 0.8788158 (105)	total: 323ms	remaining: 558ms
# 165:	test: 0.8673264	best: 0.8788158 (105)	total: 325ms	remaining: 556ms
# 166:	test: 0.8680812	best: 0.8788158 (105)	total: 326ms	remaining: 553ms
# 167:	test: 0.8669071	best: 0.8788158 (105)	total: 328ms	remaining: 551ms
# 168:	test: 0.8669909	best: 0.8788158 (105)	total: 330ms	remaining: 548ms
# 169:	test: 0.8663200	best: 0.8788158 (105)	total: 332ms	remaining: 546ms
# 170:	test: 0.8660684	best: 0.8788158 (105)	total: 333ms	remaining: 544ms
# 171:	test: 0.8658168	best: 0.8788158 (105)	total: 335ms	remaining: 541ms
# 172:	test: 0.8664039	best: 0.8788158 (105)	total: 337ms	remaining: 539ms
# 173:	test: 0.8659007	best: 0.8788158 (105)	total: 338ms	remaining: 537ms
# 174:	test: 0.8661523	best: 0.8788158 (105)	total: 340ms	remaining: 534ms
# 175:	test: 0.8649782	best: 0.8788158 (105)	total: 342ms	remaining: 532ms
# 176:	test: 0.8645589	best: 0.8788158 (105)	total: 343ms	remaining: 530ms
# 177:	test: 0.8649782	best: 0.8788158 (105)	total: 345ms	remaining: 527ms
# 178:	test: 0.8645589	best: 0.8788158 (105)	total: 347ms	remaining: 525ms
# 179:	test: 0.8657330	best: 0.8788158 (105)	total: 348ms	remaining: 522ms
# 180:	test: 0.8653137	best: 0.8788158 (105)	total: 350ms	remaining: 520ms
# 181:	test: 0.8652298	best: 0.8788158 (105)	total: 351ms	remaining: 517ms
# 182:	test: 0.8653975	best: 0.8788158 (105)	total: 353ms	remaining: 515ms
# 183:	test: 0.8649782	best: 0.8788158 (105)	total: 354ms	remaining: 512ms
# 184:	test: 0.8653975	best: 0.8788158 (105)	total: 356ms	remaining: 509ms
# 185:	test: 0.8648105	best: 0.8788158 (105)	total: 357ms	remaining: 507ms
# 186:	test: 0.8648943	best: 0.8788158 (105)	total: 359ms	remaining: 505ms
# 187:	test: 0.8643911	best: 0.8788158 (105)	total: 361ms	remaining: 503ms
# 188:	test: 0.8636364	best: 0.8788158 (105)	total: 363ms	remaining: 501ms
# 189:	test: 0.8647266	best: 0.8788158 (105)	total: 365ms	remaining: 499ms
# 190:	test: 0.8660684	best: 0.8788158 (105)	total: 366ms	remaining: 497ms
# 191:	test: 0.8669071	best: 0.8788158 (105)	total: 368ms	remaining: 494ms
# 192:	test: 0.8674103	best: 0.8788158 (105)	total: 370ms	remaining: 492ms
# 193:	test: 0.8673264	best: 0.8788158 (105)	total: 371ms	remaining: 490ms
# 194:	test: 0.8672425	best: 0.8788158 (105)	total: 373ms	remaining: 488ms
# 195:	test: 0.8679973	best: 0.8788158 (105)	total: 375ms	remaining: 486ms
# 196:	test: 0.8672425	best: 0.8788158 (105)	total: 377ms	remaining: 484ms
# 197:	test: 0.8672425	best: 0.8788158 (105)	total: 378ms	remaining: 482ms
# 198:	test: 0.8692553	best: 0.8788158 (105)	total: 380ms	remaining: 479ms
# 199:	test: 0.8698423	best: 0.8788158 (105)	total: 382ms	remaining: 477ms
# 200:	test: 0.8697585	best: 0.8788158 (105)	total: 384ms	remaining: 475ms
# 201:	test: 0.8698423	best: 0.8788158 (105)	total: 385ms	remaining: 473ms
# 202:	test: 0.8675780	best: 0.8788158 (105)	total: 387ms	remaining: 471ms
# 203:	test: 0.8679135	best: 0.8788158 (105)	total: 389ms	remaining: 469ms
# 204:	test: 0.8665716	best: 0.8788158 (105)	total: 390ms	remaining: 466ms
# 205:	test: 0.8681650	best: 0.8788158 (105)	total: 392ms	remaining: 464ms
# 206:	test: 0.8679135	best: 0.8788158 (105)	total: 394ms	remaining: 462ms
# 207:	test: 0.8678296	best: 0.8788158 (105)	total: 396ms	remaining: 460ms
# 208:	test: 0.8673264	best: 0.8788158 (105)	total: 398ms	remaining: 458ms
# 209:	test: 0.8674941	best: 0.8788158 (105)	total: 399ms	remaining: 456ms
# 210:	test: 0.8659846	best: 0.8788158 (105)	total: 401ms	remaining: 454ms
# 211:	test: 0.8655652	best: 0.8788158 (105)	total: 403ms	remaining: 452ms
# 212:	test: 0.8667393	best: 0.8788158 (105)	total: 404ms	remaining: 450ms
# 213:	test: 0.8667393	best: 0.8788158 (105)	total: 406ms	remaining: 448ms
# 214:	test: 0.8677457	best: 0.8788158 (105)	total: 408ms	remaining: 446ms
# 215:	test: 0.8677457	best: 0.8788158 (105)	total: 410ms	remaining: 444ms
# 216:	test: 0.8673264	best: 0.8788158 (105)	total: 412ms	remaining: 443ms
# 217:	test: 0.8645589	best: 0.8788158 (105)	total: 414ms	remaining: 441ms
# 218:	test: 0.8668232	best: 0.8788158 (105)	total: 416ms	remaining: 439ms
# 219:	test: 0.8667393	best: 0.8788158 (105)	total: 418ms	remaining: 437ms
# 220:	test: 0.8664878	best: 0.8788158 (105)	total: 419ms	remaining: 435ms
# 221:	test: 0.8671587	best: 0.8788158 (105)	total: 421ms	remaining: 432ms
# 222:	test: 0.8685844	best: 0.8788158 (105)	total: 423ms	remaining: 431ms
# 223:	test: 0.8680812	best: 0.8788158 (105)	total: 425ms	remaining: 429ms
# 224:	test: 0.8679973	best: 0.8788158 (105)	total: 428ms	remaining: 428ms
# 225:	test: 0.8675780	best: 0.8788158 (105)	total: 431ms	remaining: 427ms
# ...
# 240:	test: 0.8150691	best: 0.8367802 (26)	total: 438ms	remaining: 380ms
# 241:	test: 0.8138677	best: 0.8367802 (26)	total: 440ms	remaining: 378ms
# 242:	test: 0.8136102	best: 0.8367802 (26)	total: 442ms	remaining: 376ms
# 243:	test: 0.8130953	best: 0.8367802 (26)	total: 443ms	remaining: 374ms
# 244:	test: 0.8142109	best: 0.8367802 (26)	total: 445ms	remaining: 372ms
# 245:	test: 0.8142967	best: 0.8367802 (26)	total: 447ms	remaining: 370ms
# 246:	test: 0.8132670	best: 0.8367802 (26)	total: 448ms	remaining: 369ms
# 247:	test: 0.8150691	best: 0.8367802 (26)	total: 450ms	remaining: 367ms
# 248:	test: 0.8154123	best: 0.8367802 (26)	total: 452ms	remaining: 365ms
# 249:	test: 0.8130953	best: 0.8367802 (26)	total: 453ms	remaining: 363ms
# 250:	test: 0.8129237	best: 0.8367802 (26)	total: 455ms	remaining: 361ms
# 251:	test: 0.8132670	best: 0.8367802 (26)	total: 457ms	remaining: 359ms
# 252:	test: 0.8130953	best: 0.8367802 (26)	total: 458ms	remaining: 357ms
# 253:	test: 0.8125805	best: 0.8367802 (26)	total: 460ms	remaining: 355ms
# 254:	test: 0.8142967	best: 0.8367802 (26)	total: 462ms	remaining: 353ms
# 255:	test: 0.8136960	best: 0.8367802 (26)	total: 463ms	remaining: 351ms
# 256:	test: 0.8141251	best: 0.8367802 (26)	total: 465ms	remaining: 349ms
# 257:	test: 0.8145542	best: 0.8367802 (26)	total: 467ms	remaining: 347ms
# 258:	test: 0.8131812	best: 0.8367802 (26)	total: 469ms	remaining: 346ms
# 259:	test: 0.8124946	best: 0.8367802 (26)	total: 470ms	remaining: 344ms
# 260:	test: 0.8123230	best: 0.8367802 (26)	total: 472ms	remaining: 342ms
# 261:	test: 0.8125805	best: 0.8367802 (26)	total: 473ms	remaining: 340ms
# 262:	test: 0.8134386	best: 0.8367802 (26)	total: 475ms	remaining: 338ms
# 263:	test: 0.8126663	best: 0.8367802 (26)	total: 477ms	remaining: 336ms
# 264:	test: 0.8146400	best: 0.8367802 (26)	total: 479ms	remaining: 334ms
# 265:	test: 0.8146400	best: 0.8367802 (26)	total: 480ms	remaining: 332ms
# 266:	test: 0.8147258	best: 0.8367802 (26)	total: 482ms	remaining: 330ms
# 267:	test: 0.8136102	best: 0.8367802 (26)	total: 484ms	remaining: 328ms
# 268:	test: 0.8137819	best: 0.8367802 (26)	total: 485ms	remaining: 327ms
# 269:	test: 0.8135244	best: 0.8367802 (26)	total: 487ms	remaining: 325ms
# 270:	test: 0.8136960	best: 0.8367802 (26)	total: 489ms	remaining: 323ms
# 271:	test: 0.8146400	best: 0.8367802 (26)	total: 490ms	remaining: 321ms
# 272:	test: 0.8148116	best: 0.8367802 (26)	total: 492ms	remaining: 319ms
# 273:	test: 0.8148975	best: 0.8367802 (26)	total: 494ms	remaining: 317ms
# 274:	test: 0.8140393	best: 0.8367802 (26)	total: 496ms	remaining: 315ms
# 275:	test: 0.8149833	best: 0.8367802 (26)	total: 497ms	remaining: 313ms
# 276:	test: 0.8150691	best: 0.8367802 (26)	total: 499ms	remaining: 311ms
# 277:	test: 0.8159272	best: 0.8367802 (26)	total: 500ms	remaining: 310ms
# 278:	test: 0.8148975	best: 0.8367802 (26)	total: 502ms	remaining: 308ms
# 279:	test: 0.8125805	best: 0.8367802 (26)	total: 504ms	remaining: 306ms
# 280:	test: 0.8124088	best: 0.8367802 (26)	total: 505ms	remaining: 304ms
# 281:	test: 0.8130095	best: 0.8367802 (26)	total: 507ms	remaining: 302ms
# 282:	test: 0.8142967	best: 0.8367802 (26)	total: 509ms	remaining: 300ms
# 283:	test: 0.8160989	best: 0.8367802 (26)	total: 510ms	remaining: 298ms
# 284:	test: 0.8162705	best: 0.8367802 (26)	total: 512ms	remaining: 296ms
# 285:	test: 0.8154123	best: 0.8367802 (26)	total: 513ms	remaining: 294ms
# 286:	test: 0.8154982	best: 0.8367802 (26)	total: 515ms	remaining: 293ms
# 287:	test: 0.8153265	best: 0.8367802 (26)	total: 517ms	remaining: 291ms
# 288:	test: 0.8159272	best: 0.8367802 (26)	total: 518ms	remaining: 289ms
# 289:	test: 0.8148975	best: 0.8367802 (26)	total: 520ms	remaining: 287ms
# 290:	test: 0.8158414	best: 0.8367802 (26)	total: 522ms	remaining: 285ms
# 291:	test: 0.8164421	best: 0.8367802 (26)	total: 523ms	remaining: 283ms
# 292:	test: 0.8143826	best: 0.8367802 (26)	total: 525ms	remaining: 281ms
# 293:	test: 0.8148116	best: 0.8367802 (26)	total: 527ms	remaining: 280ms
# 294:	test: 0.8150691	best: 0.8367802 (26)	total: 529ms	remaining: 278ms
# 295:	test: 0.8144684	best: 0.8367802 (26)	total: 531ms	remaining: 276ms
# 296:	test: 0.8141251	best: 0.8367802 (26)	total: 533ms	remaining: 274ms
# 297:	test: 0.8139535	best: 0.8367802 (26)	total: 534ms	remaining: 272ms
# 298:	test: 0.8148975	best: 0.8367802 (26)	total: 536ms	remaining: 271ms
# 299:	test: 0.8146400	best: 0.8367802 (26)	total: 537ms	remaining: 269ms
# 300:	test: 0.8143826	best: 0.8367802 (26)	total: 538ms	remaining: 267ms
# 301:	test: 0.8157556	best: 0.8367802 (26)	total: 540ms	remaining: 265ms
# 302:	test: 0.8158414	best: 0.8367802 (26)	total: 542ms	remaining: 263ms
# 303:	test: 0.8167854	best: 0.8367802 (26)	total: 543ms	remaining: 261ms
# 304:	test: 0.8169570	best: 0.8367802 (26)	total: 545ms	remaining: 259ms
# 305:	test: 0.8154123	best: 0.8367802 (26)	total: 546ms	remaining: 257ms
# 306:	test: 0.8131812	best: 0.8367802 (26)	total: 548ms	remaining: 255ms
# 307:	test: 0.8136102	best: 0.8367802 (26)	total: 550ms	remaining: 253ms
# 308:	test: 0.8131812	best: 0.8367802 (26)	total: 552ms	remaining: 252ms
# 309:	test: 0.8133528	best: 0.8367802 (26)	total: 554ms	remaining: 250ms
# 310:	test: 0.8131812	best: 0.8367802 (26)	total: 560ms	remaining: 250ms
# 311:	test: 0.8146400	best: 0.8367802 (26)	total: 563ms	remaining: 249ms
# 312:	test: 0.8148975	best: 0.8367802 (26)	total: 567ms	remaining: 248ms
# 313:	test: 0.8141251	best: 0.8367802 (26)	total: 570ms	remaining: 247ms
# 314:	test: 0.8132670	best: 0.8367802 (26)	total: 572ms	remaining: 245ms
# 315:	test: 0.8134386	best: 0.8367802 (26)	total: 574ms	remaining: 243ms
# 316:	test: 0.8113790	best: 0.8367802 (26)	total: 575ms	remaining: 241ms
# 317:	test: 0.8112932	best: 0.8367802 (26)	total: 577ms	remaining: 240ms
# 318:	test: 0.8091479	best: 0.8367802 (26)	total: 579ms	remaining: 238ms
# 319:	test: 0.8090620	best: 0.8367802 (26)	total: 580ms	remaining: 236ms
# 320:	test: 0.8088046	best: 0.8367802 (26)	total: 582ms	remaining: 234ms
# 321:	test: 0.8084613	best: 0.8367802 (26)	total: 584ms	remaining: 232ms
# 322:	test: 0.8085472	best: 0.8367802 (26)	total: 585ms	remaining: 230ms
# 323:	test: 0.8080323	best: 0.8367802 (26)	total: 587ms	remaining: 228ms
# 324:	test: 0.8080323	best: 0.8367802 (26)	total: 589ms	remaining: 226ms
# 325:	test: 0.8113790	best: 0.8367802 (26)	total: 590ms	remaining: 225ms
# 326:	test: 0.8121514	best: 0.8367802 (26)	total: 592ms	remaining: 223ms
# 327:	test: 0.8094911	best: 0.8367802 (26)	total: 594ms	remaining: 221ms
# 328:	test: 0.8117223	best: 0.8367802 (26)	total: 595ms	remaining: 219ms
# 329:	test: 0.8107783	best: 0.8367802 (26)	total: 597ms	remaining: 217ms
# 330:	test: 0.8116365	best: 0.8367802 (26)	total: 599ms	remaining: 215ms
# 331:	test: 0.8123230	best: 0.8367802 (26)	total: 600ms	remaining: 213ms
# 332:	test: 0.8118081	best: 0.8367802 (26)	total: 602ms	remaining: 212ms
# 333:	test: 0.8118081	best: 0.8367802 (26)	total: 604ms	remaining: 210ms
# 334:	test: 0.8109500	best: 0.8367802 (26)	total: 605ms	remaining: 208ms
# 335:	test: 0.8093195	best: 0.8367802 (26)	total: 607ms	remaining: 206ms
# 336:	test: 0.8098344	best: 0.8367802 (26)	total: 608ms	remaining: 204ms
# 337:	test: 0.8106067	best: 0.8367802 (26)	total: 610ms	remaining: 202ms
# 338:	test: 0.8090620	best: 0.8367802 (26)	total: 611ms	remaining: 200ms
# 339:	test: 0.8069167	best: 0.8367802 (26)	total: 613ms	remaining: 198ms
# 340:	test: 0.8073457	best: 0.8367802 (26)	total: 615ms	remaining: 196ms
# 341:	test: 0.8072599	best: 0.8367802 (26)	total: 616ms	remaining: 195ms
# 342:	test: 0.8072599	best: 0.8367802 (26)	total: 618ms	remaining: 193ms
# 343:	test: 0.8076890	best: 0.8367802 (26)	total: 620ms	remaining: 191ms
# 344:	test: 0.8094911	best: 0.8367802 (26)	total: 621ms	remaining: 189ms
# 345:	test: 0.8088046	best: 0.8367802 (26)	total: 623ms	remaining: 187ms
# 346:	test: 0.8087188	best: 0.8367802 (26)	total: 625ms	remaining: 185ms
# 347:	test: 0.8088904	best: 0.8367802 (26)	total: 626ms	remaining: 184ms
# 348:	test: 0.8075174	best: 0.8367802 (26)	total: 628ms	remaining: 182ms
# 349:	test: 0.8058011	best: 0.8367802 (26)	total: 630ms	remaining: 180ms
# 350:	test: 0.8060585	best: 0.8367802 (26)	total: 631ms	remaining: 178ms
# 351:	test: 0.8059727	best: 0.8367802 (26)	total: 633ms	remaining: 176ms
# 352:	test: 0.8043422	best: 0.8367802 (26)	total: 635ms	remaining: 174ms
# 353:	test: 0.8039990	best: 0.8367802 (26)	total: 636ms	remaining: 173ms
# 354:	test: 0.8020252	best: 0.8367802 (26)	total: 638ms	remaining: 171ms
# 355:	test: 0.8015962	best: 0.8367802 (26)	total: 640ms	remaining: 169ms
# 356:	test: 0.8023685	best: 0.8367802 (26)	total: 641ms	remaining: 167ms
# 357:	test: 0.8021969	best: 0.8367802 (26)	total: 643ms	remaining: 165ms
# 358:	test: 0.8024543	best: 0.8367802 (26)	total: 645ms	remaining: 163ms
# 359:	test: 0.8004806	best: 0.8367802 (26)	total: 646ms	remaining: 162ms
# 360:	test: 0.8004806	best: 0.8367802 (26)	total: 648ms	remaining: 160ms
# 361:	test: 0.8003947	best: 0.8367802 (26)	total: 650ms	remaining: 158ms
# 362:	test: 0.8004806	best: 0.8367802 (26)	total: 651ms	remaining: 156ms
# 363:	test: 0.8008238	best: 0.8367802 (26)	total: 653ms	remaining: 154ms
# 364:	test: 0.7995366	best: 0.8367802 (26)	total: 655ms	remaining: 152ms
# 365:	test: 0.8010813	best: 0.8367802 (26)	total: 656ms	remaining: 151ms
# 366:	test: 0.8005664	best: 0.8367802 (26)	total: 658ms	remaining: 149ms
# 367:	test: 0.7999657	best: 0.8367802 (26)	total: 660ms	remaining: 147ms
# 368:	test: 0.7996224	best: 0.8367802 (26)	total: 661ms	remaining: 145ms
# 369:	test: 0.8006522	best: 0.8367802 (26)	total: 663ms	remaining: 143ms
# 370:	test: 0.8002231	best: 0.8367802 (26)	total: 665ms	remaining: 142ms
# 371:	test: 0.8003947	best: 0.8367802 (26)	total: 666ms	remaining: 140ms
# 372:	test: 0.8005664	best: 0.8367802 (26)	total: 668ms	remaining: 138ms
# 373:	test: 0.8003089	best: 0.8367802 (26)	total: 670ms	remaining: 136ms
# 374:	test: 0.8003947	best: 0.8367802 (26)	total: 671ms	remaining: 134ms
# 375:	test: 0.7998799	best: 0.8367802 (26)	total: 673ms	remaining: 132ms
# 376:	test: 0.8001373	best: 0.8367802 (26)	total: 675ms	remaining: 131ms
# 377:	test: 0.8005664	best: 0.8367802 (26)	total: 676ms	remaining: 129ms
# 378:	test: 0.7994508	best: 0.8367802 (26)	total: 678ms	remaining: 127ms
# 379:	test: 0.7991075	best: 0.8367802 (26)	total: 680ms	remaining: 125ms
# 380:	test: 0.7993650	best: 0.8367802 (26)	total: 681ms	remaining: 123ms
# 381:	test: 0.7994508	best: 0.8367802 (26)	total: 683ms	remaining: 122ms
# 382:	test: 0.7995366	best: 0.8367802 (26)	total: 685ms	remaining: 120ms
# 383:	test: 0.7997940	best: 0.8367802 (26)	total: 686ms	remaining: 118ms
# 384:	test: 0.7986785	best: 0.8367802 (26)	total: 688ms	remaining: 116ms
# 385:	test: 0.7979919	best: 0.8367802 (26)	total: 690ms	remaining: 114ms
# 386:	test: 0.7973912	best: 0.8367802 (26)	total: 692ms	remaining: 113ms
# 387:	test: 0.7976487	best: 0.8367802 (26)	total: 694ms	remaining: 111ms
# 388:	test: 0.7979919	best: 0.8367802 (26)	total: 696ms	remaining: 109ms
# 389:	test: 0.7984210	best: 0.8367802 (26)	total: 697ms	remaining: 107ms
# 390:	test: 0.7983352	best: 0.8367802 (26)	total: 699ms	remaining: 106ms
# 391:	test: 0.7985926	best: 0.8367802 (26)	total: 701ms	remaining: 104ms
# 392:	test: 0.7977345	best: 0.8367802 (26)	total: 703ms	remaining: 102ms
# 393:	test: 0.7975629	best: 0.8367802 (26)	total: 705ms	remaining: 100ms
# 394:	test: 0.7974770	best: 0.8367802 (26)	total: 706ms	remaining: 98.3ms
# 395:	test: 0.7977345	best: 0.8367802 (26)	total: 708ms	remaining: 96.5ms
# 396:	test: 0.7962756	best: 0.8367802 (26)	total: 710ms	remaining: 94.7ms
# 397:	test: 0.7967047	best: 0.8367802 (26)	total: 711ms	remaining: 92.9ms
# 398:	test: 0.7961898	best: 0.8367802 (26)	total: 713ms	remaining: 91.1ms
# 399:	test: 0.7959324	best: 0.8367802 (26)	total: 714ms	remaining: 89.3ms
# 400:	test: 0.7970480	best: 0.8367802 (26)	total: 716ms	remaining: 87.5ms
# 401:	test: 0.7963615	best: 0.8367802 (26)	total: 718ms	remaining: 85.7ms
# 402:	test: 0.7961898	best: 0.8367802 (26)	total: 719ms	remaining: 83.9ms
# 403:	test: 0.7980777	best: 0.8367802 (26)	total: 721ms	remaining: 82.1ms
# 404:	test: 0.7975629	best: 0.8367802 (26)	total: 723ms	remaining: 80.3ms
# 405:	test: 0.7998799	best: 0.8367802 (26)	total: 724ms	remaining: 78.5ms
# 406:	test: 0.8011671	best: 0.8367802 (26)	total: 726ms	remaining: 76.7ms
# 407:	test: 0.8005664	best: 0.8367802 (26)	total: 727ms	remaining: 74.9ms
# 408:	test: 0.8000515	best: 0.8367802 (26)	total: 729ms	remaining: 73.1ms
# 409:	test: 0.8007380	best: 0.8367802 (26)	total: 730ms	remaining: 71.3ms
# 410:	test: 0.8002231	best: 0.8367802 (26)	total: 732ms	remaining: 69.5ms
# 411:	test: 0.7999657	best: 0.8367802 (26)	total: 734ms	remaining: 67.7ms
# 412:	test: 0.7999657	best: 0.8367802 (26)	total: 735ms	remaining: 65.9ms
# 413:	test: 0.7989359	best: 0.8367802 (26)	total: 737ms	remaining: 64.1ms
# 414:	test: 0.8004806	best: 0.8367802 (26)	total: 739ms	remaining: 62.3ms
# 415:	test: 0.8003089	best: 0.8367802 (26)	total: 740ms	remaining: 60.5ms
# 416:	test: 0.8005664	best: 0.8367802 (26)	total: 743ms	remaining: 58.8ms
# 417:	test: 0.7997940	best: 0.8367802 (26)	total: 745ms	remaining: 57ms
# 418:	test: 0.8007380	best: 0.8367802 (26)	total: 748ms	remaining: 55.3ms
# 419:	test: 0.8005664	best: 0.8367802 (26)	total: 752ms	remaining: 53.7ms
# 420:	test: 0.7999657	best: 0.8367802 (26)	total: 755ms	remaining: 52ms
# 421:	test: 0.7995366	best: 0.8367802 (26)	total: 758ms	remaining: 50.3ms
# 422:	test: 0.7994508	best: 0.8367802 (26)	total: 762ms	remaining: 48.6ms
# 423:	test: 0.7993650	best: 0.8367802 (26)	total: 763ms	remaining: 46.8ms
# 424:	test: 0.7982494	best: 0.8367802 (26)	total: 765ms	remaining: 45ms
# 425:	test: 0.7979919	best: 0.8367802 (26)	total: 766ms	remaining: 43.2ms
# 426:	test: 0.7991933	best: 0.8367802 (26)	total: 768ms	remaining: 41.4ms
# 427:	test: 0.7998799	best: 0.8367802 (26)	total: 770ms	remaining: 39.6ms
# 428:	test: 0.8004806	best: 0.8367802 (26)	total: 771ms	remaining: 37.8ms
# 429:	test: 0.8004806	best: 0.8367802 (26)	total: 773ms	remaining: 36ms
# 430:	test: 0.8003947	best: 0.8367802 (26)	total: 775ms	remaining: 34.2ms
# 431:	test: 0.8002231	best: 0.8367802 (26)	total: 776ms	remaining: 32.3ms
# 432:	test: 0.8000515	best: 0.8367802 (26)	total: 780ms	remaining: 30.6ms
# 433:	test: 0.7985926	best: 0.8367802 (26)	total: 781ms	remaining: 28.8ms
# 434:	test: 0.7984210	best: 0.8367802 (26)	total: 783ms	remaining: 27ms
# 435:	test: 0.7984210	best: 0.8367802 (26)	total: 785ms	remaining: 25.2ms
# 436:	test: 0.7983352	best: 0.8367802 (26)	total: 786ms	remaining: 23.4ms
# 437:	test: 0.7980777	best: 0.8367802 (26)	total: 788ms	remaining: 21.6ms
# 438:	test: 0.7982494	best: 0.8367802 (26)	total: 789ms	remaining: 19.8ms
# 439:	test: 0.7982494	best: 0.8367802 (26)	total: 791ms	remaining: 18ms
# 440:	test: 0.7988501	best: 0.8367802 (26)	total: 793ms	remaining: 16.2ms
# 441:	test: 0.7986785	best: 0.8367802 (26)	total: 795ms	remaining: 14.4ms
# 442:	test: 0.7970480	best: 0.8367802 (26)	total: 797ms	remaining: 12.6ms
# 443:	test: 0.7966189	best: 0.8367802 (26)	total: 799ms	remaining: 10.8ms
# 444:	test: 0.7959324	best: 0.8367802 (26)	total: 802ms	remaining: 9.01ms
# 445:	test: 0.7955891	best: 0.8367802 (26)	total: 804ms	remaining: 7.21ms
# 446:	test: 0.7942161	best: 0.8367802 (26)	total: 805ms	remaining: 5.4ms
# 447:	test: 0.7947310	best: 0.8367802 (26)	total: 807ms	remaining: 3.6ms
# 448:	test: 0.7961898	best: 0.8367802 (26)	total: 808ms	remaining: 1.8ms
# 449:	test: 0.7956749	best: 0.8367802 (26)	total: 809ms	remaining: 0us
#
# bestTest = 0.8367802283
# bestIteration = 26
#
# Shrink model to first 27 iterations.
# roc_val: [0.8788158336128815, 0.8518114726601811, 0.8940791680644079, 0.8412445488091244, 0.9050654142905066, 0.8451861791345187, 0.8956725930895674, 0.8237363768986528, 0.836951857890672, 0.836780228267399]
# Mean roc_val: 0.8609343672717913
#
# roc_train: [0.9401112331734003, 0.9009073296839839, 0.8825479094485602, 0.9593000510157773, 0.9451116139660125, 0.9458053868070488, 0.9185813232178123, 0.9813375291113319, 0.94010610156863, 0.8721718562363289]
# Mean roc_train: 0.9285980334228887
#
# Best Parameters: {'depth': 2, 'iterations': 450, 'l2_leaf_reg': 2.0, 'learning_rate': 0.2773718927638865, 'min_child_samples': 8, 'scale_pos_weight': 2.8052644995777545, 'subsample': 0.650172080323659}

# %%
print("roc_val:", roc_val)
print("Mean roc_val:", np.mean(roc_val))
print("\nroc_train:", roc_train)
print("Mean roc_train:", np.mean(roc_train))
print("\nBest Parameters:", best_params)
# Out:
# roc_val: [0.8788158336128815, 0.8518114726601811, 0.8940791680644079, 0.8412445488091244, 0.9050654142905066, 0.8451861791345187, 0.8956725930895674, 0.8237363768986528, 0.836951857890672, 0.836780228267399]
# Mean roc_val: 0.8609343672717913
#
# roc_train: [0.9401112331734003, 0.9009073296839839, 0.8825479094485602, 0.9593000510157773, 0.9451116139660125, 0.9458053868070488, 0.9185813232178123, 0.9813375291113319, 0.94010610156863, 0.8721718562363289]
# Mean roc_train: 0.9285980334228887
#
# Best Parameters: {'depth': 2, 'iterations': 450, 'l2_leaf_reg': 2.0, 'learning_rate': 0.2773718927638865, 'min_child_samples': 8, 'scale_pos_weight': 2.8052644995777545, 'subsample': 0.650172080323659}

# %% [markdown]
# roc_val: [0.8788158336128815, 0.8518114726601811, 0.8940791680644079, 0.8412445488091244, 0.9050654142905066, 0.8451861791345187, 0.8956725930895674, 0.8237363768986528, 0.836951857890672, 0.836780228267399]
# Mean roc_val: 0.8609343672717913
#
# roc_train: [0.9401112331734003, 0.9009073296839839, 0.8825479094485602, 0.9593000510157773, 0.9451116139660125, 0.9458053868070488, 0.9185813232178123, 0.9813375291113319, 0.94010610156863, 0.8721718562363289]
# Mean roc_train: 0.9285980334228887
#
# Best Parameters: {'depth': 2, 'iterations': 450, 'l2_leaf_reg': 2.0, 'learning_rate': 0.2773718927638865, 'min_child_samples': 8, 'scale_pos_weight': 2.8052644995777545, 'subsample': 0.650172080323659}

# %%
# make submissions

test_ = pd.read_csv('/content/drive/MyDrive/Datasets/test.csv')
predictions_cb=predictions_df.min(axis=1)
sub=pd.DataFrame({"id":test_["id"],"Attrition":predictions_cb}).set_index("id")
sub.to_csv("sub_cv.csv")
